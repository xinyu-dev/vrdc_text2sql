# %%
import json

def open_json(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        return json.load(f)
    
def open_jsonl(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        return [json.loads(line) for line in f]
    
def open_sql(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        return f.read()

def save_json(data, file_path):
    with open(file_path, 'w', encoding='utf-8') as f:
        json.dump(data, f, indent=4, ensure_ascii=False)
        
def save_jsonl(data, file_path):
    with open(file_path, 'w', encoding='utf-8') as f:
        for sample in data:
            f.write(json.dumps(sample, ensure_ascii=False) + '\n')

# %%
eicu_data = open_jsonl("/localhome/local-hndo/hndo_eval/model_evaluation/model_predictions/hvnguyen/mistral-text2sql-v6/test_mistral-text2sql-instruct-benchmark-data-v6-ehrsql-eicu-test_result.jsonl")

question = "what was patient 031-3355's last blood, venipuncture microbiology test time in this month?"

for sample in eicu_data:
    if question in sample["question"]:
        print(sample["pred"])
# Out:
# ```sql
# select microlab.culturetakentime from microlab where microlab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '031-3355' ) and microlab.culturesite = 'blood, venipuncture' and datetime(microlab.culturetakentime,'start of month') = datetime('2123-12-31','start of month') order by microlab.culturetakentime desc limit 1
# ```

# %% [markdown]
# ## error summary

# %%
data_logs = {
    "ehrsql-eicu": open_jsonl("outputs/hvnguyen/mistral-text2sql-v6/test_mistral-text2sql-instruct-benchmark-data-v6-ehrsql-eicu-test_result_evaluation_results.jsonl"),
    "ehrsql-mimic-iii": open_jsonl("outputs/hvnguyen/mistral-text2sql-v6/test_mistral-text2sql-instruct-benchmark-data-v6-ehrsql-mimiciii-test_result_evaluation_results.jsonl"),
    "mimicsql": open_jsonl("outputs/hvnguyen/mistral-text2sql-v6/test_mistral-text2sql-instruct-benchmark-data-v6-mimicsql-test_result_evaluation_results.jsonl"),
}

print(len(data_logs["ehrsql-eicu"]))
print(len(data_logs["ehrsql-mimic-iii"]))
print(len(data_logs["mimicsql"]))

def count_error_sample(data):
    error_count = 0
    for sample in data:
        if sample["sample_scores"]["accuracy"] == 0:
            error_count += 1
    return error_count

print(count_error_sample(data_logs["ehrsql-eicu"]))
print(count_error_sample(data_logs["ehrsql-mimic-iii"]))
print(count_error_sample(data_logs["mimicsql"]))
# Out:
# 1792
# 1786
# 1000
# 1059
# 1075
# 233

# %%
def count_range_error_sample(data):
    range_error_count = 0
    for sample in data:
        if sample["real"] is not None and "_lower" in sample["real"]:
            range_error_count += 1
    return range_error_count

print(count_range_error_sample(data_logs["ehrsql-eicu"]))
print(count_range_error_sample(data_logs["ehrsql-mimic-iii"]))
print(count_range_error_sample(data_logs["mimicsql"]))
# Out:
# 0
# 0
# 0

# %%
def count_timeout_sample(data):
    timeout_count = 0
    for sample in data:
        if sample["sample_scores"]["accuracy"] == 0 and sample["pred_result"] == "[\"('timeout_pred',)\"]":
            timeout_count += 1
    return timeout_count

print("ehrsql-eicu: ", count_timeout_sample(data_logs["ehrsql-eicu"]))
print("ehrsql-mimic-iii: ", count_timeout_sample(data_logs["ehrsql-mimic-iii"]))
print("mimicsql: ", count_timeout_sample(data_logs["mimicsql"]))
# Out:
# ehrsql-eicu:  12
# ehrsql-mimic-iii:  1
# mimicsql:  0

# %%
def count_error_syntax_sample(data):
    error_syntax_count = 0
    for sample in data:
        if sample["sample_scores"]["accuracy"] == 0 and sample["pred_result"] == "[\"('error_pred',)\"]":
            error_syntax_count += 1
    return error_syntax_count

print("ehrsql-eicu: ", count_error_syntax_sample(data_logs["ehrsql-eicu"]))
print("ehrsql-mimic-iii: ", count_error_syntax_sample(data_logs["ehrsql-mimic-iii"]))
print("mimicsql: ", count_error_syntax_sample(data_logs["mimicsql"]))
# Out:
# ehrsql-eicu:  200
# ehrsql-mimic-iii:  338
# mimicsql:  109

# %%
def count_empty_sample(data):
    empty_count = 0
    for sample in data:
        if sample["sample_scores"]["accuracy"] == 0 and sample["pred_result"] == "[]":
            empty_count += 1
    return empty_count

print(count_empty_sample(data_logs["ehrsql-eicu"]))
print(count_empty_sample(data_logs["ehrsql-mimic-iii"]))
print(count_empty_sample(data_logs["mimicsql"]))
# Out:
# 276
# 221
# 20

# %%
def count_none_sample(data):
    none_count = 0
    for sample in data:
        if sample["sample_scores"]["accuracy"] == 0 and sample["pred_result"] == "['(None,)']":
            none_count += 1
    return none_count

print(count_none_sample(data_logs["ehrsql-eicu"]))
print(count_none_sample(data_logs["ehrsql-mimic-iii"]))
print(count_none_sample(data_logs["mimicsql"]))
# Out:
# 50
# 47
# 4

# %% [markdown]
# ## find out the difference between code v2 --> they give diff results

# %%
data_eicu_v2 = {
    "v2-old": open_jsonl("/localhome/local-hndo/hndo_eval/model_evaluation/outputs/hvnguyen/mistral-text2sql-v24/test_mistral-text2sql-instruct-benchmark-data-genval-512-16x4-ehrsql-eicu_result_evaluation_results.jsonl"),
    "v2-new": open_jsonl("/localhome/local-hndo/hndo_eval/model_evaluation/outputs/hvnguyen/mistral-text2sql-v24/eval_v2/test_mistral-text2sql-instruct-benchmark-data-genval-512-16x4-ehrsql-eicu_result_evaluation_results.jsonl"),
}

print(len(data_eicu_v2["v2-old"]))
print(len(data_eicu_v2["v2-new"]))

def count_error_sample(data):
    error_count = 0
    for sample in data:
        if sample["sample_scores"]["accuracy"] == 0:
            error_count += 1
    return error_count

print(count_error_sample(data_eicu_v2["v2-old"]))
print(count_error_sample(data_eicu_v2["v2-new"]))
# Out:
# 1792
# 1792
# 714
# 815

# %%
count = 0
for old, new in zip(data_eicu_v2["v2-old"], data_eicu_v2["v2-new"]):
    if old["input"] == new["input"] and old["sample_scores"]["accuracy"] != new["sample_scores"]["accuracy"]:
        count += 1
        print("OLD - ACC:")
        print("REAL: ", old["real_result"])
        print("PRED: ", old["pred_result"])
        print(old["sample_scores"]["accuracy"])
        print("-"*100)
        print("NEW - Accuracy:")
        print("REAL: ", new["real_result"])
        print("PRED: ", new["pred_result"])
        print(new["sample_scores"]["accuracy"])
        print("="*100)
print(count)
# Out:
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(77.1,)']
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('surgical drains - jackson-pratt',)"]
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('lasix',)", "('oxycodone hcl 5 mg po tabs',)", "('sennosides-docusate sodium 8.6-50 mg po tabs',)"]
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('potassium chloride',)"]
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(307,)']
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(2.9,)']
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('penicillin g sodium',)", "('penicillin',)", "('see cerner',)"]
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('gram positive cocci',)"]
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('sputum, tracheal specimen',)"]
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('p.o.',)"]
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('intake (ml)-ng/og tube nasogastric right nostril',)"]
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(None,)']
# PRED:  ['(None,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(641.8,)']
# PRED:  ['(None,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('output (ml)-ng/og tube nasogastric left nostril',)"]
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('urine',)"]
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(None,)']
# PRED:  ['(None,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(650,)']
# PRED:  ['(None,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(None,)']
# PRED:  ['(None,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(-1773.06,)']
# PRED:  ['(None,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(None,)']
# PRED:  ['(None,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(-282.7,)']
# PRED:  ['(None,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(None,)']
# PRED:  ['(None,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(95.5,)']
# PRED:  ['(None,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('2103-05-02 21:23:00',)"]
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('2102-08-01 01:09:00',)"]
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('2102-08-28 19:55:00',)"]
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('2104-12-11 01:25:00',)"]
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('2104-12-14 16:46:00',)"]
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('2105-12-31 13:58:00',)"]
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('2105-12-08 12:22:00',)"]
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('2105-05-13 00:34:00',)"]
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('2103-07-24 11:24:00',)"]
# PRED:  ["('2103-07-21 14:03:00',)"]
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('2100-01-27 00:24:00',)"]
# PRED:  ["('2100-02-06 17:56:00',)"]
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('2104-11-29 10:56:00',)"]
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('2104-12-21 16:51:00',)"]
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('2105-06-09 00:03:00',)"]
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('2101-10-04 16:54:00',)"]
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(1,)']
# PRED:  ['(0,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(1,)']
# PRED:  ['(0,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(1,)']
# PRED:  ['(0,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(1,)']
# PRED:  ['(0,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(1,)']
# PRED:  ['(0,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(1,)']
# PRED:  ['(0,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(1,)']
# PRED:  ['(0,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(1,)']
# PRED:  ['(0,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(1,)']
# PRED:  ['(0,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(1,)']
# PRED:  ['(0,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(1,)']
# PRED:  ['(0,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(1,)']
# PRED:  ['(0,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(1,)']
# PRED:  ['(0,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(1,)']
# PRED:  ['(0,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(1,)']
# PRED:  ['(0,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('2103-05-21 01:05:00',)"]
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(20.7,)']
# PRED:  ["('2102-04-24', 20.7)"]
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(87,)', '(94,)']
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(1,)']
# PRED:  ['(0,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(1,)']
# PRED:  ['(0,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(2,)']
# PRED:  ['(0,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(1,)']
# PRED:  ['(0,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(1,)']
# PRED:  ['(0,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(1,)']
# PRED:  ['(0,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('006-200601',)"]
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('030-52395',)"]
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('004-34394',)", "('005-8370',)", "('006-97726',)", "('013-27480',)", "('027-135082',)", "('027-95744',)", "('030-30152',)", "('030-53416',)"]
# PRED:  ["('004-34394',)", "('005-8370',)"]
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('003-39001',)"]
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(1,)']
# PRED:  ['(0,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(1,)']
# PRED:  ['(0,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(879,)']
# PRED:  ['(919,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(186,)']
# PRED:  ['(0,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(794,)']
# PRED:  ['(0,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(2,)']
# PRED:  ['(0,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(2,)']
# PRED:  ['(0,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(12,)']
# PRED:  ['(0,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(9,)']
# PRED:  ['(0,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(4,)']
# PRED:  ['(7,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(6,)']
# PRED:  ['(0,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(7,)']
# PRED:  ['(0,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(1,)']
# PRED:  ['(0,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(92,)']
# PRED:  ['(0,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(3,)']
# PRED:  ['(0,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(1,)']
# PRED:  ['(0,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(1,)']
# PRED:  ['(0,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(100,)']
# PRED:  ['(0,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(362,)']
# PRED:  ['(0,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ['(30,)']
# PRED:  ['(0,)']
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('acute respiratory failure',)", "('congestive heart failure',)", "('diabetes mellitus',)", "('hypertension',)", "('pain',)"]
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('abdominal pain / tenderness',)", "('acute copd exacerbation',)", "('acute renal failure',)", "('acute respiratory failure',)", "('atrial fibrillation',)", "('cardiac arrest',)", "('change in mental status',)", "('diabetes mellitus',)", "('encephalopathy - metabolic',)", "('hyperglycemia',)", "('hyperlipidemia',)", "('hypertension',)", "('hypotension / pressor dependent',)", "('hypotension',)", "('hypothyroidism',)", "('hypoxemia',)", "('nutritional deficiency',)", "('pain',)", "('pneumonia - aspiration',)", "('pneumonia',)"]
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('chest x-ray',)", "('mechanical ventilation',)", "('stress ulcer prophylaxis - pantoprazole',)"]
# PRED:  ["('chest x-ray', 118)", "('mechanical ventilation', 197)", "('stress ulcer prophylaxis - pantoprazole', 88)"]
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('abscess drainage procedure - percutaneous',)", "('alpha/beta blocker - carvedilol',)", "('analgesics - narcotic analgesic',)", "('analgesics - non-narcotic analgesic',)", "('analgesics - pca',)", "('antiarrhythmics - class iv antiarrhythmic',)", "('antiarrhythmics',)", "('antibacterials - third generation cephalosporin',)", "('anticoagulant administration - conventional heparin therapy',)", "('antiemetic - serotonin antagonist',)", "('antiemetic',)", "('antifibrinolytics - amicar (aminocaproic acid)',)", "('antihyperlipidemic agent - hmg-coa reductase inhibitor',)", "('antihypertensive drug - labetalol',)", "('antihypertensives - nicardipine',)", "('antiplatelet agent - aspirin',)", "('beta blocker - esmolol',)", "('cabg',)", "('calcium channel blocker - diltiazem',)", "('cardiology consultation',)", "('cpap/peep therapy - 5-10 cm h2o',)", "('cultures - blood',)", "('cultures - urine',)", "('cultures',)", "('diagnostic ultrasound of heart - transthoracic echocardiography',)", "('endotracheal tube removal',)", "('endotracheal tube',)", "('ent consultation',)", "('enteral feeds - oral feeds',)", "('enteral feeds',)", "('exploratory laparoscopy',)", "('exploratory laparotomy',)", "('glucocorticoid administration',)", "('glucose',)", "('head ct scan',)", "('hematopoietic growth factors - filgrastim (neupogen)',)", "('hemodialysis - for acute renal failure',)", "('inotropic agent - dopamine <= 5 micrograms/kg/min',)", "('insertion of thoracostomy tube - for drainage of effusion',)", "('intravenous diuretic',)", "('mechanical ventilation - assist controlled',)", "('mechanical ventilation',)", "('normal saline solution',)", "('occupational therapy consult',)", "('orthopedics consultation',)", "('oxygen therapy (40% to 60%) - 50-60%',)", "('oxygen therapy (< 40%) - nasal cannula',)", "('oxygen therapy (> 60%) - reduce fio2 as tolerated',)", "('oxygen therapy (> 60%)',)", "('pulmonary/ccm consultation',)", "('sedative agent - lorazepam',)", "('sedative agent - midazolam',)", "('sedative agent - propofol',)", "('sedative',)", "('stress ulcer prophylaxis - famotidine',)", "('stress ulcer prophylaxis',)", "('stress ulcer treatment - pantoprazole',)", "('stress ulcer treatment',)", "('surgical debulking for cancer',)", "('therapeutic antibacterials - fourth generation cephalosporin',)", "('therapeutic antibacterials - penicillins',)", "('therapeutic antibacterials - vancomycin',)", "('thoracic surgery consultation',)", "('tracheal suctioning',)", "('ultrasonography - abdomen',)", "('vasopressors - norepinephrine > 0.1 micrograms/kg/min',)", "('vasopressors - phenylephrine (neosynephrine)',)", "('ventilator weaning',)", "('vte prophylaxis - compression boots',)", "('vte prophylaxis - compression stockings',)", "('vte prophylaxis',)", "('wound care',)"]
# PRED:  ["('head ct scan', '2104')", "('stress ulcer treatment - pantoprazole', '2104')", "('therapeutic antibacterials - vancomycin', '2104')", "('vasopressors - norepinephrine > 0.1 micrograms/kg/min', '2104')", "('ventilator weaning', '2104')"]
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('ace inhibitor - lisinopril',)", "('administration of electrolytes - intravenous',)", "('administration of electrolytes - potassium',)", "('administration of saline solution',)", "('analgesics - bolus parenteral analgesics',)", "('analgesics - narcotic analgesic',)", "('analgesics - non-narcotic analgesic',)", "('analgesics - oral analgesics',)", "('anti-psychotic agent',)", "('antiarrhythmics - class i antiarrhythmic',)", "('antiarrhythmics - class iii antiarrhythmic',)", "('antiarrhythmics - class iv antiarrhythmic',)", "('antibacterials',)", "('anticonvulsant - levetiracetam',)", "('anticonvulsant - lorazepam',)", "('antihypertensives - labetalol',)", "('antiplatelet agent - aspirin',)", "('antiplatelet agent',)", "('bicarbonate - sodium bicarbonate',)", "('bronchodilator - beta-agonist',)", "('bronchodilator - combination beta-agonist/anticholinergic',)", "('bronchodilator - ipratropium',)", "('bronchodilator',)", "('cardiology consultation',)", "('chest tube',)", "('chest x-ray',)", "('colloid administration - albumin',)", "('cpap/peep therapy - 5-10 cm h2o',)", "('cpap/peep therapy',)", "('ct scan - abdomen',)", "('ct scan - head',)", "('ct scan',)", "('cultures - blood',)", "('cultures - sputum',)", "('cultures - urine',)", "('cultures',)", "('darbepoetin alfa',)", "('diagnostic ultrasound of heart - transthoracic echocardiography',)", "('diagnostic ultrasound of heart',)", "('eeg monitoring',)", "('electrolyte administration - intravenous',)", "('electrolyte administration - phosphate',)", "('electrolyte administration',)", "('endotracheal tube - insertion',)", "('esophagogastroduodenoscopy',)", "('exploratory laparotomy',)", "('feeding tube',)", "('foley catheter',)", "('gastroenterology consultation',)", "('glucocorticoid administration - parenteral',)", "('glucocorticoid administration',)", "('head ct scan',)", "('hemodialysis',)", "('hormonal therapy (for varices) - octreotide',)", "('infectious disease consultation',)", "('insertion of venous catheter for hemodialysis',)", "('insulin - sliding scale administration',)", "('insulin - subcutaneous dose of regular insulin',)", "('intravenous diuretic',)", "('laxatives - doss (colace)',)", "('mechanical ventilation',)", "('nephrology consultation',)", "('nimodipine',)", "('nitroglycerin - intravenous',)", "('nitroglycerin',)", "('non-invasive ventilation',)", "('normal saline administration - aggressive volume resuscitation (>250 mls/hr)',)", "('normal saline administration - fluid bolus (250-1000mls)',)", "('normal saline administration - moderate volume resuscitation (150-250 mls/hr)',)", "('oxygen therapy (40% to 60%) - 50-60%',)", "('oxygen therapy (40% to 60%)',)", "('oxygen therapy (< 40%) - nasal cannula',)", "('oxygen therapy (< 40%)',)", "('oxygen therapy (> 60%) - 70-80%',)", "('oxygen therapy (> 60%) - >90%',)", "('oxygen therapy (> 60%) - face mask',)", "('oxygen therapy (> 60%) - reduce fio2 as tolerated',)", "('parenteral feeds - intralipid',)", "('physical therapy consult',)", "('prophylactic antibacterials',)", "('psychiatry consultation',)", "('pulmonary/ccm consultation',)", "('reintubation',)", "('sedative - midazolam',)", "('sedative agent - midazolam',)", "('social work consult',)", "('stress ulcer prophylaxis - pantoprazole',)", "('therapeutic antibacterials - aminoglycoside',)", "('therapeutic antibacterials - penicillins',)", "('therapeutic antibacterials - vancomycin',)", "('thoracoscopic procedure - pleurodesis',)", "('tracheal suctioning',)", "('vascular catheter placement - arterial',)", "('vasopressors - epinephrine <= 0.1 micrograms/kg/min',)", "('vasopressors',)", "('ventilator weaning - rapid',)", "('ventilator weaning',)", "('vitamin k',)", "('vte prophylaxis - compression boots',)", "('vte prophylaxis',)"]
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('1000 ml flex cont : sodium chloride 0.9 % iv soln',)", "('acetaminophen',)", "('lasix',)", "('potassium chloride crys er 20 meq po tbcr',)", "('potassium chloride',)"]
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('acetaminophen 325 mg po tabs',)", "('aspirin',)", "('lasix',)", "('potassium chloride',)", "('sodium chloride 0.9% 1000 ml lvp',)"]
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('37.5 g tube : glucose 40 % po gel',)", "('diphenhydramine hcl 25 mg po caps',)", "('fentanyl (pf) 50 mcg/1 ml 2 ml inj',)", "('insulin (regular) 100 units in 1',)", "('metoprolol tartrate 50 mg po tabs',)", "('ondansetron (zofran) injection 4 mg',)", "('prednisone',)", "('zofran',)"]
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('bedside glucose',)", "('glucose',)", "('hgb',)", "('potassium',)"]
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('bedside glucose',)", "('creatinine',)", "('hgb',)", "('potassium',)", "('sodium',)"]
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('bedside glucose',)", "('hgb',)", "('potassium',)", "('sodium',)"]
# PRED:  ["('bedside glucose', 18992)", "('hgb', 7899)", "('potassium', 9028)", "('sodium', 8201)"]
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('bedside glucose',)", "('glucose',)", "('hgb',)", "('potassium',)", "('sodium',)"]
# PRED:  ["('bedside glucose', 7938)", "('glucose', 3297)", "('hgb', 3288)", "('potassium', 3800)", "('sodium', 3340)"]
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('bedside glucose',)", "('hgb',)", "('potassium',)", "('sodium',)"]
# PRED:  ["('bedside glucose', 2286)", "('hgb', 965)", "('potassium', 1067)", "('sodium', 957)"]
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('bedside glucose',)", "('hgb',)", "('potassium',)", "('sodium',)"]
# PRED:  ["('bedside glucose', 4520)", "('hgb', 1873)", "('potassium', 2136)", "('sodium', 1890)"]
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('bedside glucose',)", "('hgb',)", "('potassium',)"]
# PRED:  ["('bedside glucose', 3799)", "('hgb', 1656)", "('potassium', 1925)"]
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('bedside glucose',)", "('bun',)", "('potassium',)", "('sodium',)"]
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('bedside glucose',)", "('bicarbonate',)", "('potassium',)", "('sodium',)"]
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('sputum, tracheal specimen',)"]
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('continuous infusion meds',)", "('ns ivf',)", "('ns',)", "('p.o.',)"]
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('continuous infusion meds',)", "('ns ivf',)", "('ns',)", "('p.o.',)"]
# PRED:  []
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('continuous infusion meds',)", "('ns ivf',)", "('p.o.',)"]
# PRED:  ["('ns ivf', 216)", "('p.o.', 277)", "('urine', 1705)"]
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('continuous infusion meds',)", "('ivpb',)", "('ns ivf',)", "('ns',)", "('p.o.',)"]
# PRED:  ["('continuous infusion meds', 105)", "('ns ivf', 115)", "('p.o.', 135)", "('urine catheter', 114)", "('urine', 836)"]
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('continuous infusion meds',)", "('ivpb',)", "('ns ivf',)", "('ns',)", "('p.o.',)"]
# PRED:  ["('continuous infusion meds', 291)", "('ivpb', 241)", "('ns ivf', 316)", "('ns', 245)", "('p.o.', 447)"]
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('indwelling catheter',)", "('stool',)", "('urinary catheter output: indwelling/continuous ure',)", "('urine catheter',)", "('urine',)"]
# PRED:  ["('indwelling catheter', 938)", "('stool', 1203)", "('urinary catheter output: indwelling/continuous ure', 1628)", "('urine catheter', 2567)", "('urine', 20973)"]
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('urinary catheter output: indwelling/continuous ure',)", "('urine catheter',)", "('urine',)"]
# PRED:  ["('urinary catheter output: indwelling/continuous ure', 1628)", "('urine catheter', 2567)", "('urine', 20973)"]
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('indwelling catheter',)", "('stool',)", "('urinary catheter output: indwelling/continuous ure',)", "('urine catheter',)", "('urine',)"]
# PRED:  ["('indwelling catheter', 938)", "('stool', 1203)", "('urinary catheter output: indwelling/continuous ure', 1628)", "('urine catheter', 2567)", "('urine', 20973)"]
# 0
# ====================================================================================================
# OLD - ACC:
# REAL:  ["('error_real',)"]
# PRED:  ["('timeout_pred',)"]
# 0
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('error_real',)"]
# PRED:  ["('timeout_pred',)"]
# 1
# ====================================================================================================
# OLD - ACC:
# REAL:  ["('error_real',)"]
# PRED:  ["('timeout_pred',)"]
# 0
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('error_real',)"]
# PRED:  ["('timeout_pred',)"]
# 1
# ====================================================================================================
# OLD - ACC:
# REAL:  ["('error_real',)"]
# PRED:  ["('timeout_pred',)"]
# 0
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('error_real',)"]
# PRED:  ["('timeout_pred',)"]
# 1
# ====================================================================================================
# OLD - ACC:
# REAL:  ["('error_real',)"]
# PRED:  ["('timeout_pred',)"]
# 0
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('error_real',)"]
# PRED:  ["('timeout_pred',)"]
# 1
# ====================================================================================================
# OLD - ACC:
# REAL:  ["('error_real',)"]
# PRED:  ["('timeout_pred',)"]
# 0
# ----------------------------------------------------------------------------------------------------
# NEW - Accuracy:
# REAL:  ["('error_real',)"]
# PRED:  ["('timeout_pred',)"]
# 1
# ====================================================================================================
# 111

# %%
data_mimic = {
    "v2": open_jsonl("/localhome/local-hndo/hndo_eval/model_evaluation/outputs/model_base/llama31-nemotron-nano-8b-v1/llama31-nemotron-nano-8b-v1_mimicsql_results_evaluation_results.jsonl"),
    "v3": open_jsonl("/localhome/local-hndo/hndo_eval/model_evaluation/outputs/new-ddl-inst/llama31-nemotron-nano-8b-v1/Llama-3.1-Nemotron-Nano-8B-v1_mimicsql_result_thinking_on_evaluation_results.jsonl"),
}

print(len(data_mimic["v2"]))
print(len(data_mimic["v3"]))

def count_error_sample(data):
    error_count = 0
    for sample in data:
        if sample["sample_scores"]["accuracy"] == 0:
            error_count += 1
    return error_count

print(count_error_sample(data_mimic["v2"]))
print(count_error_sample(data_mimic["v3"]))
# Out:
# 1000
# 1000
# 406
# 698

# %%
count = 0
for v2, v3 in zip(data_mimic["v2"], data_mimic["v3"]):
    if v3["user_query"] in v2["input"] and v2["sample_scores"]["accuracy"] != v3["sample_scores"]["accuracy"]:
        count += 1
        print("V2 - ACC:")
        print("SQL REAL: ", v2["output"])
        print("SQL PRED: ", v2["predict"])
        print("REAL: ", v2["real_result"])
        print("PRED: ", v2["pred_result"])
        print(v2["sample_scores"]["accuracy"])
        print("-"*100)
        print("V3 - Accuracy:")
        print("SQL REAL: ", v3["output"])
        print("SQL PRED: ", v3["predict"])
        print("REAL: ", v3["real_result"])
        print("PRED: ", v3["pred_result"])
        print(v3["sample_scores"]["accuracy"])
        print("="*100)
        print("="*100)
print(count)
# Out:
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC INNER JOIN DIAGNOSES on DEMOGRAPHIC.HADM_ID = DIAGNOSES.HADM_ID WHERE DIAGNOSES."ICD9_CODE" = "53190"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM DIAGNOSES
# JOIN DEMOGRAPHIC ON DIAGNOSES.SUBJECT_ID = DEMOGRAPHIC.SUBJECT_ID
# WHERE DIAGNOSES.ICD9_CODE = '53190';
# REAL:  ['(1,)']
# PRED:  ['(2,)']
# 0
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC INNER JOIN DIAGNOSES on DEMOGRAPHIC.HADM_ID = DIAGNOSES.HADM_ID WHERE DIAGNOSES."ICD9_CODE" = "53190"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM DIAGNOSES
# WHERE ICD9_CODE = '53190';
# REAL:  ['(1,)']
# PRED:  ['(1,)']
# 1
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC INNER JOIN DIAGNOSES on DEMOGRAPHIC.HADM_ID = DIAGNOSES.HADM_ID WHERE DIAGNOSES."SHORT_TITLE" = "Chordae tendinae rupture"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM DEMOGRAPHIC d
# JOIN DIAGNOSES dg ON d.SUBJECT_ID = dg.SUBJECT_ID
# WHERE dg.ICD9_CODE = '35.00.05' AND dg.SHORT_TITLE = 'Ruptured bungee cord'
# ;
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC INNER JOIN DIAGNOSES on DEMOGRAPHIC.HADM_ID = DIAGNOSES.HADM_ID WHERE DIAGNOSES."SHORT_TITLE" = "Chordae tendinae rupture"
# ```
# SQL PRED:  None
# REAL:  ['(0,)']
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC INNER JOIN PRESCRIPTIONS on DEMOGRAPHIC.HADM_ID = PRESCRIPTIONS.HADM_ID WHERE PRESCRIPTIONS."DRUG" = "Zyrtec"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM PRESCRIPTIONS
# JOIN DEMOGRAPHIC ON PRESCRIPTIONS.SUBJECT_ID = DEMOGRAPHIC.SUBJECT_ID
# WHERE DRUG = 'Zyrtec';
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC INNER JOIN PRESCRIPTIONS on DEMOGRAPHIC.HADM_ID = PRESCRIPTIONS.HADM_ID WHERE PRESCRIPTIONS."DRUG" = "Zyrtec"
# ```
# SQL PRED:  None
# REAL:  ['(0,)']
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC INNER JOIN PRESCRIPTIONS on DEMOGRAPHIC.HADM_ID = PRESCRIPTIONS.HADM_ID WHERE PRESCRIPTIONS."DRUG" = "Oxycodone SR (OxyconTIN)"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM PRESCRIPTIONS
# JOIN DEMOGRAPHIC ON PRESCRIPTIONS.SUBJECT_ID = DEMOGRAPHIC.SUBJECT_ID
# WHERE DRUG = 'OXYCODONE SR' AND DRUG_TYPE = 'Prescription';
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC INNER JOIN PRESCRIPTIONS on DEMOGRAPHIC.HADM_ID = PRESCRIPTIONS.HADM_ID WHERE PRESCRIPTIONS."DRUG" = "Oxycodone SR (OxyconTIN)"
# ```
# SQL PRED:  None
# REAL:  ['(0,)']
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC INNER JOIN PRESCRIPTIONS on DEMOGRAPHIC.HADM_ID = PRESCRIPTIONS.HADM_ID WHERE PRESCRIPTIONS."DRUG" = "Caspofungin"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM PRESCRIPTIONS
# JOIN DEMOGRAPHIC ON PRESCRIPTIONS.SUBJECT_ID = DEMOGRAPHIC.SUBJECT_ID
# WHERE DRUG = 'capso fungin';
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC INNER JOIN PRESCRIPTIONS on DEMOGRAPHIC.HADM_ID = PRESCRIPTIONS.HADM_ID WHERE PRESCRIPTIONS."DRUG" = "Caspofungin"
# ```
# SQL PRED:  None
# REAL:  ['(0,)']
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC INNER JOIN PROCEDURES on DEMOGRAPHIC.HADM_ID = PROCEDURES.HADM_ID WHERE DEMOGRAPHIC."GENDER" = "F" AND PROCEDURES."SHORT_TITLE" = "Abdomen artery incision"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM PROCEDURES
# JOIN DEMOGRAPHIC ON PROCEDURES.SUBJECT_ID = DEMOGRAPHIC.SUBJECT_ID
# WHERE DEMOGRAPHIC.GENDER = 'F'
# AND ICD9_CODE = '36.9.1.1'  -- ICD-9 code for abdominal artery incision
# LIMIT 1;
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC INNER JOIN PROCEDURES on DEMOGRAPHIC.HADM_ID = PROCEDURES.HADM_ID WHERE DEMOGRAPHIC."GENDER" = "F" AND PROCEDURES."SHORT_TITLE" = "Abdomen artery incision"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM PROCEDURES
# JOIN DEMOGRAPHIC ON DEMOGRAPHIC.SUBJECT_ID = PROCEDURES.SUBJECT_ID
# JOIN DEMOGRAPHIC.GENDER = DEMOGRAPHIC.GENDER AND DEMOGRAPHIC.GENDER = 'F'
# JOIN PROCEDURES.ICD9_CODE = PROCEDURES.ICD9_CODE
# WHERE PROCEDURES.SHORT_TITLE = 'ABDOMEN ARTERY INCISION';
# REAL:  ['(0,)']
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC INNER JOIN LAB on DEMOGRAPHIC.HADM_ID = LAB.HADM_ID WHERE DEMOGRAPHIC."GENDER" = "M" AND LAB."LABEL" = "Ferritin"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM LAB
# JOIN DEMOGRAPHIC ON LAB.SUBJECT_ID = DEMOGRAPHIC.SUBJECT_ID
# WHERE DEMOGRAPHIC.GENDER = 'M'
# AND LAB.LABEL = 'ferritin';
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC INNER JOIN LAB on DEMOGRAPHIC.HADM_ID = LAB.HADM_ID WHERE DEMOGRAPHIC."GENDER" = "M" AND LAB."LABEL" = "Ferritin"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM LAB
# JOIN DEMOGRAPHIC ON LAB.SUBJECT_ID = DEMOGRAPHIC.SUBJECT_ID
# JOIN DEMOGRAPHIC ON LAB.HADM_ID = DEMOGRAPHIC.HADM_ID
# WHERE DEMOGRAPHIC.GENDER = 'M'
# AND LAB.LABEL = 'Ferritin';
# REAL:  ['(0,)']
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."ADMISSION_TYPE" = "NEWBORN" AND DEMOGRAPHIC."ADMITYEAR" < "2177"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM DEMOGRAPHIC
# WHERE ADMITYEAR < 2177
#   AND ADMISSION_TYPE = 'Newborn';
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."ADMISSION_TYPE" = "NEWBORN" AND DEMOGRAPHIC."ADMITYEAR" < "2177"
# ```
# SQL PRED:  None
# REAL:  ['(0,)']
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC INNER JOIN DIAGNOSES on DEMOGRAPHIC.HADM_ID = DIAGNOSES.HADM_ID WHERE DEMOGRAPHIC."ADMISSION_TYPE" = "ELECTIVE" AND DIAGNOSES."LONG_TITLE" = "Drug induced neutropenia"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM DEMOGRAPHIC d
# JOIN DIAGNOSES dg ON d.SUBJECT_ID = dg.SUBJECT_ID
# WHERE d.ADMISSION_TYPE = 'Elective'
#   AND dg.ICD9_CODE = '248.0'; -- ICD-9 code for drug-induced neutropenia
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC INNER JOIN DIAGNOSES on DEMOGRAPHIC.HADM_ID = DIAGNOSES.HADM_ID WHERE DEMOGRAPHIC."ADMISSION_TYPE" = "ELECTIVE" AND DIAGNOSES."LONG_TITLE" = "Drug induced neutropenia"
# ```
# SQL PRED:  None
# REAL:  ['(0,)']
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC INNER JOIN PROCEDURES on DEMOGRAPHIC.HADM_ID = PROCEDURES.HADM_ID WHERE DEMOGRAPHIC."ADMISSION_TYPE" = "ELECTIVE" AND PROCEDURES."SHORT_TITLE" = "Unilat rad neck dissect"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM (
#   SELECT DISTINCT HADM_ID
#   FROM DEMOGRAPHIC
#   JOIN PROCEDURES ON DEMOGRAPHIC.HADM_ID = PROCEDURES.HADM_ID
#   WHERE
#     ADMISSION_TYPE = 'Elective'
#     AND EXPIRE_FLAG = 0  -- Exclude deceased patients
#     AND ICD9_CODE = '0343'  -- ICD-9 code for radical neck dissection (unilateral)
#   GROUP BY HADM_ID
# ) AS ELECTIVE_ADMISSIONS;
# REAL:  ['(0,)']
# PRED:  ["('error_pred',)"]
# 0
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC INNER JOIN PROCEDURES on DEMOGRAPHIC.HADM_ID = PROCEDURES.HADM_ID WHERE DEMOGRAPHIC."ADMISSION_TYPE" = "ELECTIVE" AND PROCEDURES."SHORT_TITLE" = "Unilat rad neck dissect"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM PROCEDURES
# JOIN DEMOGRAPHIC ON DEMOGRAPHIC.SUBJECT_ID = PROCEDURES.SUBJECT_ID
# JOIN DIAGNOSES ON DEMOGRAPHIC.HADM_ID = DIAGNOSES.HADM_ID
# WHERE PROCEDURES.ICD9_CODE = '0224'  -- ICD-9 code for unilateral radical neck dissection
#   AND DEMOGRAPHIC.ADMISSION_TYPE = 'ELECTIVE'
#   AND PROCEDURES.ICD9_CODE IS NOT NULL;
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC INNER JOIN LAB on DEMOGRAPHIC.HADM_ID = LAB.HADM_ID WHERE DEMOGRAPHIC."ADMISSION_TYPE" = "EMERGENCY" AND LAB."LABEL" = "LD, Body Fluid"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM LAB
# JOIN DEMOGRAPHIC ON LAB.SUBJECT_ID = DEMOGRAPHIC.SUBJECT_ID
# WHERE DEMOGRAPHIC.ADMISSION_TYPE = 'Emergency'
# AND LAB.FLUID = 'Blood'
# AND LAB.CATEGORY = 'Hematology';
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC INNER JOIN LAB on DEMOGRAPHIC.HADM_ID = LAB.HADM_ID WHERE DEMOGRAPHIC."ADMISSION_TYPE" = "EMERGENCY" AND LAB."LABEL" = "LD, Body Fluid"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM LAB
# JOIN DEMOGRAPHIC ON LAB.SUBJECT_ID = DEMOGRAPHIC.SUBJECT_ID
# JOIN PROCEDURES ON LAB.HADM_ID = DEMOGRAPHIC.HADM_ID
# WHERE LAB.FLUID = 'Ld Body Fluid Test' -- Assuming "Ld" is the abbreviation for "Low" or "Leukocytosis"
# AND PROCEDURES.ICD9_CODE LIKE '%EMERGENCY%' -- Assuming ICD9 codes for emergency procedures
# AND DEMOGRAPHIC.ADMIT_TYPE = 'EMERGENCY'; -- Filter for emergency admissions
# REAL:  ['(0,)']
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC INNER JOIN LAB on DEMOGRAPHIC.HADM_ID = LAB.HADM_ID WHERE DEMOGRAPHIC."ADMISSION_TYPE" = "EMERGENCY" AND LAB."LABEL" = "Reticulocyte Count, Manual"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM LAB
# JOIN DEMOGRAPHIC ON LAB.SUBJECT_ID = DEMOGRAPHIC.SUBJECT_ID
# WHERE ADMISSION_TYPE = 'Emergency'
#   AND ITEMID = 'Reticulocyte count'
#   AND FLAG = 'Manual';
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC INNER JOIN LAB on DEMOGRAPHIC.HADM_ID = LAB.HADM_ID WHERE DEMOGRAPHIC."ADMISSION_TYPE" = "EMERGENCY" AND LAB."LABEL" = "Reticulocyte Count, Manual"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM LAB
# JOIN DEMOGRAPHIC ON LAB.SUBJECT_ID = DEMOGRAPHIC.SUBJECT_ID
# JOIN PROCEDURES ON LAB.SUBJECT_ID = PROCEDURES.SUBJECT_ID
# JOIN DEMOGRAPHIC ON PROCEDURES.SUBJECT_ID = DEMOGRAPHIC.SUBJECT_ID
# WHERE LAB.CATEGORY = 'Hematology'
#   AND LAB.FLAG = 'abnormal'
#   AND PROCEDURES.ICD9_CODE = 'C2120'  -- Manual reticulocyte count ICD-9 code
#   AND DEMOGRAPHIC.ADMIT_TYPE = 'EMERGENCY';
# REAL:  ['(0,)']
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."ETHNICITY" = "AMERICAN INDIAN/ALASKA NATIVE" AND DEMOGRAPHIC."AGE" < "67"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM DEMOGRAPHIC
# WHERE ETHNICITY = 'AMERICAN INDIAN' OR ETHNICITY = 'ALASKA NATIVE'
#   AND AGE < 67;
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."ETHNICITY" = "AMERICAN INDIAN/ALASKA NATIVE" AND DEMOGRAPHIC."AGE" < "67"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM DEMOGRAPHIC
# WHERE ETHNICITY = 'AMERICAN INDIAN/ALASKA NATIVE FEDERALLY RECOGNIZED TRIBE'
#   AND AGE < 67;
# REAL:  ['(0,)']
# PRED:  ['(2,)']
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."ETHNICITY" = "BLACK/HAITIAN" AND DEMOGRAPHIC."AGE" < "68"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM DEMOGRAPHIC
# WHERE ETHNICITY = 'Black' OR ETHNICITY = 'Haitian'
#   AND AGE < 68;
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."ETHNICITY" = "BLACK/HAITIAN" AND DEMOGRAPHIC."AGE" < "68"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM DEMOGRAPHIC
# WHERE ETHNICITY = 'BLACK/AFRICAN AMERICAN'
#   AND AGE < 68;
# REAL:  ['(0,)']
# PRED:  ['(2,)']
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."ETHNICITY" = "HISPANIC/LATINO - PUERTO RICAN" AND DEMOGRAPHIC."DOB_YEAR" < "2107"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM DEMOGRAPHIC
# WHERE ETHNICITY = 'Hispanic/Latino' OR ETHNICITY = 'PuertoRican'
#   AND DOB_YEAR < 2107;
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."ETHNICITY" = "HISPANIC/LATINO - PUERTO RICAN" AND DEMOGRAPHIC."DOB_YEAR" < "2107"
# ```
# SQL PRED:  None
# REAL:  ['(0,)']
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC INNER JOIN DIAGNOSES on DEMOGRAPHIC.HADM_ID = DIAGNOSES.HADM_ID WHERE DEMOGRAPHIC."ETHNICITY" = "WHITE" AND DIAGNOSES."SHORT_TITLE" = "Hx of GI malignancy NEC"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM DEMOGRAPHIC d
# JOIN DIAGNOSES dg ON d.SUBJECT_ID = dg.SUBJECT_ID
# WHERE d.ETHNICITY = 'White' AND dg.ICD9_CODE = 'C1990' AND dg.SHORT_TITLE = 'Malignancy of the gastrointestinal tract (nec';
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC INNER JOIN DIAGNOSES on DEMOGRAPHIC.HADM_ID = DIAGNOSES.HADM_ID WHERE DEMOGRAPHIC."ETHNICITY" = "WHITE" AND DIAGNOSES."SHORT_TITLE" = "Hx of GI malignancy NEC"
# ```
# SQL PRED:  None
# REAL:  ['(0,)']
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC INNER JOIN DIAGNOSES on DEMOGRAPHIC.HADM_ID = DIAGNOSES.HADM_ID WHERE DEMOGRAPHIC."EXPIRE_FLAG" = "0" AND DIAGNOSES."SHORT_TITLE" = "Metabolic encephalopathy"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM DEMOGRAPHIC d
# JOIN DIAGNOSES dg ON d.SUBJECT_ID = dg.SUBJECT_ID AND dg.ICD9_CODE = '250.0'
# WHERE dg.SHORT_TITLE = 'Metabolic encephalopathy' AND d.EXPIRE_FLAG = 0;
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC INNER JOIN DIAGNOSES on DEMOGRAPHIC.HADM_ID = DIAGNOSES.HADM_ID WHERE DEMOGRAPHIC."EXPIRE_FLAG" = "0" AND DIAGNOSES."SHORT_TITLE" = "Metabolic encephalopathy"
# ```
# SQL PRED:  None
# REAL:  ['(0,)']
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."ADMISSION_LOCATION" = "TRSF WITHIN THIS FACILITY" AND DEMOGRAPHIC."AGE" < "59"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM DEMOGRAPHIC
# WHERE AGE < 59
# AND ADMISSION_TYPE = 'TRANSFER'
# AND EXPIRE_FLAG = 0;
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."ADMISSION_LOCATION" = "TRSF WITHIN THIS FACILITY" AND DEMOGRAPHIC."AGE" < "59"
# ```
# SQL PRED:  None
# REAL:  ['(0,)']
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."ADMISSION_LOCATION" = "TRANSFER FROM HOSP/EXTRAM" AND DEMOGRAPHIC."ADMITYEAR" < "2131"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM DEMOGRAPHIC
# WHERE ADMISSION_LOCATION = 'transfer from hosp' OR ADMISSION_LOCATION = 'extram'
#   AND ADMITYEAR < 2131;
# REAL:  ['(9,)']
# PRED:  ['(0,)']
# 0
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."ADMISSION_LOCATION" = "TRANSFER FROM HOSP/EXTRAM" AND DEMOGRAPHIC."ADMITYEAR" < "2131"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM DEMOGRAPHIC
# WHERE ADMISSION_LOCATION = 'TRANSFER FROM HOSP/EXTRAM'
# AND ADMITYEAR < 2131;
# REAL:  ['(9,)']
# PRED:  ['(9,)']
# 1
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."DISCHARGE_LOCATION" = "SHORT TERM HOSPITAL" AND DEMOGRAPHIC."ADMITYEAR" < "2182"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM DEMOGRAPHIC
# WHERE DISCHARGE_LOCATION = 'Short-term hospital'
#   AND ADMITTIME < '2182-01-01 00:00:00';
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."DISCHARGE_LOCATION" = "SHORT TERM HOSPITAL" AND DEMOGRAPHIC."ADMITYEAR" < "2182"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM DEMOGRAPHIC
# JOIN DISCHARGE_LOCATION ON DEMOGRAPHIC.SUBJECT_ID = DISCHARGE_LOCATION.SUBJECT_ID
# WHERE DISCHARGE_LOCATION.DSCHARGE_LOCATION = 'SNF'
# AND ADMITTIME < '2182-01-01 00:00:00'
# LIMIT 1;
# REAL:  ['(0,)']
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."DIAGNOSIS" = "GUILLAIN BARRE SYNDROME" AND DEMOGRAPHIC."DOB_YEAR" < "2109"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM DEMOGRAPHIC
# WHERE DOB_YEAR < 2109
#   AND DIAGNOSIS = 'Guillain Barre Syndrome'
#   AND EXPIRE_FLAG = 0;
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."DIAGNOSIS" = "GUILLAIN BARRE SYNDROME" AND DEMOGRAPHIC."DOB_YEAR" < "2109"
# ```
# SQL PRED:  None
# REAL:  ['(0,)']
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC INNER JOIN DIAGNOSES on DEMOGRAPHIC.HADM_ID = DIAGNOSES.HADM_ID WHERE DEMOGRAPHIC."AGE" < "51" AND DIAGNOSES."SHORT_TITLE" = "Preterm NEC 2500+g"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM DEMOGRAPHIC
# JOIN DIAGNOSES ON DEMOGRAPHIC.SUBJECT_ID = DIAGNOSES.SUBJECT_ID
# WHERE DEMOGRAPHIC.AGE < 51
# AND DIAGNOSES.ICD9_CODE = '2500-2504'  -- Assuming ICD-9 codes for preterm necrolysis
# AND DEMOGRAPHIC.EXPIRE_FLAG = 0;  -- Exclude deceased patients
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC INNER JOIN DIAGNOSES on DEMOGRAPHIC.HADM_ID = DIAGNOSES.HADM_ID WHERE DEMOGRAPHIC."AGE" < "51" AND DIAGNOSES."SHORT_TITLE" = "Preterm NEC 2500+g"
# ```
# SQL PRED:  None
# REAL:  ['(0,)']
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC INNER JOIN LAB on DEMOGRAPHIC.HADM_ID = LAB.HADM_ID WHERE DEMOGRAPHIC."AGE" < "30" AND LAB."FLAG" = "abnormal"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM DEMOGRAPHIC
# JOIN LAB ON DEMOGRAPHIC.SUBJECT_ID = LAB.SUBJECT_ID
# WHERE DEMOGRAPHIC.AGE < 30 AND LAB.FLAG = 'ABORMAL';
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC INNER JOIN LAB on DEMOGRAPHIC.HADM_ID = LAB.HADM_ID WHERE DEMOGRAPHIC."AGE" < "30" AND LAB."FLAG" = "abnormal"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM DEMOGRAPHIC
# JOIN LAB ON DEMOGRAPHIC.SUBJECT_ID = LAB.SUBJECT_ID
# JOIN DIAGNOSES ON DEMOGRAPHIC.HADM_ID = DIAGNOSES.HADM_ID
# WHERE DEMOGRAPHIC.AGE < 30
# AND LAB.FLAG = 'ABNORMAL'
# AND DEMOGRAPHIC.DOB_YEAR > (SELECT MAX(DOB_YEAR FROM DEMOGRAPHIC WHERE EXPIRE_FLAG = 1 OR DOB < (DATE('now') - INTERVAL 30 YEAR));
# REAL:  ['(0,)']
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC INNER JOIN LAB on DEMOGRAPHIC.HADM_ID = LAB.HADM_ID WHERE DEMOGRAPHIC."AGE" < "41" AND LAB."FLAG" = "delta"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM DEMOGRAPHIC
# JOIN LAB ON DEMOGRAPHIC.SUBJECT_ID = LAB.SUBJECT_ID
# WHERE DEMOGRAPHIC.AGE < 41
#   AND LAB.FLAG = 'abnormal';
# REAL:  ['(0,)']
# PRED:  ['(995,)']
# 0
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC INNER JOIN LAB on DEMOGRAPHIC.HADM_ID = LAB.HADM_ID WHERE DEMOGRAPHIC."AGE" < "41" AND LAB."FLAG" = "delta"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM DEMOGRAPHIC
# JOIN LAB ON DEMOGRAPHIC.SUBJECT_ID = LAB.SUBJECT_ID
# WHERE DEMOGRAPHIC.AGE < 41
#   AND LAB.FLAG = 'ABNORMAL'
#   AND LAB.CATEGORY = 'Hematology'
# ;
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC INNER JOIN LAB on DEMOGRAPHIC.HADM_ID = LAB.HADM_ID WHERE DEMOGRAPHIC."AGE" < "85" AND LAB."LABEL" = "Heparin, LMW"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM LAB
# JOIN DEMOGRAPHIC ON LAB.SUBJECT_ID = DEMOGRAPHIC.SUBJECT_ID
# WHERE DEMOGRAPHIC.AGE < 85
# AND LAB.LABEL = 'heparin,imw';
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC INNER JOIN LAB on DEMOGRAPHIC.HADM_ID = LAB.HADM_ID WHERE DEMOGRAPHIC."AGE" < "85" AND LAB."LABEL" = "Heparin, LMW"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM LAB
# WHERE SUBJECT_ID IS NOT NULL
#   AND AGE < 85
#   AND ITEMID = 'HEPARIN,IMW';
# REAL:  ['(0,)']
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC INNER JOIN LAB on DEMOGRAPHIC.HADM_ID = LAB.HADM_ID WHERE DEMOGRAPHIC."AGE" < "56" AND LAB."LABEL" = "Sodium, Whole Blood"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM DEMOGRAPHIC
# JOIN LAB ON DEMOGRAPHIC.SUBJECT_ID = LAB.SUBJECT_ID
# WHERE DEMOGRAPHIC.AGE < 56
# AND LAB.LABEL = 'Sodium'
# AND LAB.FLUID = 'Blood'
# AND LAB.CATEGORY = 'Hematology';
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC INNER JOIN LAB on DEMOGRAPHIC.HADM_ID = LAB.HADM_ID WHERE DEMOGRAPHIC."AGE" < "56" AND LAB."LABEL" = "Sodium, Whole Blood"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM LAB
# JOIN DEMOGRAPHIC ON LAB.SUBJECT_ID = DEMOGRAPHIC.SUBJECT_ID
# JOIN DEMOGRAPHIC ON DEMOGRAPHIC.SUBJECT_ID = LAB.SUBJECT_ID
# WHERE DEMOGRAPHIC.AGE < 56
# AND LAB.CATEGORY = 'Hematology'
# AND LAB.FLUID = 'Blood'
# AND LAB.LABEL = 'Sodium (WBC)'
# AND LAB.FLAG = 'ABNORMAL' OR LAB.FLAG = 'HIGH' OR LAB.FLAG = 'LOW';
# REAL:  ['(0,)']
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC INNER JOIN PROCEDURES on DEMOGRAPHIC.HADM_ID = PROCEDURES.HADM_ID WHERE DEMOGRAPHIC."ADMITYEAR" < "2187" AND PROCEDURES."LONG_TITLE" = "(Aorto)coronary bypass of one coronary artery"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM DEMOGRAPHIC
# JOIN PROCEDURES ON DEMOGRAPHIC.SUBJECT_ID = PROCEDURES.SUBJECT_ID
# WHERE DEMOGRAPHIC.ADMITYEAR < 2187
# AND DEMOGRAPHIC.ICD9_CODE = 'AOR-TOF'
# AND DEMOGRAPHIC.EXPIRE_FLAG = 0;
# REAL:  ['(0,)']
# PRED:  ["('error_pred',)"]
# 0
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC INNER JOIN PROCEDURES on DEMOGRAPHIC.HADM_ID = PROCEDURES.HADM_ID WHERE DEMOGRAPHIC."ADMITYEAR" < "2187" AND PROCEDURES."LONG_TITLE" = "(Aorto)coronary bypass of one coronary artery"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM DEMOGRAPHIC d
# JOIN PROCEDURES p ON d.SUBJECT_ID = p.SUBJECT_ID AND d.HADM_ID = p.HADM_ID
# WHERE d.ADMITTIME < '2187-01-01'
# AND p.ICD9_CODE IN ('36.6B4', '36.6B5', '36.6B6');
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC INNER JOIN DIAGNOSES on DEMOGRAPHIC.HADM_ID = DIAGNOSES.HADM_ID INNER JOIN PRESCRIPTIONS on DEMOGRAPHIC.HADM_ID = PRESCRIPTIONS.HADM_ID WHERE DIAGNOSES."SHORT_TITLE" = "Rec depr psych-psychotic" AND PRESCRIPTIONS."ROUTE" = "PO/NG"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM DIAGNOSES
# JOIN PRESCRIPTIONS ON DIAGNOSES.SUBJECT_ID = PRESCRIPTIONS.SUBJECT_ID
# JOIN PRESCRIPTIONS ON PRESCRIPTIONS.ICUSTAY_ID = PRESCRIPTIONS.ICUSTAY_ID
# WHERE DIAGNOSES.SHORT_TITLE ='rec depr psych-psychotic'
# AND PRESCRIPTIONS.ROUTE = 'PO/NG';
# REAL:  ['(0,)']
# PRED:  ["('error_pred',)"]
# 0
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC INNER JOIN DIAGNOSES on DEMOGRAPHIC.HADM_ID = DIAGNOSES.HADM_ID INNER JOIN PRESCRIPTIONS on DEMOGRAPHIC.HADM_ID = PRESCRIPTIONS.HADM_ID WHERE DIAGNOSES."SHORT_TITLE" = "Rec depr psych-psychotic" AND PRESCRIPTIONS."ROUTE" = "PO/NG"
# ```
# SQL PRED:  SELECT COUNT(*)
# FROM DIAGNOSES
# JOIN PRESCRIPTIONS ON DIAGNOSES.SUBJECT_ID = PRESCRIPTIONS.SUBJECT_ID
# WHERE DIAGNOSES.SHORT_TITLE = 'REC DEP PSYCH-PHOSCOTIC'
# AND PRESCRIPTIONS.ROUTE = 'PO/NG';
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC INNER JOIN DIAGNOSES on DEMOGRAPHIC.HADM_ID = DIAGNOSES.HADM_ID INNER JOIN LAB on DEMOGRAPHIC.HADM_ID = LAB.HADM_ID WHERE DIAGNOSES."LONG_TITLE" = "Personal history of colonic polyps" AND LAB."FLAG" = "abnormal"
# ```
# SQL PRED:  SELECT COUNT(DISTINCT d.subject_id)
# FROM DEMOGRAPHIC d
# JOIN DIAGNOSES d_diag ON d.subject_id = d_diag.subject_id
# JOIN LAB l ON d.subject_id = l.subject_id
# WHERE d_diag.ICD9_CODE = 'C01.0' AND l.FLAG = 'abnormal';
# REAL:  ['(0,)']
# PRED:  ['(0,)']
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT COUNT ( DISTINCT DEMOGRAPHIC."SUBJECT_ID" ) FROM DEMOGRAPHIC INNER JOIN DIAGNOSES on DEMOGRAPHIC.HADM_ID = DIAGNOSES.HADM_ID INNER JOIN LAB on DEMOGRAPHIC.HADM_ID = LAB.HADM_ID WHERE DIAGNOSES."LONG_TITLE" = "Personal history of colonic polyps" AND LAB."FLAG" = "abnormal"
# ```
# SQL PRED:  SELECT COUNT(DISTINCT SUBJECT_ID)
# FROM DEMOGRAPHIC
# JOIN DIAGNOSES ON DEMOGRAPHIC.SUBJECT_ID = DIAGNOSES.SUBJECT_ID
# JOIN LAB ON DEMOGRAPHIC.SUBJECT_ID = LAB.SUBJECT_ID
# WHERE DIAGNOSES.ICD9_CODE = '010.0'
#   AND LAB.FLAG = 'ABNORMAL';
# REAL:  ['(0,)']
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT DEMOGRAPHIC."INSURANCE",DEMOGRAPHIC."DIAGNOSIS" FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."SUBJECT_ID" = "2560"
# ```
# SQL PRED:  SELECT INSURANCE, DIAGNOSIS
# FROM DEMOGRAPHIC
# WHERE SUBJECT_ID = '2560';
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT DEMOGRAPHIC."INSURANCE",DEMOGRAPHIC."DIAGNOSIS" FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."SUBJECT_ID" = "2560"
# ```
# SQL PRED:  None
# REAL:  []
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT DEMOGRAPHIC."DOB",PROCEDURES."LONG_TITLE" FROM DEMOGRAPHIC INNER JOIN PROCEDURES on DEMOGRAPHIC.HADM_ID = PROCEDURES.HADM_ID WHERE DEMOGRAPHIC."SUBJECT_ID" = "81923"
# ```
# SQL PRED:  SELECT DOB, LONG_TITLE
# FROM DEMOGRAPHIC
# JOIN PROCEDURES ON DEMOGRAPHIC.SUBJECT_ID = PROCEDURES.SUBJECT_ID
# WHERE DEMOGRAPHIC.SUBJECT_ID = '81923';
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT DEMOGRAPHIC."DOB",PROCEDURES."LONG_TITLE" FROM DEMOGRAPHIC INNER JOIN PROCEDURES on DEMOGRAPHIC.HADM_ID = PROCEDURES.HADM_ID WHERE DEMOGRAPHIC."SUBJECT_ID" = "81923"
# ```
# SQL PRED:  None
# REAL:  []
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT DEMOGRAPHIC."LANGUAGE",DEMOGRAPHIC."DIAGNOSIS" FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."SUBJECT_ID" = "3343"
# ```
# SQL PRED:  SELECT LANGUAGE, DIAGNOSIS
# FROM DEMOGRAPHIC
# WHERE SUBJECT_ID = '3343';
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT DEMOGRAPHIC."LANGUAGE",DEMOGRAPHIC."DIAGNOSIS" FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."SUBJECT_ID" = "3343"
# ```
# SQL PRED:  None
# REAL:  []
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT DEMOGRAPHIC."ADMISSION_TYPE",DIAGNOSES."ICD9_CODE" FROM DEMOGRAPHIC INNER JOIN DIAGNOSES on DEMOGRAPHIC.HADM_ID = DIAGNOSES.HADM_ID WHERE DEMOGRAPHIC."SUBJECT_ID" = "62296"
# ```
# SQL PRED:  SELECT ADMISSION_TYPE, ICD9_CODE
# FROM DEMOGRAPHIC
# JOIN DIAGNOSES ON DEMOGRAPHIC.SUBJECT_ID = DIAGNOSES.SUBJECT_ID
# JOIN DIAGNOSES ON DEMOGRAPHIC.HADM_ID = DIAGNOSES.HADM_ID
# WHERE DEMOGRAPHIC.SUBJECT_ID = '62296';
# REAL:  []
# PRED:  ["('error_pred',)"]
# 0
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT DEMOGRAPHIC."ADMISSION_TYPE",DIAGNOSES."ICD9_CODE" FROM DEMOGRAPHIC INNER JOIN DIAGNOSES on DEMOGRAPHIC.HADM_ID = DIAGNOSES.HADM_ID WHERE DEMOGRAPHIC."SUBJECT_ID" = "62296"
# ```
# SQL PRED:  SELECT
#     ADMISSION_TYPE,
#     DIAGNOSES.ICD9_CODE
# FROM
#     DEMOGRAPHIC
#     JOIN DIAGNOSES ON DEMOGRAPHIC.SUBJECT_ID = DIAGNOSES.SUBJECT_ID
#     JOIN PROCEDURES ON DEMOGRAPHIC.SUBJECT_ID = PROCEDURES.SUBJECT_ID
# WHERE
#     DEMOGRAPHIC.SUBJECT_ID = '62296';
# REAL:  []
# PRED:  []
# 1
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT DEMOGRAPHIC."INSURANCE",DEMOGRAPHIC."DIAGNOSIS" FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."SUBJECT_ID" = "8990"
# ```
# SQL PRED:  SELECT DIAGNOSIS, INSURANCE
# FROM DEMOGRAPHIC
# WHERE SUBJECT_ID = '8990';
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT DEMOGRAPHIC."INSURANCE",DEMOGRAPHIC."DIAGNOSIS" FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."SUBJECT_ID" = "8990"
# ```
# SQL PRED:  None
# REAL:  []
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT DEMOGRAPHIC."MARITAL_STATUS",DEMOGRAPHIC."RELIGION" FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."SUBJECT_ID" = "74032"
# ```
# SQL PRED:  SELECT RELIGION
# FROM DEMOGRAPHIC
# WHERE SUBJECT_ID = '74032'
# AND MARITAL_STATUS = 'Married';
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT DEMOGRAPHIC."MARITAL_STATUS",DEMOGRAPHIC."RELIGION" FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."SUBJECT_ID" = "74032"
# ```
# SQL PRED:  None
# REAL:  []
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT DEMOGRAPHIC."ADMISSION_TYPE",DIAGNOSES."LONG_TITLE" FROM DEMOGRAPHIC INNER JOIN DIAGNOSES on DEMOGRAPHIC.HADM_ID = DIAGNOSES.HADM_ID WHERE DEMOGRAPHIC."SUBJECT_ID" = "74032"
# ```
# SQL PRED:  SELECT
#     ADMISSION_TYPE,
#     LONG_TITLE
# FROM
#     DIAGNOSES
# JOIN
#     DEMOGRAPHIC ON DEMOGRAPHIC.SUBJECT_ID = DIAGNOSES.SUBJECT_ID
# WHERE
#     DEMOGRAPHIC.SUBJECT_ID = '74032';
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT DEMOGRAPHIC."ADMISSION_TYPE",DIAGNOSES."LONG_TITLE" FROM DEMOGRAPHIC INNER JOIN DIAGNOSES on DEMOGRAPHIC.HADM_ID = DIAGNOSES.HADM_ID WHERE DEMOGRAPHIC."SUBJECT_ID" = "74032"
# ```
# SQL PRED:  SELECT
#     ADMISSION_TYPE AS ADMISSION_TYPE,
#     D.LONG_TITLE AS DIAGNOSIS_LONG_TITLE
# FROM DEMOGRAPHIC D
# JOIN DIAGNOSES D ON D.SUBJECT_ID = D.SUBJECT_ID AND D.HADM_ID = D.HADM_ID
# WHERE D.SUBJECT_ID = '74032';
# REAL:  []
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT DEMOGRAPHIC."ADMISSION_TYPE",PROCEDURES."ICD9_CODE" FROM DEMOGRAPHIC INNER JOIN PROCEDURES on DEMOGRAPHIC.HADM_ID = PROCEDURES.HADM_ID WHERE DEMOGRAPHIC."SUBJECT_ID" = "21796"
# ```
# SQL PRED:  SELECT
#     ADMISSION_TYPE,
#     ICD9_CODE
# FROM PROCEDURES
# JOIN DEMOGRAPHIC ON DEMOGRAPHIC.SUBJECT_ID = PROCEDURES.SUBJECT_ID
# WHERE DEMOGRAPHIC.SUBJECT_ID = '21796';
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT DEMOGRAPHIC."ADMISSION_TYPE",PROCEDURES."ICD9_CODE" FROM DEMOGRAPHIC INNER JOIN PROCEDURES on DEMOGRAPHIC.HADM_ID = PROCEDURES.HADM_ID WHERE DEMOGRAPHIC."SUBJECT_ID" = "21796"
# ```
# SQL PRED:  None
# REAL:  []
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT DEMOGRAPHIC."INSURANCE",DIAGNOSES."ICD9_CODE" FROM DEMOGRAPHIC INNER JOIN DIAGNOSES on DEMOGRAPHIC.HADM_ID = DIAGNOSES.HADM_ID WHERE DEMOGRAPHIC."SUBJECT_ID" = "21796"
# ```
# SQL PRED:  SELECT INSURANCE, ICD9_CODE
# FROM DEMOGRAPHIC
# JOIN DIAGNOSES ON DEMOGRAPHIC.SUBJECT_ID = DIAGNOSES.SUBJECT_ID
# WHERE DEMOGRAPHIC.SUBJECT_ID = '21796';
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT DEMOGRAPHIC."INSURANCE",DIAGNOSES."ICD9_CODE" FROM DEMOGRAPHIC INNER JOIN DIAGNOSES on DEMOGRAPHIC.HADM_ID = DIAGNOSES.HADM_ID WHERE DEMOGRAPHIC."SUBJECT_ID" = "21796"
# ```
# SQL PRED:  None
# REAL:  []
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT DEMOGRAPHIC."ETHNICITY",DEMOGRAPHIC."DIAGNOSIS" FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."SUBJECT_ID" = "3623"
# ```
# SQL PRED:  SELECT ETHNICITY, DIAGNOSIS
# FROM DEMOGRAPHIC
# WHERE SUBJECT_ID = '3623';
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT DEMOGRAPHIC."ETHNICITY",DEMOGRAPHIC."DIAGNOSIS" FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."SUBJECT_ID" = "3623"
# ```
# SQL PRED:  None
# REAL:  []
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT DEMOGRAPHIC."EXPIRE_FLAG",PROCEDURES."SHORT_TITLE" FROM DEMOGRAPHIC INNER JOIN PROCEDURES on DEMOGRAPHIC.HADM_ID = PROCEDURES.HADM_ID WHERE DEMOGRAPHIC."SUBJECT_ID" = "3623"
# ```
# SQL PRED:  SELECT
#     CASE WHEN EXPIRE_FLAG = 1 THEN 'Deceased' ELSE 'Alive' END AS Death_Status,
#     ICD9_CODE AS Procedure_Code
# FROM DEMOGRAPHIC
# JOIN PROCEDURES ON DEMOGRAPHIC.SUBJECT_ID = PROCEDURES.SUBJECT_ID
# WHERE DEMOGRAPHIC.SUBJECT_ID = '3623';
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT DEMOGRAPHIC."EXPIRE_FLAG",PROCEDURES."SHORT_TITLE" FROM DEMOGRAPHIC INNER JOIN PROCEDURES on DEMOGRAPHIC.HADM_ID = PROCEDURES.HADM_ID WHERE DEMOGRAPHIC."SUBJECT_ID" = "3623"
# ```
# SQL PRED:  None
# REAL:  []
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT PROCEDURES."ICD9_CODE",PRESCRIPTIONS."DRUG_TYPE" FROM PROCEDURES INNER JOIN PRESCRIPTIONS on PROCEDURES.HADM_ID = PRESCRIPTIONS.HADM_ID WHERE PROCEDURES."SUBJECT_ID" = "52012"
# ```
# SQL PRED:  SELECT PROCEDURES.ICD9_CODE, PRESCRIPTIONS.DRUG_TYPE
# FROM PROCEDURES
# JOIN PRESCRIPTIONS ON PROCEDURES.SUBJECT_ID = PRESCRIPTIONS.SUBJECT_ID
# WHERE PROCEDURES.SUBJECT_ID = '52012';
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT PROCEDURES."ICD9_CODE",PRESCRIPTIONS."DRUG_TYPE" FROM PROCEDURES INNER JOIN PRESCRIPTIONS on PROCEDURES.HADM_ID = PRESCRIPTIONS.HADM_ID WHERE PROCEDURES."SUBJECT_ID" = "52012"
# ```
# SQL PRED:  SELECT D.ICD9_CODE, P.DRUG_TYPE
# FROM DEMOGRAPHIC D
# JOIN PRESCRIPTIONS P ON D.SUBJECT_ID = P.SUBJECT_ID
# WHERE D.SUBJECT_ID = '52012';
# REAL:  []
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT PROCEDURES."SHORT_TITLE" FROM PROCEDURES WHERE PROCEDURES."SUBJECT_ID" = "18480"
# ```
# SQL PRED:  SELECT ICD9_CODE FROM PROCEDURES WHERE SUBJECT_ID = '18480';
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT PROCEDURES."SHORT_TITLE" FROM PROCEDURES WHERE PROCEDURES."SUBJECT_ID" = "18480"
# ```
# SQL PRED:  None
# REAL:  []
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT DEMOGRAPHIC."ADMISSION_TYPE",LAB."LABEL" FROM DEMOGRAPHIC INNER JOIN LAB on DEMOGRAPHIC.HADM_ID = LAB.HADM_ID WHERE DEMOGRAPHIC."SUBJECT_ID" = "18480"
# ```
# SQL PRED:  SELECT
#     ADMISSION_TYPE,
#     LAB.LABEL
# FROM DEMOGRAPHIC
# JOIN LAB ON DEMOGRAPHIC.SUBJECT_ID = LAB.SUBJECT_ID
# WHERE DEMOGRAPHIC.SUBJECT_ID = '18480';
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT DEMOGRAPHIC."ADMISSION_TYPE",LAB."LABEL" FROM DEMOGRAPHIC INNER JOIN LAB on DEMOGRAPHIC.HADM_ID = LAB.HADM_ID WHERE DEMOGRAPHIC."SUBJECT_ID" = "18480"
# ```
# SQL PRED:  None
# REAL:  []
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT DEMOGRAPHIC."DIAGNOSIS",PROCEDURES."ICD9_CODE" FROM DEMOGRAPHIC INNER JOIN PROCEDURES on DEMOGRAPHIC.HADM_ID = PROCEDURES.HADM_ID WHERE DEMOGRAPHIC."SUBJECT_ID" = "18480"
# ```
# SQL PRED:  SELECT DIAGNOSIS, ICD9_CODE
# FROM DEMOGRAPHIC
# JOIN PROCEDURES ON DEMOGRAPHIC.SUBJECT_ID = PROCEDURES.SUBJECT_ID
# WHERE DEMOGRAPHIC.SUBJECT_ID = '18480';
# REAL:  []
# PRED:  []
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT DEMOGRAPHIC."DIAGNOSIS",PROCEDURES."ICD9_CODE" FROM DEMOGRAPHIC INNER JOIN PROCEDURES on DEMOGRAPHIC.HADM_ID = PROCEDURES.HADM_ID WHERE DEMOGRAPHIC."SUBJECT_ID" = "18480"
# ```
# SQL PRED:  None
# REAL:  []
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# ...
# ORDER BY MIN_AGE ASC;
# REAL:  ['(17,)']
# PRED:  ['(None,)']
# 0
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT MIN ( DEMOGRAPHIC."AGE" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."GENDER" = "F" AND DEMOGRAPHIC."ETHNICITY" = "WHITE"
# ```
# SQL PRED:  SELECT MIN(AGE) AS MIN_AGE
# FROM DEMOGRAPHIC
# WHERE GENDER = 'F' AND ETHNICITY = 'WHITE';
# REAL:  ['(17,)']
# PRED:  ['(17,)']
# 1
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT MAX ( DEMOGRAPHIC."AGE" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."GENDER" = "M" AND DEMOGRAPHIC."DISCHARGE_LOCATION" = "SNF"
# ```
# SQL PRED:  SELECT MAX(AGE)
# FROM DEMOGRAPHIC
# WHERE GENDER = 'M'
# AND DISCHARGE_LOCATION = 'SNF';
# REAL:  ['(89,)']
# PRED:  ['(89,)']
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT MAX ( DEMOGRAPHIC."AGE" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."GENDER" = "M" AND DEMOGRAPHIC."DISCHARGE_LOCATION" = "SNF"
# ```
# SQL PRED:  SELECT MAX(AGE)
# FROM DEMOGRAPHIC
# JOIN DISCHARGE_LOCATION ON DEMOGRAPHIC.SUBJECT_ID = DISCHARGE_LOCATION.SUBJECT_ID
# WHERE
#     GENDER = 'M'
#     AND DISCHARGE_LOCATION.DSCHARGE_LOCATION = 'SNF';
# REAL:  ['(89,)']
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT AVG ( DEMOGRAPHIC."AGE" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."LANGUAGE" = "SPAN" AND DEMOGRAPHIC."DIAGNOSIS" = "OVERDOSE"
# ```
# SQL PRED:  SELECT AVG(AGE)
# FROM DEMOGRAPHIC
# WHERE LANGUAGE = 'Spanish'
#   AND DIAGNOSIS = 'overdose';
# REAL:  ['(None,)']
# PRED:  ['(None,)']
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT AVG ( DEMOGRAPHIC."AGE" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."LANGUAGE" = "SPAN" AND DEMOGRAPHIC."DIAGNOSIS" = "OVERDOSE"
# ```
# SQL PRED:  SELECT AVG(AGE) AS AVG_AGE
# FROM DEMOGRAPHIC
# JOIN DIAGNOSES ON DEMOGRAPHIC.HADM_ID = DIAGNOSES.HADM_ID
# WHERE LANGUAGE = 'SPAN' -- Spanish speaking patients
#   AND ICD9_CODE = 'X42.1' -- Overdose as the primary disease (ICD-9 code)
# GROUP BY DEMOGRAPHIC.SUBJECT_ID;
# REAL:  ['(None,)']
# PRED:  []
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT AVG ( DEMOGRAPHIC."AGE" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."ADMISSION_TYPE" = "URGENT" AND DEMOGRAPHIC."INSURANCE" = "Self Pay"
# ```
# SQL PRED:  SELECT AVG(AGE)
# FROM DEMOGRAPHIC
# WHERE INSURANCE = 'Self Pay'
#   AND ADMISSION_TYPE = 'Urgent'
#   AND EXPIRE_FLAG = 0;
# REAL:  ['(None,)']
# PRED:  ['(None,)']
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT AVG ( DEMOGRAPHIC."AGE" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."ADMISSION_TYPE" = "URGENT" AND DEMOGRAPHIC."INSURANCE" = "Self Pay"
# ```
# SQL PRED:  SELECT AVG(AGE)
# FROM DEMOGRAPHIC
# JOIN INSURANCE ON DEMOGRAPHIC.INSURANCE = INSURANCE.TYPE
# JOIN PROCEDURES ON DEMOGRAPHIC.HADM_ID = PROCEDURES.HADM_ID
# WHERE INSURANCE.TYPE = 'PRIVATE'
#   AND ADMISSION_TYPE = 'URGENT';
# REAL:  ['(None,)']
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT MIN ( DEMOGRAPHIC."AGE" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."ADMISSION_TYPE" = "EMERGENCY" AND DEMOGRAPHIC."ADMITYEAR" >= "2173"
# ```
# SQL PRED:  SELECT MIN(AGE) AS MIN_AGE
# FROM DEMOGRAPHIC
# WHERE ADMISSION_TYPE = 'Emergency'
# AND ADMITYEAR >= 2173;
# REAL:  ['(17,)']
# PRED:  ['(None,)']
# 0
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT MIN ( DEMOGRAPHIC."AGE" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."ADMISSION_TYPE" = "EMERGENCY" AND DEMOGRAPHIC."ADMITYEAR" >= "2173"
# ```
# SQL PRED:  SELECT MIN(AGE) AS MIN_AGE
# FROM DEMOGRAPHIC
# WHERE ADMISSION_TYPE = 'EMERGENCY'
# AND ADMITYEAR >= 2173;
# REAL:  ['(17,)']
# PRED:  ['(17,)']
# 1
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT MIN ( DEMOGRAPHIC."AGE" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."ADMISSION_TYPE" = "EMERGENCY" AND DEMOGRAPHIC."ADMITYEAR" >= "2175"
# ```
# SQL PRED:  SELECT MIN(AGE) AS MIN_AGE
# FROM DEMOGRAPHIC
# WHERE ADMISSION_TYPE = 'Emergency'
#   AND DOB_YEAR >= 2175;
# REAL:  ['(17,)']
# PRED:  ['(None,)']
# 0
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT MIN ( DEMOGRAPHIC."AGE" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."ADMISSION_TYPE" = "EMERGENCY" AND DEMOGRAPHIC."ADMITYEAR" >= "2175"
# ```
# SQL PRED:  SELECT MIN(AGE) AS MIN_AGE
# FROM DEMOGRAPHIC
# WHERE ADMISSION_TYPE = 'EMERGENCY'
#   AND DOB_YEAR >= 2175;
# REAL:  ['(17,)']
# PRED:  ['(17,)']
# 1
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT MIN ( DEMOGRAPHIC."AGE" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."INSURANCE" = "Medicaid" AND DEMOGRAPHIC."DIAGNOSIS" = "CEREBRAL ANEURYSM/SDA"
# ```
# SQL PRED:  SELECT MIN(AGE) AS MIN_AGE
# FROM DEMOGRAPHIC
# WHERE INSURANCE = 'MEDICARE' AND DIAGNOSIS = 'Cerebral Aneurysm/SDA'
# ORDER BY MIN_AGE ASC;
# REAL:  ['(None,)']
# PRED:  ['(None,)']
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT MIN ( DEMOGRAPHIC."AGE" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."INSURANCE" = "Medicaid" AND DEMOGRAPHIC."DIAGNOSIS" = "CEREBRAL ANEURYSM/SDA"
# ```
# SQL PRED:  SELECT MIN(AGE) AS MIN_AGE
# FROM DEMOGRAPHIC
# JOIN DIAGNOSES ON DEMOGRAPHIC.HADM_ID = DIAGNOSES.HADM_ID
# JOIN LAB ON DEMOGRAPHIC.HADM_ID = LAB.HADM_ID
# JOIN DIAGNOSES ON LAB.ICD9_CODE = DIAGNOSES.ICD9_CODE
# WHERE INSURANCE = 'MEDICARE'
#   AND DIAGNOSES.SHORT_TITLE = 'CEBRAEL ANEURYSM/SDA'
#   AND DIAGNOSES.LONG_TITLE LIKE '% PRIMARY DEISEASE%';
# REAL:  ['(None,)']
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT MAX ( DEMOGRAPHIC."AGE" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."INSURANCE" = "Self Pay" AND DEMOGRAPHIC."DIAGNOSIS" = "COLANGITIS"
# ```
# SQL PRED:  SELECT MAX(AGE)
# FROM DEMOGRAPHIC
# WHERE INSURANCE = 'Self Pay'
#   AND DIAGNOSIS = 'colangitis';
# REAL:  ['(None,)']
# PRED:  ['(None,)']
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT MAX ( DEMOGRAPHIC."AGE" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."INSURANCE" = "Self Pay" AND DEMOGRAPHIC."DIAGNOSIS" = "COLANGITIS"
# ```
# SQL PRED:  None
# REAL:  ['(None,)']
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT AVG ( DEMOGRAPHIC."AGE" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."INSURANCE" = "Government" AND DEMOGRAPHIC."DAYS_STAY" = "1"
# ```
# SQL PRED:  SELECT AVG(AGE)
# FROM DEMOGRAPHIC
# WHERE INSURANCE = 'GOVERNMENT'
# AND DAYS_STAY = 1;
# REAL:  ['(None,)']
# PRED:  ['(None,)']
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT AVG ( DEMOGRAPHIC."AGE" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."INSURANCE" = "Government" AND DEMOGRAPHIC."DAYS_STAY" = "1"
# ```
# SQL PRED:  SELECT AVG(AGE)
# FROM DEMOGRAPHIC
# JOIN INSURANCE ON DEMOGRAPHIC.INSURANCE = INSURANCE.TYPE
# JOIN ADMISSION_TYPE ON ADMISSION_TYPE = 'GOVERNMENT'
# JOIN DEMOGRAPHIC ON DEMOGRAPHIC.HADM_ID = ADMISSION_TYPE.HADM_ID
# WHERE INSURANCE.TYPE = 'GOVERNMENT'
# AND DAYS_STAY = 1;
# REAL:  ['(None,)']
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT AVG ( DEMOGRAPHIC."AGE" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."ETHNICITY" = "WHITE" AND DEMOGRAPHIC."DAYS_STAY" = "2"
# ```
# SQL PRED:  SELECT AVG(AGE)
# FROM DEMOGRAPHIC
# WHERE ETHNICITY = 'White' AND INSURANCE = 'Not specified' AND DAYS_STAY = 2;
# REAL:  ['(72.4,)']
# PRED:  ['(None,)']
# 0
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT AVG ( DEMOGRAPHIC."AGE" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."ETHNICITY" = "WHITE" AND DEMOGRAPHIC."DAYS_STAY" = "2"
# ```
# SQL PRED:  SELECT AVG(AGE)
# FROM DEMOGRAPHIC
# WHERE ETHNICITY = 'WHITE'
#   AND DAYS_STAY = 2;
# REAL:  ['(72.4,)']
# PRED:  ['(72.4,)']
# 1
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT AVG ( DEMOGRAPHIC."AGE" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."DISCHARGE_LOCATION" = "HOME HEALTH CARE" AND DEMOGRAPHIC."DIAGNOSIS" = "GASTROINTESTINAL BLEED"
# ```
# SQL PRED:  SELECT AVG(AGE)
# FROM DEMOGRAPHIC
# WHERE DISCHARGE_LOCATION = 'home'
#   AND DIAGNOSIS = 'primary disease gastrointestinal bleed';
# REAL:  ['(None,)']
# PRED:  ['(None,)']
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT AVG ( DEMOGRAPHIC."AGE" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."DISCHARGE_LOCATION" = "HOME HEALTH CARE" AND DEMOGRAPHIC."DIAGNOSIS" = "GASTROINTESTINAL BLEED"
# ```
# SQL PRED:  None
# REAL:  ['(None,)']
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT AVG ( DEMOGRAPHIC."AGE" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."DIAGNOSIS" = "BOWEL OBSTRUCTION" AND DEMOGRAPHIC."AGE" >= "71"
# ```
# SQL PRED:  SELECT AVG(AGE)
# FROM DEMOGRAPHIC
# WHERE DIAGNOSIS = 'Bowel obstruction' AND AGE >= 71;
# REAL:  ['(None,)']
# PRED:  ['(None,)']
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT AVG ( DEMOGRAPHIC."AGE" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."DIAGNOSIS" = "BOWEL OBSTRUCTION" AND DEMOGRAPHIC."AGE" >= "71"
# ```
# SQL PRED:  None
# REAL:  ['(None,)']
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT MIN ( DEMOGRAPHIC."AGE" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."DIAGNOSIS" = "GANGRENE" AND DEMOGRAPHIC."DAYS_STAY" = "27"
# ```
# SQL PRED:  SELECT MIN(AGE) AS MIN_AGE
# FROM DEMOGRAPHIC
# WHERE DAYS_STAY = 27
#   AND DIAGNOSIS = 'gangrene'
#   AND EXPIRE_FLAG = 0;
# REAL:  ['(None,)']
# PRED:  ['(None,)']
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT MIN ( DEMOGRAPHIC."AGE" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."DIAGNOSIS" = "GANGRENE" AND DEMOGRAPHIC."DAYS_STAY" = "27"
# ```
# SQL PRED:  SELECT MIN(AGE) AS MIN_AGE
# FROM DEMOGRAPHIC
# JOIN DIAGNOSES ON DEMOGRAPHIC.SUBJECT_ID = DIAGNOSES.SUBJECT_ID
# JOIN PROCEDURES ON DEMOGRAPHIC.SUBJECT_ID = PROCEDURES.SUBJECT_ID
# WHERE DEMOGRAPHIC.DAYS_STAY = 27
# AND DIAGNOSES.ICD9_CODE = '36.1'  -- Gangrene is classified under ICD-9 code 36.1
# GROUP BY DEMOGRAPHIC.SUBJECT_ID;
# REAL:  ['(None,)']
# PRED:  []
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT MAX ( DEMOGRAPHIC."AGE" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."DIAGNOSIS" = "ABDOMINAL PAIN" AND DEMOGRAPHIC."DAYS_STAY" = "43"
# ```
# SQL PRED:  SELECT MAX(AGE)
# FROM DEMOGRAPHIC
# WHERE
#     DIAGNOSIS = 'abdominal pain primary disease'
#     AND DAYS_STAY = 43;
# REAL:  ['(None,)']
# PRED:  ['(None,)']
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT MAX ( DEMOGRAPHIC."AGE" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."DIAGNOSIS" = "ABDOMINAL PAIN" AND DEMOGRAPHIC."DAYS_STAY" = "43"
# ```
# SQL PRED:  SELECT MAX(AGE)
# FROM DEMOGRAPHIC
# JOIN DIAGNOSES ON DEMOGRAPHIC.SUBJECT_ID = DIAGNOSES.SUBJECT_ID
# JOIN PROCEDURES ON DEMOGRAPHIC.SUBJECT_ID = PROCEDURES.SUBJECT_ID
# WHERE
#     DEMOGRAPHIC.ADMIT_TYPE = 'EMERGENCY' OR DEMOGRAPHIC.ADMIT_TYPE = 'URGENT' OR DEMOGRAPHIC.ADMIT_TYPE = 'ELECTIVE'
#     AND DIAGNOSES.ICD9_CODE = 'C18.0'  -- Primary disease: abdominal pain (C18.0 is the ICD-9 code for primary abdominal pain)
#     AND DEMOGRAPHIC.DAYS_STAY = 43;
# REAL:  ['(None,)']
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT MIN ( DEMOGRAPHIC."AGE" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."DIAGNOSIS" = "TRANSIENT ISCHEMIC ATTACK" AND DEMOGRAPHIC."DOB_YEAR" > "2095"
# ```
# SQL PRED:  SELECT MIN(AGE) AS MIN_AGE
# FROM DEMOGRAPHIC
# WHERE DOB < '2095-01-01' AND DIAGNOSIS = 'Transient Ischemic Attack';
# REAL:  ['(None,)']
# PRED:  ['(None,)']
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT MIN ( DEMOGRAPHIC."AGE" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."DIAGNOSIS" = "TRANSIENT ISCHEMIC ATTACK" AND DEMOGRAPHIC."DOB_YEAR" > "2095"
# ```
# SQL PRED:  None
# REAL:  ['(None,)']
# PRED:  ["('error_pred',)"]
# 0
# ====================================================================================================
# ====================================================================================================
# V2 - ACC:
# SQL REAL:  ```sql
# SELECT MAX ( DEMOGRAPHIC."AGE" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."DAYS_STAY" = "20" AND DEMOGRAPHIC."DOD_YEAR" < "2131.0"
# ```
# SQL PRED:  SELECT MAX(AGE)
# FROM DEMOGRAPHIC
# WHERE DAYS_STAY = 20
#   AND EXPIRE_FLAG = 1
#   AND DOD_YEAR < 2131;
# REAL:  ['(None,)']
# PRED:  ['(None,)']
# 1
# ----------------------------------------------------------------------------------------------------
# V3 - Accuracy:
# SQL REAL:  ```sql
# SELECT MAX ( DEMOGRAPHIC."AGE" ) FROM DEMOGRAPHIC WHERE DEMOGRAPHIC."DAYS_STAY" = "20" AND DEMOGRAPHIC."DOD_YEAR" < "2131.0"
# ```
# SQL PRED:  SELECT MAX(AGE)
# FROM DEMOGRAPHIC
# WHERE DAYS_STAY >= 20
# AND EXPIRE_FLAG = 1
# AND DOD_YEAR < 2131;
# REAL:  ['(None,)']
# PRED:  ['(76,)']
# 0
# ====================================================================================================
# ====================================================================================================
# 390

# %% [markdown]
# ## convert mimicall database into new database whose string value convert to lower case

# %%
import sqlite3
import os

# Paths to your databases
src_db = '/localhome/local-hndo/hndo_eval/model_evaluation/databases/mimic_all.db'
dst_db = '/localhome/local-hndo/hndo_eval/model_evaluation/databases/mimic_all_lower.db'

# Remove destination DB if it exists
if os.path.exists(dst_db):
    os.remove(dst_db)

# Connect to source and destination databases
src_conn = sqlite3.connect(src_db)
dst_conn = sqlite3.connect(dst_db)

src_cur = src_conn.cursor()
dst_cur = dst_conn.cursor()

# Get all table names
src_cur.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = [row[0] for row in src_cur.fetchall()]

for table in tables:
    # Get table schema
    src_cur.execute(f"SELECT sql FROM sqlite_master WHERE type='table' AND name='{table}';")
    create_table_sql = src_cur.fetchone()[0]
    dst_cur.execute(create_table_sql)

    # Get column info
    src_cur.execute(f"PRAGMA table_info({table});")
    columns_info = src_cur.fetchall()
    columns = [col[1] for col in columns_info]
    types = [col[2].upper() for col in columns_info]

    # Select all data
    src_cur.execute(f"SELECT * FROM {table};")
    rows = src_cur.fetchall()

    # Prepare insert statement
    placeholders = ','.join(['?'] * len(columns))
    insert_sql = f"INSERT INTO {table} ({', '.join(columns)}) VALUES ({placeholders})"

    # Convert text columns to lowercase
    new_rows = []
    for row in rows:
        new_row = []
        for value, col_type in zip(row, types):
            if col_type == 'TEXT' and value is not None:
                new_row.append(value.lower())
            else:
                new_row.append(value)
        new_rows.append(tuple(new_row))

    # Insert into new database
    dst_cur.executemany(insert_sql, new_rows)
    dst_conn.commit()

# Close connections
src_conn.close()
dst_conn.close()

print("All string values have been converted to lowercase and saved to mimic_all_lower.db")
# Out:
# All string values have been converted to lowercase and saved to mimic_all_lower.db
