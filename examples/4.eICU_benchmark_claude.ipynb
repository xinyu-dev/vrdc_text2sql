# %% [markdown]
# # eICU benchmarking with Claude

# %%
from dotenv import load_dotenv
import os
load_dotenv()

from openai import OpenAI
from loguru import logger
import sys
import json
sys.path.append(os.path.abspath(os.path.join('..', 'model_evaluation')))

# %% [markdown]
# # Set up dataset

# %%
# input test set directory
test_data_dir = "../model_evaluation/dataset/test"
test_data_fp = os.path.join(test_data_dir, "test_ehrsql_eicu_data_benchmark.json")

# try loading the test set
with open(test_data_fp, "r") as f:
    test_set = json.load(f)

print("Size of test set:", len(test_set))

print("Example of a test set item:")
print(json.dumps(test_set[0], indent=4))
# Out:
# Size of test set: 1792
# Example of a test set item:
# {
#     "index": 1,
#     "system": "Based on DDL statements, instructions, and the current date, generate a SQL query in the following sqlite to answer the question.\n If the question cannot be answered using the available tables and columns in the DDL (i.e., it is out of scope), return only: None.\nToday is 2105-12-31 23:59:00\nDDL statements:\nDROP TABLE IF EXISTS patient;\nCREATE TABLE patient    -- store patient demographics and admission information\n(\n    uniquepid VARCHAR(10) NOT NULL, -- Unique patient identifier across the system\n    patienthealthsystemstayid INT NOT NULL, -- unique identifier for a single ICU stay of a patient.\n    patientunitstayid INT NOT NULL PRIMARY KEY, -- Unique ID for the patient's ICU stay\n    gender VARCHAR(25) NOT NULL, -- Gender of the patient (\"female\" or \"male\") (lowercase)\n    age VARCHAR(10) NOT NULL, -- Age at admission (can be in years or an age category)\n    ethnicity VARCHAR(50), -- Ethnicity of the patient (e.g: \"caucasian\", \"native american\", \"hispanic\", \"african american\", \"other/unknown\", \"asian\" or null) (lowercase)\n    hospitalid INT NOT NULL, -- ID of the hospital\n    wardid INT NOT NULL, -- ID of the hospital ward/unit\n    admissionheight NUMERIC(10,2), -- Patient's height on admission (in cm)\n    admissionweight NUMERIC(10,2), -- Weight on admission (in kg)\n    dischargeweight NUMERIC(10,2), -- Weight at discharge (in kg)\n    hospitaladmittime TIMESTAMP(0) NOT NULL, -- Time patient was admitted to hospital\n    hospitaladmitsource VARCHAR(30) NOT NULL, -- Source of hospital admission (e.g., \"operating room\", \"floor\", \"other hospital\", \"emergency department\", \"direct admit\", \"step-down unit (sdu)\", \"acute care/floor\", \"recovery room\", \"icu to sdu\", \"other icu\" or \"pacu\") (lowercase)\n    unitadmittime TIMESTAMP(0) NOT NULL, -- Time of ICU admission\n    unitdischargetime TIMESTAMP(0), -- time of discharge from the ICU unit\n    hospitaldischargetime TIMESTAMP(0), -- Time of hospital discharge\n    hospitaldischargestatus VARCHAR(10) -- Discharge status (e.g., \"alive\", \"expired\" or null)\n);\n\nDROP TABLE IF EXISTS diagnosis;\nCREATE TABLE diagnosis  -- store diagnoses assigned during ICU stay\n(\n    diagnosisid INT NOT NULL PRIMARY KEY, -- Unique diagnosis record ID\n    patientunitstayid INT NOT NULL, -- ICU stay ID (FK to patient)\n    diagnosisname VARCHAR(200) NOT NULL, -- Full name of diagnosis (lowercase)\n    diagnosistime TIMESTAMP(0) NOT NULL, -- Time diagnosis was recorded\n    icd9code VARCHAR(100), -- ICD-9 code of the diagnosis\n    FOREIGN KEY(patientunitstayid) REFERENCES patient(patientunitstayid)\n);\n\nDROP TABLE IF EXISTS treatment;\nCREATE TABLE treatment  -- store treatments administered during ICU stay\n(\n    treatmentid INT NOT NULL PRIMARY KEY, -- Unique treatment record ID\n    patientunitstayid INT NOT NULL, -- ICU stay ID (FK to patient)\n    treatmentname VARCHAR(200) NOT NULL, -- Name of the treatment administered (lowercase)\n    treatmenttime TIMESTAMP(0) NOT NULL, -- Time the treatment was given\n    FOREIGN KEY(patientunitstayid) REFERENCES patient(patientunitstayid)\n);\n\nDROP TABLE IF EXISTS lab;\nCREATE TABLE lab  -- store lab test results\n(\n    labid INT NOT NULL PRIMARY KEY, -- Unique lab test result ID\n    patientunitstayid INT NOT NULL, -- ICU stay ID (FK to patient)\n    labname VARCHAR(256) NOT NULL, -- Name of the lab test (lowercase)\n    labresult NUMERIC(11,4) NOT NULL, -- Result value\n    labresulttime TIMESTAMP(0) NOT NULL, -- Time when the lab result was recorded\n    FOREIGN KEY(patientunitstayid) REFERENCES patient(patientunitstayid)\n);\n\nDROP TABLE IF EXISTS medication;\nCREATE TABLE medication  -- store medication administration records\n(\n    medicationid INT NOT NULL PRIMARY KEY, -- Unique medication record ID\n    patientunitstayid INT NOT NULL, -- ICU stay ID (FK to patient)\n    drugname VARCHAR(220) NOT NULL, -- Name of the medication (lowercase)\n    dosage VARCHAR(60) NOT ...
#     "user": "tell me the method of dextrose 5% in water (d5w) iv : 1000 ml bag intake?",
#     "real": "select distinct medication.routeadmin from medication where medication.drugname = 'dextrose 5% in water (d5w) iv : 1000 ml bag';"
# }

# %% [markdown]
# # Set up client

# %%
import asyncio
from openai import AsyncOpenAI
import json
from loguru import logger

# Initialize the AsyncOpenAI client
async_client = AsyncOpenAI(
    api_key=os.environ['BEDROCK_OPENAI_API_KEY'],
    base_url=os.environ['BEDROCK_OPENAI_BASE_URL']
)

# %%
from utils import postprocess_sql_query_from_markdown

async def get_prediction(
    record: dict, 
    reasoning_effort:[None, "low", "medium", "high"] = None, 
    model="us.anthropic.claude-3-7-sonnet-20250219-v1:0"
    
    ) -> str:
    """
    Generates a SQL query for a given record asynchronously
    Args:
        record: a dictionary of Q&A pairs
    Returns:
        A dictionary containing the input, predict, and real fields
    """
    index = record['index']
    system = record['system']
    user = record['user']
    real = record['real']

    prompt_chat_template = [
        {
            "role": "system",
            "content": f"{system}",
        },
        {
            "role": "user",
            "content": f"{user}"
        }
    ]

    try:
        if reasoning_effort is None:
            response = await async_client.chat.completions.create(
                model=model,
                messages=prompt_chat_template,
                max_completion_tokens=512, # if no reasoning, keep at 512 same as Mistral
            )
        else:
            response = await async_client.chat.completions.create(
                model=model,
                messages=prompt_chat_template,
                max_completion_tokens=1024*2, # With reasnoning minimum is 1024. and must be greater than prompt
                reasoning_effort=reasoning_effort,
            )

        generated_sql = response.choices[0].message.content
        prediction = postprocess_sql_query_from_markdown(generated_sql)
        logger.info(f"Generated SQL for index {index}: {prediction}") 

        return {
            "index": index,
            "input": user, # user query
            "predict": prediction,  # model predicted SQL
            "real": real # ground truth SQL
        }
        
    except Exception as e:
        logger.error(f"An error occurred for index {record.get('index', 'N/A')}: {e}")
        return f"Error: {e}"

# %%
async def run_predictions_async(test_fp: str, output_fp: str, reasoning_effort: [None, "low", "medium", "high"] = None):
    """
    Loads a test set and runs predictions asynchronously.
    """
    # Path to the mini test set
    with open(test_fp, "r") as f:
        test_data = json.load(f)
    
    # chunk the data into 5 items at a time to avoid rate limit
    chunk_size = 5
    results = []

    for i in range(0, len(test_data), chunk_size):
        logger.info(f"Processing chunk {i} to {i+chunk_size-1}")
        chunk = test_data[i:i+chunk_size]
        tasks = [get_prediction(record = record, reasoning_effort=reasoning_effort) for record in chunk]
        
        logger.info(f"Sending {len(tasks)} requests to the vLLM server...")
        predictions = await asyncio.gather(*tasks)
        logger.success("All predictions done.")

        # add predictions to the test data by looking up the index
        for pred in predictions:
            # create a dictionary with the index and prediction
            results.append({
                "index": pred['index'],
                "input": pred['input'],
                "predict": pred['predict'], 
                "real": pred['real']
            })

    # handle if the output file does not exist
    with open(output_fp, "w") as f:
        json.dump(results, f, indent=4)

    logger.success(f"Predictions saved to {output_fp}")

# %% [markdown]
# # Generate Queries

# %%
from utils import preprare_directory
from time import time

# model name 
model_name = "claude_3_7_sonnet_thinking"
# trial number 
trial_number = 0    
# reasoning effort. None means no reasoning effort. Or "low", "medium", "high"
reasoning_effort = "medium"

# create output directory. set exist_ok=False to delete the old results and re-create a fresh folder
output_dir = f"../model_predictions/eICU/{model_name}/trial_{trial_number}"    
preprare_directory(output_dir, exist_ok=False)


# run predictions
start_time = time()
# run predictions
await run_predictions_async(
    test_fp = test_data_fp,
    output_fp = os.path.join(output_dir, "predictions.json"), 
    reasoning_effort = reasoning_effort
)
end_time = time()
logger.success(f"Model {model_name}. Trial {trial_number} completed. Time taken: {end_time - start_time:.2f} seconds")
# Out:
# 2025-07-27 22:45:01.042 | INFO     | __main__:run_predictions_async:14 - Processing chunk 0 to 4
# 2025-07-27 22:45:01.043 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-27 22:45:06.944 | INFO     | __main__:get_prediction:49 - Generated SQL for index 2: SELECT DISTINCT routeadmin
# FROM medication
# WHERE LOWER(drugname) = 'clonidine'
# ORDER BY routeadmin;
# 2025-07-27 22:45:07.644 | INFO     | __main__:get_prediction:49 - Generated SQL for index 4: SELECT DISTINCT routeadmin
# FROM medication
# WHERE drugname LIKE '%propofol%'
# AND dosage LIKE '%1000 mg/100 ml (pmx)%';
# 2025-07-27 22:45:09.664 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1: None
# 2025-07-27 22:45:10.047 | INFO     | __main__:get_prediction:49 - Generated SQL for index 5: SELECT DISTINCT routeadmin
# FROM medication
# WHERE drugname = 'zolpidem tartrate'
# AND dosage LIKE '5 mg%'
# AND LOWER(routeadmin) LIKE 'po%';
# 2025-07-27 22:45:11.838 | INFO     | __main__:get_prediction:49 - Generated SQL for index 3: SELECT routeadmin
# FROM medication
# WHERE drugname = 'morphine'
# AND dosage = '2 mg/1 ml 1 ml syr';
# 2025-07-27 22:45:11.839 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-27 22:45:11.839 | INFO     | __main__:run_predictions_async:14 - Processing chunk 5 to 9
# 2025-07-27 22:45:11.840 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-27 22:45:19.407 | INFO     | __main__:get_prediction:49 - Generated SQL for index 9: SELECT AVG(c.cost) as average_cost
# FROM treatment t
# JOIN cost c ON t.treatmentid = c.eventid
# WHERE t.treatmentname = 'thoracoscopic procedure - wedge resection'
# AND c.eventtype = 'treatment';
# 2025-07-27 22:45:20.412 | INFO     | __main__:get_prediction:49 - Generated SQL for index 10: SELECT AVG(c.cost) AS average_cost, MIN(c.cost) AS min_cost, MAX(c.cost) AS max_cost
# FROM treatment t
# JOIN cost c ON t.treatmentid = c.eventid AND c.eventtype = 'treatment'
# WHERE t.treatmentname = 'insertion of venous catheter for hemodialysis - percutaneous catheter';
# 2025-07-27 22:45:20.791 | INFO     | __main__:get_prediction:49 - Generated SQL for index 7: SELECT c.cost
# FROM treatment t
# JOIN cost c ON t.treatmentid = c.eventid
# WHERE c.eventtype = 'treatment'
# AND LOWER(t.treatmentname) LIKE '%internal fixation%';
# 2025-07-27 22:45:21.298 | INFO     | __main__:get_prediction:49 - Generated SQL for index 8: SELECT AVG(c.cost) as average_cost
# FROM cost c
# JOIN treatment t ON c.eventid = t.treatmentid
# WHERE c.eventtype = 'treatment'
# AND t.treatmentname LIKE '%pulmonary angiogram%' OR t.treatmentname LIKE '%angiography%pulmonary%';
# 2025-07-27 22:45:22.411 | INFO     | __main__:get_prediction:49 - Generated SQL for index 6: SELECT DISTINCT routeadmin
# FROM medication
# WHERE drugname LIKE '%vancomycin%'
# AND dosage LIKE '%1000 mg%' OR dosage LIKE '%1,000 mg%';
# 2025-07-27 22:45:22.412 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-27 22:45:22.412 | INFO     | __main__:run_predictions_async:14 - Processing chunk 10 to 14
# 2025-07-27 22:45:22.412 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-27 22:45:28.765 | INFO     | __main__:get_prediction:49 - Generated SQL for index 11: SELECT c.cost
# FROM treatment t
# JOIN cost c ON t.treatmentid = c.eventid
# WHERE t.treatmentname = 'focussed abdominal sonography'
# AND c.eventtype = 'treatment';
# 2025-07-27 22:45:29.664 | INFO     | __main__:get_prediction:49 - Generated SQL for index 12: SELECT c.cost, m.drugname, m.dosage, c.chargetime
# FROM cost c
# JOIN medication m ON c.eventid = m.medicationid
# WHERE c.eventtype = 'medication'
# AND m.drugname LIKE '%bronchodilator%beta-agonist%';
# 2025-07-27 22:45:30.512 | INFO     | __main__:get_prediction:49 - Generated SQL for index 15: SELECT AVG(c.cost) AS average_cost
# FROM medication m
# JOIN cost c ON m.medicationid = c.eventid AND c.eventtype = 'medication'
# WHERE LOWER(m.drugname) LIKE '%nitroglycerin%'
# AND (LOWER(m.routeadmin) = 'po' OR LOWER(m.routeadmin) = 'oral');
# 2025-07-27 22:45:30.574 | INFO     | __main__:get_prediction:49 - Generated SQL for index 13: SELECT AVG(c.cost) AS average_cost
# FROM cost c
# JOIN medication m ON c.eventid = m.medicationid
# WHERE c.eventtype = 'medication'
# AND LOWER(m.drugname) LIKE '%hydralazine%';
# 2025-07-27 22:45:31.023 | INFO     | __main__:get_prediction:49 - Generated SQL for index 14: None
# 2025-07-27 22:45:31.024 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-27 22:45:31.024 | INFO     | __main__:run_predictions_async:14 - Processing chunk 15 to 19
# 2025-07-27 22:45:31.025 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-27 22:45:38.014 | INFO     | __main__:get_prediction:49 - Generated SQL for index 17: SELECT c.cost
# FROM cost c
# JOIN lab l ON c.eventid = l.labid
# WHERE c.eventtype = 'lab'
# AND l.labname LIKE '%folate%';
# 2025-07-27 22:45:38.145 | INFO     | __main__:get_prediction:49 - Generated SQL for index 16: SELECT c.cost
# FROM lab l
# JOIN cost c ON c.eventid = l.labid AND c.eventtype = 'lab'
# WHERE LOWER(l.labname) LIKE '%methemoglobin%';
# 2025-07-27 22:45:38.649 | INFO     | __main__:get_prediction:49 - Generated SQL for index 19: SELECT c.cost
# FROM cost c
# JOIN lab l ON c.eventid = l.labid
# WHERE c.eventtype = 'lab'
# AND LOWER(l.labname) LIKE '%ph%';
# 2025-07-27 22:45:41.053 | INFO     | __main__:get_prediction:49 - Generated SQL for index 18: SELECT SUM(c.cost) AS total_co2_test_cost
# FROM lab l
# JOIN cost c ON l.labid = c.eventid AND c.eventtype = 'lab'
# WHERE LOWER(l.labname) LIKE '%co2%' OR LOWER(l.labname) LIKE '%carbon dioxide%';
# 2025-07-27 22:45:41.993 | INFO     | __main__:get_prediction:49 - Generated SQL for index 20: None
# 2025-07-27 22:45:41.993 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-27 22:45:41.993 | INFO     | __main__:run_predictions_async:14 - Processing chunk 20 to 24
# 2025-07-27 22:45:41.994 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-27 22:45:49.936 | INFO     | __main__:get_prediction:49 - Generated SQL for index 23: SELECT c.cost, c.chargetime, m.drugname, m.dosage
# FROM cost c
# JOIN medication m ON c.eventid = m.medicationid
# WHERE c.eventtype = 'medication' AND m.drugname = 'klonopin';
# 2025-07-27 22:45:50.368 | INFO     | __main__:get_prediction:49 - Generated SQL for index 25: SELECT c.cost
# FROM cost c
# JOIN medication m ON c.eventid = m.medicationid
# WHERE c.eventtype = 'medication'
# AND LOWER(m.drugname) = 'milk of magnesia ud liq 30 ml';
# 2025-07-27 22:45:50.636 | INFO     | __main__:get_prediction:49 - Generated SQL for index 22: None
# 2025-07-27 22:45:51.984 | INFO     | __main__:get_prediction:49 - Generated SQL for index 24: SELECT c.cost
# FROM medication m
# JOIN cost c ON m.medicationid = c.eventid
# WHERE m.drugname LIKE '%aspirin%'
#   AND m.dosage LIKE '%81 mg%'
#   AND m.dosage LIKE '%chewable%'
#   AND c.eventtype = 'medication';
# 2025-07-27 22:45:54.623 | INFO     | __main__:get_prediction:49 - Generated SQL for index 21: SELECT AVG(c.cost) AS average_cost, SUM(c.cost) AS total_cost, COUNT(*) AS count
# FROM cost c
# JOIN treatment t ON c.eventid = t.treatmentid
# WHERE c.eventtype = 'treatment'
# AND LOWER(t.treatmentname) LIKE '%vent other%';
# 2025-07-27 22:45:54.623 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-27 22:45:54.624 | INFO     | __main__:run_predictions_async:14 - Processing chunk 25 to 29
# 2025-07-27 22:45:54.624 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-27 22:46:01.328 | INFO     | __main__:get_prediction:49 - Generated SQL for index 30: SELECT AVG(c.cost) AS average_cost
# FROM diagnosis d
# JOIN cost c ON d.diagnosisid = c.eventid
# WHERE c.eventtype = 'diagnosis'
# AND LOWER(d.diagnosisname) LIKE '%oral thrush%' OR
#     LOWER(d.diagnosisname) LIKE '%candidiasis oral%' OR
#     LOWER(d.diagnosisname) LIKE '%thrush%oral%';
# 2025-07-27 22:46:01.822 | INFO     | __main__:get_prediction:49 - Generated SQL for index 29: SELECT AVG(c.cost) AS average_cost
# FROM cost c
# JOIN medication m ON c.eventid = m.medicationid
# WHERE c.eventtype = 'medication'
# AND m.drugname LIKE '%epinephrine%';
# 2025-07-27 22:46:02.987 | INFO     | __main__:get_prediction:49 - Generated SQL for index 26: SELECT c.cost
# FROM cost c
# JOIN medication m ON c.eventid = m.medicationid
# WHERE c.eventtype = 'medication'
# AND m.drugname = 'furosemide'
# AND m.dosage LIKE '%4 ml vial%10 mg/ml%'
# LIMIT 1;
# 2025-07-27 22:46:03.414 | INFO     | __main__:get_prediction:49 - Generated SQL for index 27: SELECT c.cost
# FROM cost c
# JOIN medication m ON c.eventid = m.medicationid
# WHERE c.eventtype = 'medication'
# AND LOWER(m.drugname) LIKE '%cephulac%';
# 2025-07-27 22:46:05.502 | INFO     | __main__:get_prediction:49 - Generated SQL for index 28: None
# 2025-07-27 22:46:05.502 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-27 22:46:05.503 | INFO     | __main__:run_predictions_async:14 - Processing chunk 30 to 34
# 2025-07-27 22:46:05.503 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-27 22:46:12.133 | INFO     | __main__:get_prediction:49 - Generated SQL for index 33: SELECT AVG(c.cost) as average_cost
# FROM cost c
# JOIN diagnosis d ON c.eventid = d.diagnosisid
# WHERE c.eventtype = 'diagnosis'
# AND LOWER(d.diagnosisname) LIKE '%acute pulmonary edema%';
# 2025-07-27 22:46:12.680 | INFO     | __main__:get_prediction:49 - Generated SQL for index 34: SELECT c.cost
# FROM diagnosis d
# JOIN cost c ON d.diagnosisid = c.eventid
# WHERE d.diagnosisname = 'acute lung injury - etiology unknown'
# AND c.eventtype = 'diagnosis';
# 2025-07-27 22:46:14.559 | INFO     | __main__:get_prediction:49 - Generated SQL for index 31: SELECT AVG(c.cost) AS average_cost
# FROM diagnosis d
# JOIN cost c ON d.diagnosisid = c.eventid
# WHERE d.diagnosisname LIKE '%benzodiazepine overdose%decreased mental status%'
# AND c.eventtype = 'diagnosis';
# 2025-07-27 22:46:14.815 | INFO     | __main__:get_prediction:49 - Generated SQL for index 32: SELECT AVG(c.cost) AS average_cost
# FROM diagnosis d
# JOIN cost c ON d.diagnosisid = c.eventid
# WHERE c.eventtype = 'diagnosis'
# AND LOWER(d.diagnosisname) = 'acute respiratory distress - etiology unknown';
# 2025-07-27 22:46:16.187 | INFO     | __main__:get_prediction:49 - Generated SQL for index 35: SELECT AVG(c.cost) AS average_cost
# FROM diagnosis d
# JOIN cost c ON d.diagnosisid = c.eventid
# WHERE c.eventtype = 'diagnosis'
# AND LOWER(d.diagnosisname) LIKE '%coronary artery disease%';
# 2025-07-27 22:46:16.188 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-27 22:46:16.188 | INFO     | __main__:run_predictions_async:14 - Processing chunk 35 to 39
# 2025-07-27 22:46:16.188 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-27 22:46:20.653 | INFO     | __main__:get_prediction:49 - Generated SQL for index 38: SELECT gender
# FROM patient
# WHERE uniquepid = '015-66570';
# 2025-07-27 22:46:21.267 | INFO     | __main__:get_prediction:49 - Generated SQL for index 37: SELECT gender
# FROM patient
# WHERE uniquepid = '028-40370';
# 2025-07-27 22:46:22.958 | INFO     | __main__:get_prediction:49 - Generated SQL for index 40: SELECT gender
# FROM patient
# WHERE uniquepid = '006-227759';
# 2025-07-27 22:46:23.042 | INFO     | __main__:get_prediction:49 - Generated SQL for index 39: SELECT gender
# FROM patient
# WHERE uniquepid = '015-76706';
# 2025-07-27 22:46:24.809 | INFO     | __main__:get_prediction:49 - Generated SQL for index 36: SELECT AVG(c.cost) AS average_cost
# FROM diagnosis d
# JOIN cost c ON d.diagnosisid = c.eventid
# WHERE d.diagnosisname LIKE '%pacemaker/aicd dysfunction%'
# AND c.eventtype = 'diagnosis';
# 2025-07-27 22:46:24.809 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-27 22:46:24.810 | INFO     | __main__:run_predictions_async:14 - Processing chunk 40 to 44
# 2025-07-27 22:46:24.810 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-27 22:46:31.616 | INFO     | __main__:get_prediction:49 - Generated SQL for index 41: SELECT
#     uniquepid,
#     patientunitstayid,
#     (julianday(hospitaldischargetime) - julianday(hospitaladmittime)) * 24 AS length_of_stay_hours
# FROM
#     patient
# WHERE
#     uniquepid = '006-146580'
# ORDER BY
#     hospitaladmittime DESC
# LIMIT 1;
# 2025-07-27 22:46:32.143 | INFO     | __main__:get_prediction:49 - Generated SQL for index 45: SELECT
#   uniquepid,
#   hospitaladmittime,
#   hospitaldischargetime,
#   ROUND((JULIANDAY(hospitaldischargetime) - JULIANDAY(hospitaladmittime)) * 24, 2) AS duration_hours
# FROM patient
# WHERE uniquepid = '006-65780'
# ORDER BY hospitaladmittime DESC
# LIMIT 1;
# 2025-07-27 22:46:32.460 | INFO     | __main__:get_prediction:49 - Generated SQL for index 42: SELECT
#     (julianday(hospitaldischargetime) - julianday(hospitaladmittime)) AS length_of_stay_days
# FROM
#     patient
# WHERE
#     uniquepid = '002-52932'
# ORDER BY
#     hospitaladmittime DESC
# LIMIT 1;
# 2025-07-27 22:46:32.764 | INFO     | __main__:get_prediction:49 - Generated SQL for index 44: SELECT
#     uniquepid,
#     (julianday(hospitaldischargetime) - julianday(hospitaladmittime)) * 24 as length_of_stay_hours
# FROM
#     patient
# WHERE
#     uniquepid = '015-75226'
# ORDER BY
#     hospitaladmittime
# LIMIT 1;
# 2025-07-27 22:46:34.376 | INFO     | __main__:get_prediction:49 - Generated SQL for index 43: SELECT
#     uniquepid,
#     julianday(hospitaldischargetime) - julianday(hospitaladmittime) AS length_of_stay_days
# FROM
#     patient
# WHERE
#     uniquepid = '028-47306'
# ORDER BY
#     hospitaladmittime DESC
# LIMIT 1;
# 2025-07-27 22:46:34.377 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-27 22:46:34.377 | INFO     | __main__:run_predictions_async:14 - Processing chunk 45 to 49
# 2025-07-27 22:46:34.377 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-27 22:46:41.570 | INFO     | __main__:get_prediction:49 - Generated SQL for index 46: SELECT
#     uniquepid,
#     hospitaladmittime,
#     hospitaldischargetime,
#     (JULIANDAY(hospitaldischargetime) - JULIANDAY(hospitaladmittime)) AS hospital_stay_days
# FROM
#     patient
# WHERE
#     uniquepid = '017-74343';
# 2025-07-27 22:46:41.663 | INFO     | __main__:get_prediction:49 - Generated SQL for index 49: SELECT
#     uniquepid,
#     julianday(hospitaldischargetime) - julianday(hospitaladmittime) AS length_of_stay_days
# FROM
#     patient
# WHERE
#     uniquepid = '011-58352'
# ORDER BY
#     hospitaladmittime DESC
# LIMIT 1;
# 2025-07-27 22:46:44.920 | INFO     | __main__:get_prediction:49 - Generated SQL for index 48: SELECT
#     (julianday(hospitaldischargetime) - julianday(hospitaladmittime)) AS length_of_stay_days
# FROM
#     patient
# WHERE
#     uniquepid = '017-101310'
# ORDER BY
#     hospitaladmittime ASC
# LIMIT 1;
# 2025-07-27 22:46:45.573 | INFO     | __main__:get_prediction:49 - Generated SQL for index 50: SELECT
#     uniquepid,
#     julianday(hospitaldischargetime) - julianday(hospitaladmittime) AS length_of_stay_days
# FROM
#     patient
# WHERE
#     uniquepid = '032-32248'
# ORDER BY
#     hospitaladmittime DESC
# LIMIT 1;
# 2025-07-27 22:46:45.738 | INFO     | __main__:get_prediction:49 - Generated SQL for index 47: SELECT
#     JULIANDAY(hospitaldischargetime) - JULIANDAY(hospitaladmittime) AS length_of_stay_days
# FROM
#     patient
# WHERE
#     uniquepid = '016-5052'
# ORDER BY
#     hospitaladmittime ASC
# LIMIT 1;
# 2025-07-27 22:46:45.739 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-27 22:46:45.739 | INFO     | __main__:run_predictions_async:14 - Processing chunk 50 to 54
# 2025-07-27 22:46:45.739 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-27 22:46:53.153 | INFO     | __main__:get_prediction:49 - Generated SQL for index 51: SELECT
#     uniquepid,
#     patienthealthsystemstayid,
#     ROUND((JULIANDAY(hospitaldischargetime) - JULIANDAY(hospitaladmittime)) * 24, 2) AS hospital_los_hours
# FROM
#     patient
# WHERE
#     uniquepid = '016-1459'
# ORDER BY
#     hospitaladmittime DESC
# LIMIT 1;
# 2025-07-27 22:46:53.962 | INFO     | __main__:get_prediction:49 - Generated SQL for index 55: SELECT
#     julianday(hospitaldischargetime) - julianday(hospitaladmittime) AS length_of_stay_days
# FROM
#     patient
# WHERE
#     uniquepid = '025-37141'
# ORDER BY
#     hospitaladmittime ASC
# LIMIT 1;
# 2025-07-27 22:46:55.356 | INFO     | __main__:get_prediction:49 - Generated SQL for index 54: SELECT
#     (julianday(hospitaldischargetime) - julianday(hospitaladmittime)) AS length_of_stay_days
# FROM patient
# WHERE uniquepid = '006-245995'
# ORDER BY hospitaladmittime
# LIMIT 1;
# 2025-07-27 22:46:55.441 | INFO     | __main__:get_prediction:49 - Generated SQL for index 52: SELECT
#     uniquepid,
#     patienthealthsystemstayid,
#     julianday(hospitaldischargetime) - julianday(hospitaladmittime) AS length_of_stay_days
# FROM
#     patient
# WHERE
#     uniquepid = '027-107035'
# ORDER BY
#     hospitaladmittime ASC
# LIMIT 1;
# 2025-07-27 22:47:00.389 | INFO     | __main__:get_prediction:49 - Generated SQL for index 53: SELECT
#     uniquepid,
#     julianday(hospitaldischargetime) - julianday(hospitaladmittime) AS length_of_stay_days
# FROM
#     patient
# WHERE
#     uniquepid = '035-22706'
# ORDER BY
#     hospitaladmittime DESC
# LIMIT 1;
# 2025-07-27 22:47:00.390 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-27 22:47:00.390 | INFO     | __main__:run_predictions_async:14 - Processing chunk 55 to 59
# 2025-07-27 22:47:00.391 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-27 22:47:07.823 | INFO     | __main__:get_prediction:49 - Generated SQL for index 59: None
# 2025-07-27 22:47:07.841 | INFO     | __main__:get_prediction:49 - Generated SQL for index 57: SELECT (dischargeweight - admissionweight) AS weight_change
# FROM patient
# WHERE uniquepid = '010-12376'
# AND patienthealthsystemstayid = (
#     SELECT MIN(patienthealthsystemstayid)
#     FROM patient
#     WHERE uniquepid = '010-12376'
# );
# 2025-07-27 22:47:08.118 | INFO     | __main__:get_prediction:49 - Generated SQL for index 60: None
# 2025-07-27 22:47:08.451 | INFO     | __main__:get_prediction:49 - Generated SQL for index 56: SELECT
#     dischargeweight - admissionweight AS weight_difference
# FROM
#     patient
# WHERE
#     uniquepid = '018-47575'
# ORDER BY
#     hospitaladmittime DESC
# LIMIT 1;
# 2025-07-27 22:47:09.448 | INFO     | __main__:get_prediction:49 - Generated SQL for index 58: None
# 2025-07-27 22:47:09.448 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-27 22:47:09.448 | INFO     | __main__:run_predictions_async:14 - Processing chunk 60 to 64
# 2025-07-27 22:47:09.449 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-27 22:47:17.029 | INFO     | __main__:get_prediction:49 - Generated SQL for index 64: None
# 2025-07-27 22:47:17.087 | INFO     | __main__:get_prediction:49 - Generated SQL for index 62: None
# 2025-07-27 22:47:20.396 | INFO     | __main__:get_prediction:49 - Generated SQL for index 61: SELECT
#   dischargeweight - admissionweight AS weight_change
# FROM
#   patient
# WHERE
#   uniquepid = '006-202970'
#   AND hospitaldischargetime IS NULL;
# 2025-07-27 22:47:20.450 | INFO     | __main__:get_prediction:49 - Generated SQL for index 63: SELECT
#     dischargeweight - admissionweight AS weight_difference
# FROM
#     patient
# WHERE
#     uniquepid = '007-13494'
#     AND patienthealthsystemstayid = (
#         SELECT MIN(patienthealthsystemstayid)
#         FROM patient
#         WHERE uniquepid = '007-13494'
#     );
# 2025-07-27 22:47:20.490 | INFO     | __main__:get_prediction:49 - Generated SQL for index 65: SELECT
#     dischargeweight - admissionweight as weight_difference
# FROM
#     patient
# WHERE
#     uniquepid = '007-9115'
#     AND patienthealthsystemstayid = (
#         SELECT MIN(patienthealthsystemstayid)
#         FROM patient
#         WHERE uniquepid = '007-9115'
#     );
# 2025-07-27 22:47:20.491 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-27 22:47:20.491 | INFO     | __main__:run_predictions_async:14 - Processing chunk 65 to 69
# 2025-07-27 22:47:20.491 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-27 22:47:28.409 | INFO     | __main__:get_prediction:49 - Generated SQL for index 68: None
# 2025-07-27 22:47:30.655 | INFO     | __main__:get_prediction:49 - Generated SQL for index 66: None
# 2025-07-27 22:47:33.797 | INFO     | __main__:get_prediction:49 - Generated SQL for index 67: SELECT
#     last_creatinine.labresult - second_last_creatinine.labresult AS creatinine_difference
# FROM
#     (SELECT l.labresult, l.labresulttime
#      FROM lab l
#      JOIN patient p ON p.patientunitstayid = l.patientunitstayid
#      WHERE p.uniquepid = '006-195316'
#      AND l.labname = 'creatinine'
#      ORDER BY l.labresulttime DESC
#      LIMIT 1) AS last_creatinine,
#
#     (SELECT l.labresult, l.labresulttime
#      FROM lab l
#      JOIN patient p ON p.patientunitstayid = l.patientunitstayid
#      WHERE p.uniquepid = '006-195316'
#      AND l.labname = 'creatinine'
#      ORDER BY l.labresulttime DESC
#      LIMIT 1 OFFSET 1) AS second_last_creatinine;
# 2025-07-27 22:47:35.206 | INFO     | __main__:get_prediction:49 - Generated SQL for index 69: None
# 2025-07-27 22:47:35.315 | INFO     | __main__:get_prediction:49 - Generated SQL for index 70: WITH LastStay AS (
#     SELECT patientunitstayid, hospitaladmittime, hospitaldischargetime
#     FROM patient
#     WHERE uniquepid = '005-68848'
#     ORDER BY hospitaladmittime DESC
#     LIMIT 1
# ),
# SodiumValues AS (
#     SELECT
#         l.labresult,
#         l.labresulttime,
#         ROW_NUMBER() OVER (ORDER BY l.labresulttime ASC) as first_reading,
#         ROW_NUMBER() OVER (ORDER BY l.labresulttime DESC) as last_reading
#     FROM lab l
#     JOIN LastStay ls ON l.patientunitstayid = ls.patientunitstayid
#     WHERE l.labname = 'sodium'
#     AND l.labresulttime BETWEEN ls.hospitaladmittime AND COALESCE(ls.hospitaldischargetime, '2105-12-31 23:59:00')
# )
# SELECT
#     (SELECT labresult FROM SodiumValues WHERE last_reading = 1) -
#     (SELECT labresult FROM SodiumValues WHERE first_reading = 1) AS sodium_difference;
# 2025-07-27 22:47:35.315 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-27 22:47:35.315 | INFO     | __main__:run_predictions_async:14 - Processing chunk 70 to 74
# 2025-07-27 22:47:35.316 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-27 22:47:44.683 | INFO     | __main__:get_prediction:49 - Generated SQL for index 72: SELECT
#     (lab2.labresult - lab1.labresult) AS bun_change
# FROM
#     lab lab1
# JOIN
#     lab lab2 ON lab1.patientunitstayid = lab2.patientunitstayid
# JOIN
#     patient p ON lab1.patientunitstayid = p.patientunitstayid
# WHERE
#     p.uniquepid = '030-16826'
#     AND lab1.labname = 'bun'
#     AND lab2.labname = 'bun'
#     AND lab1.labresulttime = '2104-06-13 12:26:00'
#     AND lab2.labresulttime = '2104-06-17 13:25:00';
# 2025-07-27 22:47:46.090 | INFO     | __main__:get_prediction:49 - Generated SQL for index 75: SELECT
#     second_sodium.labresult - first_sodium.labresult AS sodium_difference
# FROM
#     (SELECT lab.labresult, lab.labresulttime
#      FROM lab
#      JOIN patient ON lab.patientunitstayid = patient.patientunitstayid
#      WHERE patient.uniquepid = '016-3041'
#      AND lab.labname = 'sodium'
#      ORDER BY lab.labresulttime
#      LIMIT 1) AS first_sodium,
#     (SELECT lab.labresult, lab.labresulttime
#      FROM lab
#      JOIN patient ON lab.patientunitstayid = patient.patientunitstayid
#      WHERE patient.uniquepid = '016-3041'
#      AND lab.labname = 'sodium'
#      ORDER BY lab.labresulttime
#      LIMIT 1 OFFSET 1) AS second_sodium;
# 2025-07-27 22:47:48.426 | INFO     | __main__:get_prediction:49 - Generated SQL for index 73: None
# 2025-07-27 22:47:48.945 | INFO     | __main__:get_prediction:49 - Generated SQL for index 71: WITH LastVisit AS (
#     SELECT patientunitstayid
#     FROM patient
#     WHERE uniquepid = '027-10308'
#     ORDER BY hospitaladmittime DESC
#     LIMIT 1
# ),
# GlucoseMeasurements AS (
#     SELECT
#         labresult,
#         labresulttime,
#         ROW_NUMBER() OVER (ORDER BY labresulttime DESC) as rn
#     FROM lab
#     JOIN LastVisit USING (patientunitstayid)
#     WHERE labname LIKE '%glucose%' AND labname LIKE '%bedside%'
# )
# SELECT
#     (SELECT labresult FROM GlucoseMeasurements WHERE rn = 1) -
#     (SELECT labresult FROM GlucoseMeasurements WHERE rn = 2) AS glucose_difference
# FROM GlucoseMeasurements
# WHERE rn = 1;
# 2025-07-27 22:47:52.180 | INFO     | __main__:get_prediction:49 - Generated SQL for index 74: WITH bun_measurements AS (
#   SELECT
#     lab.labresult,
#     lab.labresulttime,
#     ROW_NUMBER() OVER (ORDER BY lab.labresulttime) AS measurement_number
#   FROM lab
#   JOIN patient ON lab.patientunitstayid = patient.patientunitstayid
#   WHERE patient.uniquepid = '005-4471'
#     AND lab.labname = 'bun'
#     AND lab.labresulttime >= patient.hospitaladmittime
# )
# SELECT
#   second.labresult - first.labresult AS bun_change
# FROM bun_measurements first
# JOIN bun_measurements second ON second.measurement_number = 2
# WHERE first.measurement_number = 1;
# 2025-07-27 22:47:52.181 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-27 22:47:52.181 | INFO     | __main__:run_predictions_async:14 - Processing chunk 75 to 79
# 2025-07-27 22:47:52.182 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-27 22:48:00.563 | INFO     | __main__:get_prediction:49 - Generated SQL for index 78: None
# 2025-07-27 22:48:01.681 | INFO     | __main__:get_prediction:49 - Generated SQL for index 80: WITH ranked_respirations AS (
#   SELECT
#     vp.respiration,
#     vp.observationtime,
#     ROW_NUMBER() OVER (ORDER BY vp.observationtime DESC) as rn
#   FROM vitalperiodic vp
#   JOIN patient p ON p.patientunitstayid = vp.patientunitstayid
#   WHERE p.uniquepid = '027-203413'
#     AND vp.respiration IS NOT NULL
# )
# SELECT
#   last_resp.respiration - second_last_resp.respiration AS respiration_difference
# FROM
#   ranked_respirations last_resp,
#   ranked_respirations second_last_resp
# WHERE
#   last_resp.rn = 1
#   AND second_last_resp.rn = 2;
# 2025-07-27 22:48:03.659 | INFO     | __main__:get_prediction:49 - Generated SQL for index 77: None
# 2025-07-27 22:48:04.026 | INFO     | __main__:get_prediction:49 - Generated SQL for index 79: SELECT
#   (t2.temperature - t1.temperature) AS temperature_change
# FROM
#   vitalperiodic t1,
#   vitalperiodic t2
# WHERE
#   t1.patientunitstayid = 13127
#   AND t2.patientunitstayid = 13127
#   AND t1.observationtime = '2105-12-31 22:49:00'
#   AND t2.observationtime = '2105-12-31 22:54:00';
# 2025-07-27 22:48:05.655 | INFO     | __main__:get_prediction:49 - Generated SQL for index 76: WITH sodium_values AS (
#   SELECT
#     l.labresult,
#     l.labresulttime
#   FROM
#     lab l
#     JOIN patient p ON l.patientunitstayid = p.patientunitstayid
#   WHERE
#     p.uniquepid = '027-120477'
#     AND l.labname LIKE '%sodium%'
#     AND (l.labresulttime = '2104-01-04 13:15:00' OR l.labresulttime = '2104-01-03 05:32:00')
# )
# SELECT
#   (SELECT labresult FROM sodium_values WHERE labresulttime = '2104-01-04 13:15:00') -
#   (SELECT labresult FROM sodium_values WHERE labresulttime = '2104-01-03 05:32:00') AS sodium_difference;
# 2025-07-27 22:48:05.656 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-27 22:48:05.656 | INFO     | __main__:run_predictions_async:14 - Processing chunk 80 to 84
# 2025-07-27 22:48:05.656 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-27 22:48:13.826 | INFO     | __main__:get_prediction:49 - Generated SQL for index 81: None
# 2025-07-27 22:48:13.962 | INFO     | __main__:get_prediction:49 - Generated SQL for index 82: None
# 2025-07-27 22:48:14.471 | INFO     | __main__:get_prediction:49 - Generated SQL for index 83: WITH hr_values AS (
#     SELECT
#         vp1.heartrate AS hr_earlier,
#         vp2.heartrate AS hr_later
#     FROM patient p
#     JOIN vitalperiodic vp1 ON p.patientunitstayid = vp1.patientunitstayid AND vp1.observationtime = '2105-08-15 09:52:00'
#     JOIN vitalperiodic vp2 ON p.patientunitstayid = vp2.patientunitstayid AND vp2.observationtime = '2105-08-15 09:57:00'
#     WHERE p.uniquepid = '015-96048'
# )
# SELECT
#     hr_later - hr_earlier AS heartrate_change
# FROM hr_values;
# 2025-07-27 22:48:18.788 | INFO     | __main__:get_prediction:49 - Generated SQL for index 85: WITH heart_rates AS (
#     SELECT v.heartrate, v.observationtime
#     FROM vitalperiodic v
#     JOIN patient p ON v.patientunitstayid = p.patientunitstayid
#     WHERE p.uniquepid = '027-94096'
#     AND v.observationtime IN ('2104-07-27 12:18:40', '2104-07-27 12:13:40')
# )
# SELECT
#     (SELECT heartrate FROM heart_rates WHERE observationtime = '2104-07-27 12:18:40') -
#     (SELECT heartrate FROM heart_rates WHERE observationtime = '2104-07-27 12:13:40')
#     AS heartrate_difference;
# 2025-07-27 22:48:22.071 | INFO     | __main__:get_prediction:49 - Generated SQL for index 84: WITH first_icu_stay AS (
#     SELECT patientunitstayid
#     FROM patient
#     WHERE uniquepid = '015-94586'
#     ORDER BY unitadmittime
#     LIMIT 1
# ),
# heart_rates AS (
#     SELECT
#         heartrate,
#         ROW_NUMBER() OVER (ORDER BY observationtime) as measurement_num
#     FROM vitalperiodic
#     WHERE patientunitstayid = (SELECT patientunitstayid FROM first_icu_stay)
#         AND heartrate IS NOT NULL
#     ORDER BY observationtime
# )
# SELECT
#     (SELECT heartrate FROM heart_rates WHERE measurement_num = 2) -
#     (SELECT heartrate FROM heart_rates WHERE measurement_num = 1) AS heartrate_difference
# FROM dual;
# 2025-07-27 22:48:22.072 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-27 22:48:22.072 | INFO     | __main__:run_predictions_async:14 - Processing chunk 85 to 89
# 2025-07-27 22:48:22.073 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-27 22:48:29.455 | INFO     | __main__:get_prediction:49 - Generated SQL for index 87: None
# 2025-07-27 22:48:32.756 | INFO     | __main__:get_prediction:49 - Generated SQL for index 86: WITH first_icu AS (
#     SELECT patientunitstayid
#     FROM patient
#     WHERE uniquepid = '006-36108'
#     ORDER BY unitadmittime ASC
#     LIMIT 1
# ),
# first_measurement AS (
#     SELECT respiration
#     FROM vitalperiodic
#     JOIN first_icu USING (patientunitstayid)
#     ORDER BY observationtime ASC
#     LIMIT 1
# ),
# last_measurement AS (
#     SELECT respiration
#     FROM vitalperiodic
#     JOIN first_icu USING (patientunitstayid)
#     ORDER BY observationtime DESC
#     LIMIT 1
# )
# SELECT last_measurement.respiration - first_measurement.respiration AS respiration_difference
# FROM last_measurement, first_measurement;
# 2025-07-27 22:48:35.966 | INFO     | __main__:get_prediction:49 - Generated SQL for index 89: WITH first_visit AS (
#     SELECT patientunitstayid
#     FROM patient
#     WHERE uniquepid = '027-69449'
#     ORDER BY hospitaladmittime
#     LIMIT 1
# ),
# platelet_readings AS (
#     SELECT
#         l.labresult,
#         l.labresulttime,
#         ROW_NUMBER() OVER (ORDER BY l.labresulttime DESC) as rn
#     FROM lab l
#     JOIN first_visit fv ON l.patientunitstayid = fv.patientunitstayid
#     WHERE l.labname LIKE '%platelet%'
# )
# SELECT
#     CASE
#         WHEN (SELECT labresult FROM platelet_readings WHERE rn = 1) <
#              (SELECT labresult FROM platelet_readings WHERE rn = 2)
#         THEN 'Yes, the last platelet value is less than the second-to-last value'
#         ELSE 'No, the last platelet value is not less than the second-to-last value'
#     END as comparison_result
# FROM platelet_readings
# LIMIT 1;
# 2025-07-27 22:48:37.099 | INFO     | __main__:get_prediction:49 - Generated SQL for index 90: None
# 2025-07-27 22:48:39.096 | INFO     | __main__:get_prediction:49 - Generated SQL for index 88: WITH first_lactate AS (
#     SELECT lab.labresult
#     FROM lab
#     JOIN patient p ON lab.patientunitstayid = p.patientunitstayid
#     WHERE p.uniquepid = '006-133605'
#     AND lab.labname = 'lactate'
#     AND lab.labresulttime >= p.hospitaladmittime
#     ORDER BY lab.labresulttime ASC
#     LIMIT 1
# ),
# last_lactate AS (
#     SELECT lab.labresult
#     FROM lab
#     JOIN patient p ON lab.patientunitstayid = p.patientunitstayid
#     WHERE p.uniquepid = '006-133605'
#     AND lab.labname = 'lactate'
#     AND lab.labresulttime >= p.hospitaladmittime
#     ORDER BY lab.labresulttime DESC
#     LIMIT 1
# )
# SELECT
#     CASE WHEN last_lactate.labresult > first_lactate.labresult
#          THEN 1 ELSE 0 END AS is_last_greater_than_first
# FROM first_lactate, last_lactate;
# 2025-07-27 22:48:39.096 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-27 22:48:39.097 | INFO     | __main__:run_predictions_async:14 - Processing chunk 90 to 94
# 2025-07-27 22:48:39.097 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-27 22:48:49.139 | INFO     | __main__:get_prediction:49 - Generated SQL for index 94: WITH calcium_labs AS (
#     SELECT
#         p.patientunitstayid,
#         l.labname,
#         l.labresult,
#         l.labresulttime,
#         ROW_NUMBER() OVER (PARTITION BY p.patientunitstayid ORDER BY l.labresulttime) AS first_reading,
#         ROW_NUMBER() OVER (PARTITION BY p.patientunitstayid ORDER BY l.labresulttime DESC) AS last_reading
#     FROM
#         patient p
#         JOIN lab l ON p.patientunitstayid = l.patientunitstayid
#     WHERE
#         p.uniquepid = '021-111547'
#         AND l.labname LIKE '%calcium%'
# )
# SELECT
#     (SELECT labresult FROM calcium_labs WHERE last_reading = 1) <
#     (SELECT labresult FROM calcium_labs WHERE first_reading = 1) AS is_last_less_than_first;
# 2025-07-27 22:48:50.765 | INFO     | __main__:get_prediction:49 - Generated SQL for index 91: WITH patient_stay AS (
#   SELECT patientunitstayid
#   FROM patient
#   WHERE uniquepid = '009-5001'
# ),
# glucose_measurements AS (
#   SELECT
#     l.labresult,
#     l.labresulttime
#   FROM lab l
#   JOIN patient_stay ps ON l.patientunitstayid = ps.patientunitstayid
#   WHERE LOWER(l.labname) LIKE '%glucose%' OR LOWER(l.labname) LIKE '%blood sugar%'
# ),
# first_measurement AS (
#   SELECT labresult
#   FROM glucose_measurements
#   ORDER BY labresulttime ASC
#   LIMIT 1
# ),
# last_measurement AS (
#   SELECT labresult
#   FROM glucose_measurements
#   ORDER BY labresulttime DESC
#   LIMIT 1
# )
# SELECT
#   (SELECT labresult FROM last_measurement) > (SELECT labresult FROM first_measurement) AS is_last_greater_than_first;
# 2025-07-27 22:48:50.908 | INFO     | __main__:get_prediction:49 - Generated SQL for index 95: WITH first_icu_stay AS (
#     SELECT patientunitstayid
#     FROM patient
#     WHERE uniquepid = '006-146580'
#     ORDER BY unitadmittime
#     LIMIT 1
# ),
# first_measurement AS (
#     SELECT systemicsystolic
#     FROM vitalperiodic v
#     JOIN first_icu_stay f ON v.patientunitstayid = f.patientunitstayid
#     WHERE systemicsystolic IS NOT NULL
#     ORDER BY observationtime
#     LIMIT 1
# ),
# last_measurement AS (
#     SELECT systemicsystolic
#     FROM vitalperiodic v
#     JOIN first_icu_stay f ON v.patientunitstayid = f.patientunitstayid
#     WHERE systemicsystolic IS NOT NULL
#     ORDER BY observationtime DESC
#     LIMIT 1
# )
# SELECT
#     first_measurement.systemicsystolic AS first_value,
#     last_measurement.systemicsystolic AS last_value,
#     CASE
#         WHEN last_measurement.systemicsystolic < first_measurement.systemicsystolic
#         THEN 'Yes'
#         ELSE 'No'
#     END AS is_last_less_than_first
# FROM first_measurement, last_measurement;
# 2025-07-27 22:48:51.436 | INFO     | __main__:get_prediction:49 - Generated SQL for index 92: WITH wbc_measurements AS (
#     SELECT
#         labresult,
#         labresulttime,
#         ROW_NUMBER() OVER (ORDER BY labresulttime DESC) as row_num
#     FROM lab
#     WHERE patientunitstayid = (
#         SELECT patientunitstayid
#         FROM patient
#         WHERE uniquepid = '007-15837'
#         AND hospitaldischargetime IS NULL
#     )
#     AND LOWER(labname) LIKE '%wbc%'
#     ORDER BY labresulttime DESC
# )
# SELECT
#     CASE
#         WHEN (SELECT labresult FROM wbc_measurements WHERE row_num = 1) <
#              (SELECT labresult FROM wbc_measurements WHERE row_num = 2)
#         THEN 'Yes, the most recent WBC is less than the second most recent'
#         ELSE 'No, the most recent WBC is not less than the second most recent'
#     END as comparison_result;
# 2025-07-27 22:48:55.416 | INFO     | __main__:get_prediction:49 - Generated SQL for index 93: WITH first_visit AS (
#   SELECT patientunitstayid
#   FROM patient
#   WHERE uniquepid = '012-11090'
#   ORDER BY hospitaladmittime
#   LIMIT 1
# ),
# chloride_values AS (
#   SELECT
#     l.labresult,
#     l.labresulttime,
#     ROW_NUMBER() OVER (ORDER BY l.labresulttime ASC) as first_reading,
#     ROW_NUMBER() OVER (ORDER BY l.labresulttime DESC) as last_reading
#   FROM lab l
#   JOIN first_visit fv ON l.patientunitstayid = fv.patientunitstayid
#   WHERE l.labname LIKE '%chloride%'
# )
# SELECT
#   (SELECT labresult FROM chloride_values WHERE last_reading = 1) <
#   (SELECT labresult FROM chloride_values WHERE first_reading = 1) as is_last_less_than_first
# FROM chloride_values
# LIMIT 1;
# 2025-07-27 22:48:55.417 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-27 22:48:55.417 | INFO     | __main__:run_predictions_async:14 - Processing chunk 95 to 99
# 2025-07-27 22:48:55.417 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-27 22:49:06.131 | INFO     | __main__:get_prediction:49 - Generated SQL for index 97: WITH patient_vitals AS (
#     SELECT
#         v.sao2,
#         v.observationtime,
#         FIRST_VALUE(v.sao2) OVER (PARTITION BY v.patientunitstayid ORDER BY v.observationtime ASC) AS first_sao2,
#         FIRST_VALUE(v.sao2) OVER (PARTITION BY v.patientunitstayid ORDER BY v.observationtime DESC) AS last_sao2
#     FROM vitalperiodic v
#     JOIN patient p ON v.patientunitstayid = p.patientunitstayid
#     WHERE p.uniquepid = '027-165214'
#     AND v.sao2 IS NOT NULL
# )
# SELECT
#     CASE
#         WHEN last_sao2 > first_sao2 THEN 'Yes, the last SAO2 is greater than the first'
#         WHEN last_sao2 < first_sao2 THEN 'No, the last SAO2 is not greater than the first'
#         ELSE 'The first and last SAO2 values are equal'
#     END AS comparison_result
# FROM patient_vitals
# LIMIT 1;
# 2025-07-27 22:49:06.338 | INFO     | __main__:get_prediction:49 - Generated SQL for index 98: None
# 2025-07-27 22:49:07.588 | INFO     | __main__:get_prediction:49 - Generated SQL for index 99: WITH first_measurement AS (
#     SELECT heartrate, observationtime
#     FROM vitalperiodic v
#     JOIN patient p ON v.patientunitstayid = p.patientunitstayid
#     WHERE p.uniquepid = '005-4471'
#     AND v.heartrate IS NOT NULL
#     ORDER BY v.observationtime ASC
#     LIMIT 1
# ),
# last_measurement AS (
#     SELECT heartrate, observationtime
#     FROM vitalperiodic v
#     JOIN patient p ON v.patientunitstayid = p.patientunitstayid
#     WHERE p.uniquepid = '005-4471'
#     AND v.heartrate IS NOT NULL
#     ORDER BY v.observationtime DESC
#     LIMIT 1
# )
# SELECT
#     CASE WHEN last.heartrate < first.heartrate THEN 'Yes' ELSE 'No' END AS is_last_less_than_first
# FROM first_measurement first
# JOIN last_measurement last ON 1=1;
# 2025-07-27 22:49:07.995 | INFO     | __main__:get_prediction:49 - Generated SQL for index 96: WITH first_icu_stay AS (
#     SELECT patientunitstayid
#     FROM patient
#     WHERE uniquepid = '027-210868'
#     ORDER BY unitadmittime ASC
#     LIMIT 1
# ),
# measurements AS (
#     SELECT
#         systemicmean,
#         observationtime,
#         FIRST_VALUE(systemicmean) OVER (PARTITION BY patientunitstayid ORDER BY observationtime ASC) AS first_measurement,
#         FIRST_VALUE(systemicmean) OVER (PARTITION BY patientunitstayid ORDER BY observationtime DESC) AS last_measurement
#     FROM vitalperiodic
#     WHERE patientunitstayid = (SELECT patientunitstayid FROM first_icu_stay)
#     AND systemicmean IS NOT NULL
# )
# SELECT
#     CASE WHEN last_measurement > first_measurement THEN 'Yes' ELSE 'No' END AS is_last_greater_than_first
# FROM measurements
# LIMIT 1;
# 2025-07-27 22:49:08.643 | INFO     | __main__:get_prediction:49 - Generated SQL for index 100: WITH heart_rate_data AS (
#   SELECT
#     v1.heartrate AS first_time_hr,
#     v2.heartrate AS second_time_hr
#   FROM
#     patient p
#   JOIN
#     vitalperiodic v1 ON p.patientunitstayid = v1.patientunitstayid AND v1.observationtime = '2105-12-29 04:56:00'
#   JOIN
#     vitalperiodic v2 ON p.patientunitstayid = v2.patientunitstayid AND v2.observationtime = '2105-12-29 05:01:00'
#   WHERE
#     p.uniquepid = '006-195316'
# )
# SELECT
#   CASE
#     WHEN second_time_hr < first_time_hr THEN 'Yes'
#     ELSE 'No'
#   END AS heart_rate_decreased
# FROM
#   heart_rate_data;
# 2025-07-27 22:49:08.643 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-27 22:49:08.644 | INFO     | __main__:run_predictions_async:14 - Processing chunk 100 to 104
# 2025-07-27 22:49:08.644 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-27 22:49:13.639 | INFO     | __main__:get_prediction:49 - Generated SQL for index 104: SELECT age
# FROM patient
# WHERE uniquepid = '006-158338';
# 2025-07-27 22:49:15.369 | INFO     | __main__:get_prediction:49 - Generated SQL for index 102: SELECT age
# FROM patient
# WHERE uniquepid = '016-35481'
# ORDER BY hospitaladmittime DESC
# LIMIT 1;
# 2025-07-27 22:49:15.786 | INFO     | __main__:get_prediction:49 - Generated SQL for index 105: SELECT age
# FROM patient
# WHERE uniquepid = '022-130563'
# ORDER BY hospitaladmittime DESC
# LIMIT 1;
# 2025-07-27 22:49:16.721 | INFO     | __main__:get_prediction:49 - Generated SQL for index 103: SELECT age
# FROM patient
# WHERE uniquepid = '003-39001'
# ORDER BY hospitaladmittime DESC
# LIMIT 1;
# 2025-07-27 22:49:17.435 | INFO     | __main__:get_prediction:49 - Generated SQL for index 101: SELECT age
# FROM patient
# WHERE uniquepid = '028-34632'
# ORDER BY hospitaladmittime DESC
# LIMIT 1;
# 2025-07-27 22:49:17.435 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-27 22:49:17.435 | INFO     | __main__:run_predictions_async:14 - Processing chunk 105 to 109
# 2025-07-27 22:49:17.436 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-27 22:49:23.804 | INFO     | __main__:get_prediction:49 - Generated SQL for index 106: SELECT age
# FROM patient
# WHERE uniquepid = '002-56583'
# ORDER BY hospitaladmittime DESC
# LIMIT 1;
# 2025-07-27 22:49:25.112 | INFO     | __main__:get_prediction:49 - Generated SQL for index 108: None
# 2025-07-27 22:49:25.703 | INFO     | __main__:get_prediction:49 - Generated SQL for index 109: None
# 2025-07-27 22:49:26.722 | INFO     | __main__:get_prediction:49 - Generated SQL for index 110: None
# 2025-07-27 22:49:27.176 | INFO     | __main__:get_prediction:49 - Generated SQL for index 107: None
# 2025-07-27 22:49:27.177 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-27 22:49:27.177 | INFO     | __main__:run_predictions_async:14 - Processing chunk 110 to 114
# 2025-07-27 22:49:27.177 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-27 22:49:34.387 | INFO     | __main__:get_prediction:49 - Generated SQL for index 113: SELECT ROUND((JULIANDAY('2105-12-31 23:59:00') - JULIANDAY(hospitaladmittime)) * 24, 2) AS hours_since_admission
# FROM patient
# WHERE uniquepid = '032-21820';
# 2025-07-27 22:49:36.241 | INFO     | __main__:get_prediction:49 - Generated SQL for index 115: SELECT JULIANDAY('2105-12-31 23:59:00') - JULIANDAY(hospitaladmittime) AS days_since_admission
# FROM patient
# WHERE uniquepid = '021-111547';
# 2025-07-27 22:49:36.636 | INFO     | __main__:get_prediction:49 - Generated SQL for index 114: SELECT julianday('2105-12-31 23:59:00') - julianday(hospitaladmittime) AS days_since_admission
# FROM patient
# WHERE uniquepid = '012-31752';
# 2025-07-27 22:49:38.744 | INFO     | __main__:get_prediction:49 - Generated SQL for index 111: WITH target_patient AS (
#     SELECT age
#     FROM patient
#     WHERE uniquepid = '030-3372'
#     ORDER BY hospitaladmittime
#     LIMIT 1
# ),
# hct_values AS (
#     SELECT l.labresult
#     FROM lab l
#     JOIN patient p ON l.patientunitstayid = p.patientunitstayid
#     JOIN target_patient tp ON p.age = tp.age
#     WHERE l.labname = 'hct' OR l.labname LIKE '%hematocrit%'
# )
# SELECT
#     (SELECT COUNT(*) FROM hct_values WHERE labresult < 27.0) * 100.0 /
#     (SELECT COUNT(*) FROM hct_values) AS percentile
# FROM dual;
# 2025-07-27 22:49:39.871 | INFO     | __main__:get_prediction:49 - Generated SQL for index 112: WITH patient_info AS (
#     SELECT age
#     FROM patient
#     WHERE uniquepid = '009-7776'
#     ORDER BY hospitaladmittime DESC
#     LIMIT 1
# ),
# bicarbonate_results AS (
#     SELECT l.labresult
#     FROM lab l
#     JOIN patient p ON l.patientunitstayid = p.patientunitstayid
#     JOIN patient_info pi ON p.age = pi.age
#     WHERE l.labname = 'bicarbonate' OR l.labname = 'hco3'
# ),
# ranked_results AS (
#     SELECT labresult,
#            PERCENT_RANK() OVER (ORDER BY labresult) AS percentile
#     FROM bicarbonate_results
# )
# SELECT ROUND(percentile * 100, 2) AS percentile
# FROM ranked_results
# WHERE labresult = 26.0
# LIMIT 1;
# 2025-07-27 22:49:39.872 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-27 22:49:39.872 | INFO     | __main__:run_predictions_async:14 - Processing chunk 115 to 119
# 2025-07-27 22:49:39.872 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-27 22:49:48.016 | INFO     | __main__:get_prediction:49 - Generated SQL for index 120: SELECT julianday('2105-12-31 23:59:00') - julianday(unitadmittime) AS days_since_icu_admission
# FROM patient
# WHERE uniquepid = '022-187132';
# 2025-07-27 22:49:50.400 | INFO     | __main__:get_prediction:49 - Generated SQL for index 118: SELECT
#     JULIANDAY('2105-12-31 23:59:00') - JULIANDAY(unitadmittime) AS days_since_admission
# FROM
#     patient
# WHERE
#     uniquepid = '004-79017';
# 2025-07-27 22:49:50.621 | INFO     | __main__:get_prediction:49 - Generated SQL for index 117: SELECT julianday('2105-12-31 23:59:00') - julianday(unitadmittime) AS days_since_admission
# FROM patient
# WHERE uniquepid = '006-80884';
# 2025-07-27 22:49:51.176 | INFO     | __main__:get_prediction:49 - Generated SQL for index 116: SELECT
#   (julianday('2105-12-31 23:59:00') - julianday(hospitaladmittime)) * 24 as hours_since_admission
# FROM
#   patient
# WHERE
#   uniquepid = '010-21105';
# 2025-07-27 22:49:51.371 | INFO     | __main__:get_prediction:49 - Generated SQL for index 119: SELECT (julianday('2105-12-31 23:59:00') - julianday(unitadmittime)) * 24 AS hours_since_icu_admission
# FROM patient
# WHERE uniquepid = '007-15837';
# 2025-07-27 22:49:51.372 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-27 22:49:51.372 | INFO     | __main__:run_predictions_async:14 - Processing chunk 120 to 124
# 2025-07-27 22:49:51.372 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-27 22:49:59.242 | INFO     | __main__:get_prediction:49 - Generated SQL for index 122: None
# 2025-07-27 22:49:59.300 | INFO     | __main__:get_prediction:49 - Generated SQL for index 125: None
# 2025-07-27 22:49:59.472 | INFO     | __main__:get_prediction:49 - Generated SQL for index 121: SELECT julianday('2105-12-31 23:59:00') - julianday(hospitaldischargetime) AS days_since_discharge
# FROM patient
# WHERE uniquepid = '016-27397' AND wardid = 613
# ORDER BY hospitaldischargetime DESC
# LIMIT 1;
# 2025-07-27 22:50:01.422 | INFO     | __main__:get_prediction:49 - Generated SQL for index 123: SELECT julianday('2105-12-31 23:59:00') - julianday(min(unitadmittime)) AS days_elapsed
# FROM patient
# WHERE uniquepid = '004-13127'
# AND wardid = 236;
# 2025-07-27 22:50:08.338 | INFO     | __main__:get_prediction:49 - Generated SQL for index 124: SELECT
# ...
#     m.drugname LIKE '%buprenorphine%' OR
#     m.drugname LIKE '%opioid%'
# )
# ORDER BY m.drugstarttime;
# 2025-07-27 23:55:20.143 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1716: SELECT m.drugname, m.dosage, m.routeadmin, m.drugstarttime, m.drugstoptime
# FROM medication m
# JOIN patient p ON m.patientunitstayid = p.patientunitstayid
# WHERE p.uniquepid = '013-33898'
# AND m.drugname IN (
#     'morphine', 'fentanyl', 'oxycodone', 'hydrocodone', 'codeine',
#     'hydromorphone', 'methadone', 'buprenorphine', 'tramadol', 'oxymorphone',
#     'tapentadol', 'meperidine', 'demerol', 'dilaudid', 'percocet', 'vicodin',
#     'norco', 'lortab', 'opana', 'duragesic', 'nucynta', 'suboxone', 'subutex',
#     'roxicodone', 'remifentanil', 'sufentanil', 'alfentanil', 'oxycontin'
# )
# ORDER BY m.drugstarttime;
# 2025-07-27 23:55:20.144 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-27 23:55:20.144 | INFO     | __main__:run_predictions_async:14 - Processing chunk 1720 to 1724
# 2025-07-27 23:55:20.144 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-27 23:55:25.165 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1721: None
# 2025-07-27 23:55:26.388 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1724: None
# 2025-07-27 23:55:26.801 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1725: None
# 2025-07-27 23:55:28.030 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1722: None
# 2025-07-27 23:55:31.744 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1723: None
# 2025-07-27 23:55:31.745 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-27 23:55:31.745 | INFO     | __main__:run_predictions_async:14 - Processing chunk 1725 to 1729
# 2025-07-27 23:55:31.746 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-27 23:55:38.347 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1728: None
# 2025-07-27 23:55:38.348 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1730: None;
# 2025-07-27 23:55:38.399 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1727: None
# 2025-07-27 23:55:40.677 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1726: None
# 2025-07-27 23:55:41.825 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1729: None
# 2025-07-27 23:55:41.826 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-27 23:55:41.826 | INFO     | __main__:run_predictions_async:14 - Processing chunk 1730 to 1734
# 2025-07-27 23:55:41.827 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-27 23:55:47.419 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1732: None
# 2025-07-27 23:55:48.169 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1731: None
# 2025-07-27 23:55:49.131 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1734: None
# 2025-07-27 23:55:50.489 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1733: None
# 2025-07-27 23:55:50.938 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1735: None
# 2025-07-27 23:55:50.938 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-27 23:55:50.939 | INFO     | __main__:run_predictions_async:14 - Processing chunk 1735 to 1739
# 2025-07-27 23:55:50.939 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-27 23:55:57.731 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1736: None
# 2025-07-27 23:55:57.917 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1737: None
# 2025-07-27 23:55:58.561 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1738: None
# 2025-07-27 23:55:59.991 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1739: None
# 2025-07-27 23:56:02.046 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1740: None
# 2025-07-27 23:56:02.047 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-27 23:56:02.047 | INFO     | __main__:run_predictions_async:14 - Processing chunk 1740 to 1744
# 2025-07-27 23:56:02.048 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-27 23:56:07.858 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1741: None
# 2025-07-27 23:56:08.086 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1743: None
# 2025-07-27 23:56:08.392 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1742: None
# 2025-07-27 23:56:09.356 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1745: None
# 2025-07-27 23:56:10.801 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1744: None
# 2025-07-27 23:56:10.802 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-27 23:56:10.802 | INFO     | __main__:run_predictions_async:14 - Processing chunk 1745 to 1749
# 2025-07-27 23:56:10.803 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-27 23:56:18.286 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1747: None
# 2025-07-27 23:56:18.368 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1746: None
# 2025-07-27 23:56:20.000 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1750: None
# 2025-07-27 23:56:20.681 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1749: None
# 2025-07-27 23:56:22.051 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1748: None
# 2025-07-27 23:56:22.052 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-27 23:56:22.053 | INFO     | __main__:run_predictions_async:14 - Processing chunk 1750 to 1754
# 2025-07-27 23:56:22.053 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-27 23:56:29.903 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1752: None
# 2025-07-27 23:56:30.468 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1755: None
# 2025-07-27 23:56:30.629 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1753: None;
# 2025-07-27 23:56:31.008 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1751: None
# 2025-07-27 23:56:32.864 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1754: None
# 2025-07-27 23:56:32.865 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-27 23:56:32.865 | INFO     | __main__:run_predictions_async:14 - Processing chunk 1755 to 1759
# 2025-07-27 23:56:32.866 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-27 23:56:40.299 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1757: None
# 2025-07-27 23:56:40.655 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1756: None
# 2025-07-27 23:56:41.297 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1758: None
# 2025-07-27 23:56:42.407 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1760: None;
# 2025-07-27 23:56:42.480 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1759: SELECT l.labname, l.labresult, l.labresulttime
# FROM lab l
# JOIN patient p ON l.patientunitstayid = p.patientunitstayid
# WHERE p.uniquepid = '028-55503'
#
# UNION
#
# SELECT m.culturesite || ' culture for ' || m.organism, NULL, m.culturetakentime
# FROM microlab m
# JOIN patient p ON m.patientunitstayid = p.patientunitstayid
# WHERE p.uniquepid = '028-55503';
# 2025-07-27 23:56:42.480 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-27 23:56:42.481 | INFO     | __main__:run_predictions_async:14 - Processing chunk 1760 to 1764
# 2025-07-27 23:56:42.481 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-27 23:56:49.916 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1765: None
# 2025-07-27 23:56:49.918 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1764: SELECT l.*
# FROM patient p
# JOIN lab l ON p.patientunitstayid = l.patientunitstayid
# WHERE p.uniquepid = '027-136480'
# AND l.labname LIKE '%sputum, expectorated%';
# 2025-07-27 23:56:52.244 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1762: None
# 2025-07-27 23:56:52.618 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1761: None
# 2025-07-27 23:56:53.990 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1763: SELECT
#     p.uniquepid,
#     t.treatmentname,
#     t.treatmenttime
# FROM
#     patient p
# JOIN
#     treatment t ON p.patientunitstayid = t.patientunitstayid
# WHERE
#     p.uniquepid = '006-80884'
#     AND (
#         t.treatmentname LIKE '%blood%'
#         OR t.treatmentname LIKE '%transfusion%'
#         OR t.treatmentname LIKE '%venipuncture%'
#     )
# ORDER BY
#     t.treatmenttime;
# 2025-07-27 23:56:53.991 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-27 23:56:53.992 | INFO     | __main__:run_predictions_async:14 - Processing chunk 1765 to 1769
# 2025-07-27 23:56:53.992 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-27 23:57:01.900 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1770: None
# 2025-07-27 23:57:02.220 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1768: None
# 2025-07-27 23:57:02.902 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1769: SELECT t.treatmentname, t.treatmenttime
# FROM patient p
# JOIN treatment t ON p.patientunitstayid = t.patientunitstayid
# WHERE p.uniquepid = '005-77687'
# AND (
#     t.treatmentname LIKE '%blood%'
#     OR t.treatmentname LIKE '%transfusion%'
#     OR t.treatmentname LIKE '%venipuncture%'
# );
# 2025-07-27 23:57:03.557 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1767: None
# 2025-07-27 23:57:03.692 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1766: SELECT m.culturesite, m.organism, m.culturetakentime
# FROM microlab m
# JOIN patient p ON m.patientunitstayid = p.patientunitstayid
# WHERE p.uniquepid = '010-20205'
# AND (m.culturesite LIKE '%sputum%' OR m.culturesite LIKE '%tracheal%')
# ORDER BY m.culturetakentime;
# 2025-07-27 23:57:03.692 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-27 23:57:03.692 | INFO     | __main__:run_predictions_async:14 - Processing chunk 1770 to 1774
# 2025-07-27 23:57:03.693 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-27 23:57:12.021 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1774: None
# 2025-07-27 23:57:12.486 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1772: None
# 2025-07-27 23:57:12.974 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1773: SELECT m.*
# FROM microlab m
# JOIN patient p ON m.patientunitstayid = p.patientunitstayid
# WHERE p.uniquepid = '010-32430'
# AND (m.culturesite LIKE '%sputum%' OR m.culturesite LIKE '%tracheal%')
# ORDER BY m.culturetakentime;
# 2025-07-27 23:57:13.681 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1775: -- Check lab tests related to urine for patient with uniquepid 009-424
# SELECT l.*
# FROM lab l
# JOIN patient p ON l.patientunitstayid = p.patientunitstayid
# WHERE p.uniquepid = '009-424'
# AND (LOWER(l.labname) LIKE '%urine%' OR LOWER(l.labname) LIKE '%void%')
#
# UNION
#
# -- Check microbiology cultures related to urine for the same patient
# SELECT m.*
# FROM microlab m
# JOIN patient p ON m.patientunitstayid = p.patientunitstayid
# WHERE p.uniquepid = '009-424'
# AND LOWER(m.culturesite) LIKE '%urine%';
# 2025-07-27 23:57:15.263 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1771: SELECT
#     'Lab Test' as test_type,
#     l.labname as test_name,
#     l.labresulttime as test_time
# FROM patient p
# JOIN lab l ON p.patientunitstayid = l.patientunitstayid
# WHERE p.uniquepid = '032-9230'
#
# UNION ALL
#
# SELECT
#     'Microbiology Culture' as test_type,
#     m.culturesite || ' - ' || m.organism as test_name,
#     m.culturetakentime as test_time
# FROM patient p
# JOIN microlab m ON p.patientunitstayid = m.patientunitstayid
# WHERE p.uniquepid = '032-9230'
#
# UNION ALL
#
# SELECT
#     'Vital Signs' as test_type,
#     'Vital measurements' as test_name,
#     v.observationtime as test_time
# FROM patient p
# JOIN vitalperiodic v ON p.patientunitstayid = v.patientunitstayid
# WHERE p.uniquepid = '032-9230'
#
# ORDER BY test_time;
# 2025-07-27 23:57:15.264 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-27 23:57:15.265 | INFO     | __main__:run_predictions_async:14 - Processing chunk 1775 to 1779
# 2025-07-27 23:57:15.265 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-27 23:57:19.746 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1780: None
# 2025-07-27 23:57:20.923 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1779: None
# 2025-07-27 23:57:21.088 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1777: None
# 2025-07-27 23:57:23.738 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1778: None
# 2025-07-27 23:57:24.052 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1776: None
# 2025-07-27 23:57:24.053 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-27 23:57:24.053 | INFO     | __main__:run_predictions_async:14 - Processing chunk 1780 to 1784
# 2025-07-27 23:57:24.054 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-27 23:57:28.130 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1782: None
# 2025-07-27 23:57:28.187 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1783: None
# 2025-07-27 23:57:29.983 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1781: None
# 2025-07-27 23:57:31.311 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1785: None
# 2025-07-27 23:57:32.931 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1784: None
# 2025-07-27 23:57:32.931 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-27 23:57:32.932 | INFO     | __main__:run_predictions_async:14 - Processing chunk 1785 to 1789
# 2025-07-27 23:57:32.932 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-27 23:57:38.218 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1790: None
# 2025-07-27 23:57:38.268 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1788: None
# 2025-07-27 23:57:38.808 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1789: None
# 2025-07-27 23:57:39.389 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1787: None
# 2025-07-27 23:57:40.373 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1786: None
# 2025-07-27 23:57:40.374 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-27 23:57:40.374 | INFO     | __main__:run_predictions_async:14 - Processing chunk 1790 to 1794
# 2025-07-27 23:57:40.374 | INFO     | __main__:run_predictions_async:18 - Sending 2 requests to the vLLM server...
# 2025-07-27 23:57:48.007 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1792: None
# 2025-07-27 23:57:49.321 | INFO     | __main__:get_prediction:49 - Generated SQL for index 1791: None
# 2025-07-27 23:57:49.322 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-27 23:57:49.339 | SUCCESS  | __main__:run_predictions_async:36 - Predictions saved to ../model_predictions/eICU/claude_3_7_sonnet_thinking/trial_0/predictions.json
# 2025-07-27 23:57:49.341 | SUCCESS  | __main__:<module>:25 - Model claude_3_7_sonnet_thinking. Trial 0 completed. Time taken: 4368.33 seconds

# %% [markdown]
# **Trial 0**:
# - Time taken:  4368.33 seconds

# %% [markdown]
# # Evaluate

# %%
import os
from utils import preprare_directory

# create output directory for evaluation results, relative to the path of model_evaluation directory
# note that the evaluate results need a clean new folder, because it will overwrite any existing files in the folder
pred_directory = f"../model_predictions/eICU/{model_name}/trial_{trial_number}"
eval_directory = os.path.join(pred_directory, "evaluation")
preprare_directory(eval_directory, exist_ok=False)

# the predicted file from previous step
pred_file = os.path.join(pred_directory, "predictions.json")

print("Using predictions from: ", pred_file)

# path to the eICU database
db_path = "../model_evaluation/databases/eicu.sqlite"
# Out:
# Using predictions from:  ../model_predictions/eICU/claude_3_7_sonnet_thinking/trial_0/predictions.json

# %%
# run evaluation
# !python ../model_evaluation/ehrsql_eval.py \
    --pred_file {pred_file} \
    --db_path {db_path} \
    --num_workers -1 \
    --timeout 60 \
    --out_file {eval_directory} \
    --ndigits 2

# %% [markdown]
# # Interpret Results

# %%
fp = f"../model_predictions/eICU/{model_name}/trial_{trial_number}/evaluation/predictions_metrics.json"

with open(fp, "r") as f:
    metrics = json.load(f)

print(json.dumps(metrics, indent=4))
# Out:
# {
#     "precision_ans": 100.0,
#     "recall_ans": 63.11,
#     "f1_ans": 77.39,
#     "precision_exec": 32.98,
#     "recall_exec": 20.81,
#     "f1_exec": 25.52,
#     "acc": 20.81
# }

# %%
from openai import OpenAI
client = OpenAI(
    api_key=os.environ['BEDROCK_OPENAI_API_KEY'],
    base_url=os.environ['BEDROCK_OPENAI_BASE_URL']
)

messages = [{"role": "user", "content": "which one is bigger, 3.9 or 3.11?"}]
response = client.chat.completions.create(
    model="us.anthropic.claude-3-7-sonnet-20250219-v1:0",
    messages=messages,
    reasoning_effort="medium",
    max_completion_tokens=4096,

)

# reasoning trace
reasoning_content = response.choices[0].message.reasoning_content

# final answer
content = response.choices[0].message.content

content
# Out:
# '3.9 is bigger than 3.11.\n\nWhen comparing decimal numbers, we need to compare the digits from left to right. Both numbers have the same whole number (3), so we look at the tenths place (first digit after the decimal point):\n\n- 3.9 has 9 in the tenths place\n- 3.11 has 1 in the tenths place\n\nSince 9 is greater than 1, 3.9 is greater than 3.11.\n\nAnother way to understand this is that 3.9 equals 3.90 when written with the same number of decimal places, and 3.90 is clearly greater than 3.11.'
