# %% [markdown]
# # eICU benchmarking with Claude

# %%
from dotenv import load_dotenv
import os
load_dotenv()

from openai import OpenAI
from loguru import logger
import sys
import json
sys.path.append(os.path.abspath(os.path.join('..', 'model_evaluation')))

# %% [markdown]
# # Set up dataset

# %%
# input test set directory
test_data_dir = "../model_evaluation/dataset/test"
test_data_fp = os.path.join(test_data_dir, "test_ehrsql_eicu_data_benchmark.json")

# try loading the test set
with open(test_data_fp, "r") as f:
    test_set = json.load(f)

print("Size of test set:", len(test_set))

print("Example of a test set item:")
print(json.dumps(test_set[0], indent=4))
# Out:
# Size of test set: 1792
# Example of a test set item:
# {
#     "index": 1,
#     "system": "Based on DDL statements, instructions, and the current date, generate a SQL query in the following sqlite to answer the question.\n If the question cannot be answered using the available tables and columns in the DDL (i.e., it is out of scope), return only: None.\nToday is 2105-12-31 23:59:00\nDDL statements:\nDROP TABLE IF EXISTS patient;\nCREATE TABLE patient    -- store patient demographics and admission information\n(\n    uniquepid VARCHAR(10) NOT NULL, -- Unique patient identifier across the system\n    patienthealthsystemstayid INT NOT NULL, -- unique identifier for a single ICU stay of a patient.\n    patientunitstayid INT NOT NULL PRIMARY KEY, -- Unique ID for the patient's ICU stay\n    gender VARCHAR(25) NOT NULL, -- Gender of the patient (\"female\" or \"male\") (lowercase)\n    age VARCHAR(10) NOT NULL, -- Age at admission (can be in years or an age category)\n    ethnicity VARCHAR(50), -- Ethnicity of the patient (e.g: \"caucasian\", \"native american\", \"hispanic\", \"african american\", \"other/unknown\", \"asian\" or null) (lowercase)\n    hospitalid INT NOT NULL, -- ID of the hospital\n    wardid INT NOT NULL, -- ID of the hospital ward/unit\n    admissionheight NUMERIC(10,2), -- Patient's height on admission (in cm)\n    admissionweight NUMERIC(10,2), -- Weight on admission (in kg)\n    dischargeweight NUMERIC(10,2), -- Weight at discharge (in kg)\n    hospitaladmittime TIMESTAMP(0) NOT NULL, -- Time patient was admitted to hospital\n    hospitaladmitsource VARCHAR(30) NOT NULL, -- Source of hospital admission (e.g., \"operating room\", \"floor\", \"other hospital\", \"emergency department\", \"direct admit\", \"step-down unit (sdu)\", \"acute care/floor\", \"recovery room\", \"icu to sdu\", \"other icu\" or \"pacu\") (lowercase)\n    unitadmittime TIMESTAMP(0) NOT NULL, -- Time of ICU admission\n    unitdischargetime TIMESTAMP(0), -- time of discharge from the ICU unit\n    hospitaldischargetime TIMESTAMP(0), -- Time of hospital discharge\n    hospitaldischargestatus VARCHAR(10) -- Discharge status (e.g., \"alive\", \"expired\" or null)\n);\n\nDROP TABLE IF EXISTS diagnosis;\nCREATE TABLE diagnosis  -- store diagnoses assigned during ICU stay\n(\n    diagnosisid INT NOT NULL PRIMARY KEY, -- Unique diagnosis record ID\n    patientunitstayid INT NOT NULL, -- ICU stay ID (FK to patient)\n    diagnosisname VARCHAR(200) NOT NULL, -- Full name of diagnosis (lowercase)\n    diagnosistime TIMESTAMP(0) NOT NULL, -- Time diagnosis was recorded\n    icd9code VARCHAR(100), -- ICD-9 code of the diagnosis\n    FOREIGN KEY(patientunitstayid) REFERENCES patient(patientunitstayid)\n);\n\nDROP TABLE IF EXISTS treatment;\nCREATE TABLE treatment  -- store treatments administered during ICU stay\n(\n    treatmentid INT NOT NULL PRIMARY KEY, -- Unique treatment record ID\n    patientunitstayid INT NOT NULL, -- ICU stay ID (FK to patient)\n    treatmentname VARCHAR(200) NOT NULL, -- Name of the treatment administered (lowercase)\n    treatmenttime TIMESTAMP(0) NOT NULL, -- Time the treatment was given\n    FOREIGN KEY(patientunitstayid) REFERENCES patient(patientunitstayid)\n);\n\nDROP TABLE IF EXISTS lab;\nCREATE TABLE lab  -- store lab test results\n(\n    labid INT NOT NULL PRIMARY KEY, -- Unique lab test result ID\n    patientunitstayid INT NOT NULL, -- ICU stay ID (FK to patient)\n    labname VARCHAR(256) NOT NULL, -- Name of the lab test (lowercase)\n    labresult NUMERIC(11,4) NOT NULL, -- Result value\n    labresulttime TIMESTAMP(0) NOT NULL, -- Time when the lab result was recorded\n    FOREIGN KEY(patientunitstayid) REFERENCES patient(patientunitstayid)\n);\n\nDROP TABLE IF EXISTS medication;\nCREATE TABLE medication  -- store medication administration records\n(\n    medicationid INT NOT NULL PRIMARY KEY, -- Unique medication record ID\n    patientunitstayid INT NOT NULL, -- ICU stay ID (FK to patient)\n    drugname VARCHAR(220) NOT NULL, -- Name of the medication (lowercase)\n    dosage VARCHAR(60) NOT ...
#     "user": "tell me the method of dextrose 5% in water (d5w) iv : 1000 ml bag intake?",
#     "real": "select distinct medication.routeadmin from medication where medication.drugname = 'dextrose 5% in water (d5w) iv : 1000 ml bag';"
# }

# %% [markdown]
# # Set up client

# %%
import asyncio
from openai import AsyncOpenAI
import json
from loguru import logger

# Initialize the AsyncOpenAI client
async_client = AsyncOpenAI(
    api_key=os.environ['BEDROCK_OPENAI_API_KEY'],
    base_url=os.environ['BEDROCK_OPENAI_BASE_URL']
)

# %%
from utils import postprocess_sql_query_from_markdown

async def get_prediction(
    record: dict, 
    model: str,
    reasoning_effort:[None, "low", "medium", "high"], 
    
    ) -> str:
    """
    Generates a SQL query for a given record asynchronously
    Args:
        record: a dictionary of Q&A pairs
        model: the model to use
        reasoning_effort: the reasoning effort to use. None means no reasoning effort. Or "low", "medium", "high"
    Returns:
        A dictionary containing the input, predict, and real fields
    """
    index = record['index']
    system = record['system']
    user = record['user']
    real = record['real']

    prompt_chat_template = [
        {
            "role": "system",
            "content": f"{system}",
        },
        {
            "role": "user",
            "content": f"{user}"
        }
    ]

    try:
        if reasoning_effort is None:
            response = await async_client.chat.completions.create(
                model=model,
                messages=prompt_chat_template,
                max_completion_tokens=512, # if no reasoning, keep at 512 same as Mistral
            )
        else:
            response = await async_client.chat.completions.create(
                model=model,
                messages=prompt_chat_template,
                max_completion_tokens=1024*2, # With reasnoning minimum is 1024. and must be greater than prompt
                reasoning_effort=reasoning_effort,
            )

        generated_sql = response.choices[0].message.content
        prediction = postprocess_sql_query_from_markdown(generated_sql)
        logger.info(f"Generated SQL for index {index}: {prediction}") 

        return {
            "index": index,
            "input": user, # user query
            "predict": prediction,  # model predicted SQL
            "real": real # ground truth SQL
        }
        
    except Exception as e:
        logger.error(f"An error occurred for index {record.get('index', 'N/A')}: {e}")
        return f"Error: {e}"

# %%
async def run_predictions_async(test_fp: str, output_fp: str, model: str, reasoning_effort: [None, "low", "medium", "high"]):
    """
    Loads a test set and runs predictions asynchronously.
    """
    # Path to the mini test set
    with open(test_fp, "r") as f:
        test_data = json.load(f)
    
    # chunk the data into 5 items at a time to avoid rate limit
    chunk_size = 5
    results = []

    for i in range(0, len(test_data), chunk_size):
        logger.info(f"Processing chunk {i} to {i+chunk_size-1}")
        chunk = test_data[i:i+chunk_size]
        tasks = [get_prediction(record = record, reasoning_effort=reasoning_effort, model=model) for record in chunk]
        
        logger.info(f"Sending {len(tasks)} requests to the vLLM server...")
        predictions = await asyncio.gather(*tasks)
        logger.success("All predictions done.")

        # add predictions to the test data by looking up the index
        for pred in predictions:
            # create a dictionary with the index and prediction
            results.append({
                "index": pred['index'],
                "input": pred['input'],
                "predict": pred['predict'], 
                "real": pred['real']
            })

    # handle if the output file does not exist
    with open(output_fp, "w") as f:
        json.dump(results, f, indent=4)

    logger.success(f"Predictions saved to {output_fp}")

# %% [markdown]
# # Generate Queries

# %%
from utils import preprare_directory
from time import time

# ======= CHANGE THIS =======
# model name 
model_name = "claude_4_sonnet_thinking"

# trial number 
trial_number = 1    

# reasoning effort. None means no reasoning effort. Or "low", "medium", "high"
reasoning_effort = "medium"

# model to use
model = "us.anthropic.claude-sonnet-4-20250514-v1:0"
# model = "us.anthropic.claude-3-7-sonnet-20250219-v1:0"

# ======= CHANGE THIS END =======

# %%
# create output directory. set exist_ok=False to delete the old results and re-create a fresh folder
output_dir = f"../model_predictions/eICU/{model_name}/trial_{trial_number}"    
preprare_directory(output_dir, exist_ok=False)
#

# run predictions
start_time = time()
# run predictions
await run_predictions_async(
    test_fp = test_data_fp,
    output_fp = os.path.join(output_dir, "predictions.json"), 
    reasoning_effort = reasoning_effort, 
    model = model
)
end_time = time()
logger.success(f"Model {model_name}. Trial {trial_number} completed. Time taken: {end_time - start_time:.2f} seconds")
# Out:
# 2025-07-28 20:52:12.835 | INFO     | __main__:run_predictions_async:14 - Processing chunk 0 to 4
# 2025-07-28 20:52:12.836 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-28 20:52:16.845 | INFO     | __main__:get_prediction:51 - Generated SQL for index 2: SELECT DISTINCT routeadmin
# FROM medication
# WHERE drugname LIKE '%clonidine%';
# 2025-07-28 20:52:17.152 | INFO     | __main__:get_prediction:51 - Generated SQL for index 5: SELECT DISTINCT routeadmin
# FROM medication
# WHERE drugname = 'zolpidem tartrate 5 mg po tabs';
# 2025-07-28 20:52:17.891 | INFO     | __main__:get_prediction:51 - Generated SQL for index 4: SELECT DISTINCT routeadmin
# FROM medication
# WHERE drugname = 'propofol 1000 mg/100 ml (pmx)';
# 2025-07-28 20:52:19.731 | INFO     | __main__:get_prediction:51 - Generated SQL for index 3: SELECT DISTINCT routeadmin
# FROM medication
# WHERE drugname LIKE '%morphine%'
# AND (dosage LIKE '%2 mg%' OR dosage LIKE '%1 ml%' OR dosage LIKE '%syr%');
# 2025-07-28 20:52:20.792 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1: SELECT DISTINCT routeadmin, dosage
# FROM medication
# WHERE LOWER(drugname) LIKE '%dextrose 5%'
#    OR LOWER(drugname) LIKE '%d5w%'
#    AND (LOWER(dosage) LIKE '%1000%ml%' OR LOWER(dosage) LIKE '%1000%bag%');
# 2025-07-28 20:52:20.792 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-28 20:52:20.792 | INFO     | __main__:run_predictions_async:14 - Processing chunk 5 to 9
# 2025-07-28 20:52:20.793 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-28 20:52:25.624 | INFO     | __main__:get_prediction:51 - Generated SQL for index 6: SELECT DISTINCT routeadmin
# FROM medication
# WHERE drugname LIKE '%vancomycin%'
# AND dosage LIKE '%1,000 mg%' OR dosage LIKE '%1000 mg%';
# 2025-07-28 20:52:26.910 | INFO     | __main__:get_prediction:51 - Generated SQL for index 9: SELECT c.cost
# FROM cost c
# JOIN treatment t ON c.eventid = t.treatmentid
# WHERE c.eventtype = 'treatment'
# AND t.treatmentname = 'thoracoscopic procedure - wedge resection';
# 2025-07-28 20:52:27.943 | INFO     | __main__:get_prediction:51 - Generated SQL for index 7: SELECT c.cost
# FROM treatment t
# JOIN cost c ON t.treatmentid = c.eventid AND c.eventtype = 'treatment'
# WHERE t.treatmentname = 'internal fixation';
# 2025-07-28 20:52:28.052 | INFO     | __main__:get_prediction:51 - Generated SQL for index 8: SELECT c.cost
# FROM cost c
# JOIN treatment t ON c.eventid = t.treatmentid
# WHERE c.eventtype = 'treatment'
# AND (t.treatmentname LIKE '%angiography%' AND t.treatmentname LIKE '%pulmonary%');
# 2025-07-28 20:52:29.721 | INFO     | __main__:get_prediction:51 - Generated SQL for index 10: SELECT c.cost
# FROM treatment t
# JOIN cost c ON t.treatmentid = c.eventid AND c.eventtype = 'treatment'
# WHERE t.treatmentname = 'insertion of venous catheter for hemodialysis - percutaneous catheter';
# 2025-07-28 20:52:29.722 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-28 20:52:29.722 | INFO     | __main__:run_predictions_async:14 - Processing chunk 10 to 14
# 2025-07-28 20:52:29.723 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-28 20:52:36.504 | INFO     | __main__:get_prediction:51 - Generated SQL for index 15: SELECT c.cost
# FROM cost c
# JOIN medication m ON c.eventid = m.medicationid
# WHERE c.eventtype = 'medication'
# AND (m.drugname LIKE '%nitroglycerin%' AND m.routeadmin = 'po');
# 2025-07-28 20:52:36.523 | INFO     | __main__:get_prediction:51 - Generated SQL for index 13: SELECT c.cost
# FROM medication m
# JOIN patient p ON m.patientunitstayid = p.patientunitstayid
# JOIN cost c ON c.patienthealthsystemstayid = p.patienthealthsystemstayid
#     AND c.eventtype = 'medication'
#     AND c.eventid = m.medicationid
# WHERE m.drugname LIKE '%hydralazine%';
# 2025-07-28 20:52:36.644 | INFO     | __main__:get_prediction:51 - Generated SQL for index 11: SELECT c.cost
# FROM treatment t
# JOIN cost c ON t.treatmentid = c.eventid
# WHERE t.treatmentname = 'focussed abdominal sonography'
# AND c.eventtype = 'treatment';
# 2025-07-28 20:52:37.087 | INFO     | __main__:get_prediction:51 - Generated SQL for index 12: SELECT
#     m.drugname,
#     c.cost,
#     c.chargetime
# FROM medication m
# JOIN cost c ON m.medicationid = c.eventid
# WHERE c.eventtype = 'medication'
#     AND (m.drugname LIKE '%bronchodilator%' OR m.drugname LIKE '%beta-agonist%')
# ORDER BY c.cost DESC;
# 2025-07-28 20:52:37.358 | INFO     | __main__:get_prediction:51 - Generated SQL for index 14: SELECT
#     (SELECT c.cost
#      FROM medication m
#      JOIN cost c ON m.medicationid = c.eventid AND c.eventtype = 'medication'
#      WHERE m.drugname LIKE '%bicarbonate%' AND m.drugname NOT LIKE '%sodium bicarbonate%'
#      LIMIT 1) -
#     (SELECT c.cost
#      FROM medication m
#      JOIN cost c ON m.medicationid = c.eventid AND c.eventtype = 'medication'
#      WHERE m.drugname LIKE '%sodium bicarbonate%'
#      LIMIT 1) AS price_difference;
# 2025-07-28 20:52:37.358 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-28 20:52:37.358 | INFO     | __main__:run_predictions_async:14 - Processing chunk 15 to 19
# 2025-07-28 20:52:37.358 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-28 20:52:42.759 | INFO     | __main__:get_prediction:51 - Generated SQL for index 18: SELECT SUM(c.cost) as total_cost
# FROM lab l
# JOIN cost c ON l.labid = c.eventid AND c.eventtype = 'lab'
# WHERE l.labname LIKE '%co2%';
# 2025-07-28 20:52:43.706 | INFO     | __main__:get_prediction:51 - Generated SQL for index 17: SELECT SUM(c.cost) as total_folate_cost
# FROM lab l
# JOIN cost c ON l.labid = c.eventid
# WHERE l.labname LIKE '%folate%'
# AND c.eventtype = 'lab';
# 2025-07-28 20:52:43.883 | INFO     | __main__:get_prediction:51 - Generated SQL for index 16: SELECT c.cost
# FROM cost c
# JOIN lab l ON c.eventid = l.labid
# WHERE c.eventtype = 'lab'
# AND l.labname LIKE '%methemoglobin%';
# 2025-07-28 20:52:43.988 | INFO     | __main__:get_prediction:51 - Generated SQL for index 19: SELECT c.cost
# FROM lab l
# JOIN cost c ON l.labid = c.eventid AND c.eventtype = 'lab'
# WHERE l.labname LIKE '%ph%';
# 2025-07-28 20:52:46.327 | INFO     | __main__:get_prediction:51 - Generated SQL for index 20: SELECT DISTINCT c.cost
# FROM cost c
# WHERE c.eventtype = 'lab'
#   AND c.eventid IN (
#     SELECT labid
#     FROM lab
#     WHERE labname LIKE '%-basos%'
#   )
# UNION
# SELECT DISTINCT c.cost
# FROM cost c
# WHERE c.eventtype = 'medication'
#   AND c.eventid IN (
#     SELECT medicationid
#     FROM medication
#     WHERE drugname LIKE '%-basos%'
#   )
# UNION
# SELECT DISTINCT c.cost
# FROM cost c
# WHERE c.eventtype = 'treatment'
#   AND c.eventid IN (
#     SELECT treatmentid
#     FROM treatment
#     WHERE treatmentname LIKE '%-basos%'
#   )
# UNION
# SELECT DISTINCT c.cost
# FROM cost c
# WHERE c.eventtype = 'diagnosis'
#   AND c.eventid IN (
#     SELECT diagnosisid
#     FROM diagnosis
#     WHERE diagnosisname LIKE '%-basos%'
#   );
# 2025-07-28 20:52:46.328 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-28 20:52:46.328 | INFO     | __main__:run_predictions_async:14 - Processing chunk 20 to 24
# 2025-07-28 20:52:46.329 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-28 20:52:52.310 | INFO     | __main__:get_prediction:51 - Generated SQL for index 24: SELECT c.cost
# FROM cost c
# JOIN medication m ON c.eventid = m.medicationid
# WHERE c.eventtype = 'medication'
# AND m.drugname = 'aspirin 81 mg chewable tablet';
# 2025-07-28 20:52:52.386 | INFO     | __main__:get_prediction:51 - Generated SQL for index 21: SELECT c.cost
# FROM treatment t
# JOIN cost c ON t.treatmentid = c.eventid
# WHERE t.treatmentname = 'vent other'
# AND c.eventtype = 'treatment';
# 2025-07-28 20:52:52.467 | INFO     | __main__:get_prediction:51 - Generated SQL for index 25: SELECT c.cost
# FROM medication m
# JOIN cost c ON m.medicationid = c.eventid
# WHERE m.drugname = 'milk of magnesia ud liq 30 ml'
# AND c.eventtype = 'medication';
# 2025-07-28 20:52:52.548 | INFO     | __main__:get_prediction:51 - Generated SQL for index 22: SELECT c.cost
# FROM cost c
# WHERE (c.eventtype = 'lab' AND c.eventid IN (
#     SELECT labid FROM lab WHERE labname LIKE '%chloride%'
# )) OR (c.eventtype = 'medication' AND c.eventid IN (
#     SELECT medicationid FROM medication WHERE drugname LIKE '%chloride%'
# ));
# 2025-07-28 20:52:52.824 | INFO     | __main__:get_prediction:51 - Generated SQL for index 23: SELECT c.cost
# FROM medication m
# JOIN cost c ON m.medicationid = c.eventid
# WHERE m.drugname LIKE '%klonopin%'
# AND c.eventtype = 'medication';
# 2025-07-28 20:52:52.824 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-28 20:52:52.824 | INFO     | __main__:run_predictions_async:14 - Processing chunk 25 to 29
# 2025-07-28 20:52:52.825 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-28 20:52:57.453 | INFO     | __main__:get_prediction:51 - Generated SQL for index 28: SELECT c.cost
# FROM medication m
# JOIN cost c ON m.medicationid = c.eventid AND c.eventtype = 'medication'
# WHERE m.drugname LIKE '%sodium chloride 0.9%';
# 2025-07-28 20:52:57.705 | INFO     | __main__:get_prediction:51 - Generated SQL for index 27: SELECT DISTINCT c.cost
# FROM medication m
# JOIN cost c ON m.medicationid = c.eventid
# WHERE LOWER(m.drugname) LIKE '%cephulac%'
# AND c.eventtype = 'medication';
# 2025-07-28 20:52:59.303 | INFO     | __main__:get_prediction:51 - Generated SQL for index 26: SELECT c.cost
# FROM medication m
# JOIN cost c ON m.medicationid = c.eventid
# WHERE c.eventtype = 'medication'
# AND m.drugname = '4 ml vial: furosemide 10 mg/ml ij soln';
# 2025-07-28 20:52:59.622 | INFO     | __main__:get_prediction:51 - Generated SQL for index 29: SELECT c.cost
# FROM medication m
# JOIN cost c ON m.medicationid = c.eventid
# WHERE LOWER(m.drugname) LIKE '%epinephrine%'
# AND c.eventtype = 'medication';
# 2025-07-28 20:53:00.672 | INFO     | __main__:get_prediction:51 - Generated SQL for index 30: SELECT AVG(c.cost) as average_cost, MIN(c.cost) as min_cost, MAX(c.cost) as max_cost, COUNT(*) as count
# FROM diagnosis d
# JOIN cost c ON d.diagnosisid = c.eventid
# WHERE (d.diagnosisname LIKE '%oral thrush%' OR d.diagnosisname LIKE '%candidiasis%' OR d.diagnosisname LIKE '%thrush%')
# AND c.eventtype = 'diagnosis';
# 2025-07-28 20:53:00.672 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-28 20:53:00.673 | INFO     | __main__:run_predictions_async:14 - Processing chunk 30 to 34
# 2025-07-28 20:53:00.673 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-28 20:53:06.305 | INFO     | __main__:get_prediction:51 - Generated SQL for index 34: SELECT c.cost
# FROM cost c
# JOIN diagnosis d ON c.eventid = d.diagnosisid
# WHERE c.eventtype = 'diagnosis'
# AND d.diagnosisname = 'acute lung injury - etiology unknown';
# 2025-07-28 20:53:06.675 | INFO     | __main__:get_prediction:51 - Generated SQL for index 31: SELECT c.cost
# FROM diagnosis d
# JOIN cost c ON d.diagnosisid = c.eventid
# WHERE d.diagnosisname = 'benzodiazepine overdose - with decreased mental status'
# AND c.eventtype = 'diagnosis';
# 2025-07-28 20:53:07.120 | INFO     | __main__:get_prediction:51 - Generated SQL for index 35: SELECT c.cost
# FROM diagnosis d
# JOIN cost c ON d.diagnosisid = c.eventid
# WHERE d.diagnosisname = 'coronary artery disease - known'
# AND c.eventtype = 'diagnosis';
# 2025-07-28 20:53:07.178 | INFO     | __main__:get_prediction:51 - Generated SQL for index 32: SELECT c.cost
# FROM diagnosis d
# JOIN cost c ON d.diagnosisid = c.eventid
# WHERE d.diagnosisname = 'acute respiratory distress - etiology unknown'
# AND c.eventtype = 'diagnosis';
# 2025-07-28 20:53:08.112 | INFO     | __main__:get_prediction:51 - Generated SQL for index 33: SELECT c.cost
# FROM diagnosis d
# JOIN cost c ON d.diagnosisid = c.eventid
# WHERE d.diagnosisname LIKE '%acute pulmonary edema%'
# AND c.eventtype = 'diagnosis';
# 2025-07-28 20:53:08.112 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-28 20:53:08.113 | INFO     | __main__:run_predictions_async:14 - Processing chunk 35 to 39
# 2025-07-28 20:53:08.113 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-28 20:53:10.392 | INFO     | __main__:get_prediction:51 - Generated SQL for index 38: SELECT gender
# FROM patient
# WHERE uniquepid = '015-66570';
# 2025-07-28 20:53:10.717 | INFO     | __main__:get_prediction:51 - Generated SQL for index 40: SELECT gender
# FROM patient
# WHERE uniquepid = '006-227759';
# 2025-07-28 20:53:11.216 | INFO     | __main__:get_prediction:51 - Generated SQL for index 37: SELECT gender
# FROM patient
# WHERE uniquepid = '028-40370';
# 2025-07-28 20:53:11.345 | INFO     | __main__:get_prediction:51 - Generated SQL for index 39: SELECT gender
# FROM patient
# WHERE uniquepid = '015-76706';
# 2025-07-28 20:53:14.389 | INFO     | __main__:get_prediction:51 - Generated SQL for index 36: SELECT c.cost
# FROM diagnosis d
# JOIN cost c ON d.diagnosisid = c.eventid
# WHERE d.diagnosisname = 'pacemaker/aicd dysfunction'
# AND c.eventtype = 'diagnosis';
# 2025-07-28 20:53:14.390 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-28 20:53:14.390 | INFO     | __main__:run_predictions_async:14 - Processing chunk 40 to 44
# 2025-07-28 20:53:14.390 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-28 20:53:18.950 | INFO     | __main__:get_prediction:51 - Generated SQL for index 41: SELECT
#     JULIANDAY(hospitaldischargetime) - JULIANDAY(hospitaladmittime) AS length_of_stay_days
# FROM patient
# WHERE uniquepid = '006-146580'
# ORDER BY hospitaladmittime DESC
# LIMIT 1;
# 2025-07-28 20:53:19.197 | INFO     | __main__:get_prediction:51 - Generated SQL for index 44: SELECT
#     hospitaladmittime,
#     hospitaldischargetime,
#     (julianday(hospitaldischargetime) - julianday(hospitaladmittime)) AS stay_duration_days
# FROM patient
# WHERE uniquepid = '015-75226'
# ORDER BY hospitaladmittime
# LIMIT 1;
# 2025-07-28 20:53:20.021 | INFO     | __main__:get_prediction:51 - Generated SQL for index 42: SELECT
#     hospitaldischargetime - hospitaladmittime as hospital_stay_length
# FROM patient
# WHERE uniquepid = '002-52932'
# ORDER BY hospitaladmittime DESC
# LIMIT 1;
# 2025-07-28 20:53:20.800 | INFO     | __main__:get_prediction:51 - Generated SQL for index 43: SELECT julianday(hospitaldischargetime) - julianday(hospitaladmittime) as stay_duration_days
# FROM patient
# WHERE uniquepid = '028-47306'
# ORDER BY hospitaladmittime DESC
# LIMIT 1;
# 2025-07-28 20:53:20.865 | INFO     | __main__:get_prediction:51 - Generated SQL for index 45: SELECT
#     hospitaladmittime,
#     hospitaldischargetime,
#     ROUND((julianday(hospitaldischargetime) - julianday(hospitaladmittime)), 2) AS duration_days
# FROM patient
# WHERE uniquepid = '006-65780'
# ORDER BY hospitaladmittime DESC
# LIMIT 1;
# 2025-07-28 20:53:20.865 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-28 20:53:20.866 | INFO     | __main__:run_predictions_async:14 - Processing chunk 45 to 49
# 2025-07-28 20:53:20.866 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-28 20:53:25.903 | INFO     | __main__:get_prediction:51 - Generated SQL for index 47: SELECT
#     hospitaldischargetime - hospitaladmittime AS los
# FROM patient
# WHERE uniquepid = '016-5052'
# ORDER BY hospitaladmittime ASC
# LIMIT 1;
# 2025-07-28 20:53:26.302 | INFO     | __main__:get_prediction:51 - Generated SQL for index 48: SELECT
#     hospitaldischargetime - hospitaladmittime as length_of_stay
# FROM patient
# WHERE uniquepid = '017-101310'
# ORDER BY hospitaladmittime ASC
# LIMIT 1;
# 2025-07-28 20:53:26.337 | INFO     | __main__:get_prediction:51 - Generated SQL for index 50: SELECT
#     (julianday(hospitaldischargetime) - julianday(hospitaladmittime)) AS los_days
# FROM patient
# WHERE uniquepid = '032-32248'
# ORDER BY hospitaladmittime DESC
# LIMIT 1;
# 2025-07-28 20:53:26.715 | INFO     | __main__:get_prediction:51 - Generated SQL for index 46: SELECT
#     hospitaldischargetime - hospitaladmittime AS hospital_stay_duration
# FROM patient
# WHERE uniquepid = '017-74343'
# ORDER BY hospitaladmittime DESC
# LIMIT 1;
# 2025-07-28 20:53:26.943 | INFO     | __main__:get_prediction:51 - Generated SQL for index 49: SELECT
#     uniquepid,
#     hospitaladmittime,
#     hospitaldischargetime,
#     (julianday(hospitaldischargetime) - julianday(hospitaladmittime)) AS length_of_stay_days
# FROM patient
# WHERE uniquepid = '011-58352'
# ORDER BY hospitaladmittime DESC
# LIMIT 1;
# 2025-07-28 20:53:26.944 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-28 20:53:26.944 | INFO     | __main__:run_predictions_async:14 - Processing chunk 50 to 54
# 2025-07-28 20:53:26.944 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-28 20:53:31.484 | INFO     | __main__:get_prediction:51 - Generated SQL for index 51: SELECT
#     uniquepid,
#     hospitaladmittime,
#     hospitaldischargetime,
#     JULIANDAY(hospitaldischargetime) - JULIANDAY(hospitaladmittime) AS los_days
# FROM patient
# WHERE uniquepid = '016-1459'
# ORDER BY hospitaladmittime DESC
# LIMIT 1;
# 2025-07-28 20:53:31.486 | INFO     | __main__:get_prediction:51 - Generated SQL for index 54: SELECT
#     julianday(hospitaldischargetime) - julianday(hospitaladmittime) AS length_of_stay_days
# FROM patient
# WHERE uniquepid = '006-245995'
# ORDER BY hospitaladmittime ASC
# LIMIT 1;
# 2025-07-28 20:53:31.634 | INFO     | __main__:get_prediction:51 - Generated SQL for index 52: SELECT
#     (hospitaldischargetime - hospitaladmittime) AS los
# FROM patient
# WHERE uniquepid = '027-107035'
# ORDER BY hospitaladmittime ASC
# LIMIT 1;
# 2025-07-28 20:53:32.991 | INFO     | __main__:get_prediction:51 - Generated SQL for index 53: SELECT
#     uniquepid,
#     hospitaladmittime,
#     hospitaldischargetime,
#     CASE
#         WHEN hospitaldischargetime IS NOT NULL THEN
#             ROUND((julianday(hospitaldischargetime) - julianday(hospitaladmittime)), 2)
#         ELSE NULL
#     END AS los_days
# FROM patient
# WHERE uniquepid = '035-22706'
# ORDER BY hospitaladmittime DESC
# LIMIT 1;
# 2025-07-28 20:53:33.951 | INFO     | __main__:get_prediction:51 - Generated SQL for index 55: SELECT
#     uniquepid,
#     patienthealthsystemstayid,
#     hospitaladmittime,
#     hospitaldischargetime,
#     (hospitaldischargetime - hospitaladmittime) AS los
# FROM patient
# WHERE uniquepid = '025-37141'
# ORDER BY hospitaladmittime ASC
# LIMIT 1;
# 2025-07-28 20:53:33.952 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-28 20:53:33.953 | INFO     | __main__:run_predictions_async:14 - Processing chunk 55 to 59
# 2025-07-28 20:53:33.953 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-28 20:53:40.961 | INFO     | __main__:get_prediction:51 - Generated SQL for index 56: SELECT
#     (dischargeweight - admissionweight) as weight_difference
# FROM patient
# WHERE uniquepid = '018-47575'
# AND hospitaladmittime = (
#     SELECT MAX(hospitaladmittime)
#     FROM patient
#     WHERE uniquepid = '018-47575'
# );
# 2025-07-28 20:53:41.122 | INFO     | __main__:get_prediction:51 - Generated SQL for index 59: SELECT
#     (SELECT io2.cellvaluenumeric
#      FROM patient p2
#      JOIN intakeoutput io2 ON p2.patientunitstayid = io2.patientunitstayid
#      WHERE p2.uniquepid = '021-240586'
#      AND io2.intakeoutputtime = '2101-12-16 20:24:00'
#      AND (io2.celllabel LIKE '%weight%' OR io2.cellpath LIKE '%weight%')) -
#     (SELECT io1.cellvaluenumeric
#      FROM patient p1
#      JOIN intakeoutput io1 ON p1.patientunitstayid = io1.patientunitstayid
#      WHERE p1.uniquepid = '021-240586'
#      AND io1.intakeoutputtime = '2101-10-12 15:58:00'
#      AND (io1.celllabel LIKE '%weight%' OR io1.cellpath LIKE '%weight%')) AS weight_variation;
# 2025-07-28 20:53:41.381 | INFO     | __main__:get_prediction:51 - Generated SQL for index 57: SELECT dischargeweight - admissionweight as weight_change
# FROM patient
# WHERE uniquepid = '010-12376'
# AND hospitaladmittime = (
#     SELECT MIN(hospitaladmittime)
#     FROM patient
#     WHERE uniquepid = '010-12376'
# );
# 2025-07-28 20:53:42.087 | INFO     | __main__:get_prediction:51 - Generated SQL for index 58: WITH patient_visits AS (
#   SELECT patienthealthsystemstayid, patientunitstayid
#   FROM patient
#   WHERE uniquepid = '006-161415'
#   ORDER BY patienthealthsystemstayid
#   LIMIT 1
# ),
# weight_measurements AS (
#   SELECT io.cellvaluenumeric as weight, io.intakeoutputtime
#   FROM intakeoutput io
#   JOIN patient_visits pv ON io.patientunitstayid = pv.patientunitstayid
#   WHERE LOWER(io.celllabel) LIKE '%weight%' OR LOWER(io.cellpath) LIKE '%weight%'
#   ORDER BY io.intakeoutputtime DESC
# ),
# ranked_weights AS (
#   SELECT weight, intakeoutputtime,
#          ROW_NUMBER() OVER (ORDER BY intakeoutputtime DESC) as rn
#   FROM weight_measurements
# )
# SELECT
#   (SELECT weight FROM ranked_weights WHERE rn = 1) -
#   (SELECT weight FROM ranked_weights WHERE rn = 2) as weight_change
# FROM ranked_weights
# LIMIT 1;
# 2025-07-28 20:53:43.687 | INFO     | __main__:get_prediction:51 - Generated SQL for index 60: WITH first_visit AS (
#     SELECT patientunitstayid
#     FROM patient
#     WHERE uniquepid = '021-49416'
#     ORDER BY hospitaladmittime
#     LIMIT 1
# ),
# weight_measurements AS (
#     SELECT
#         cellvaluenumeric as weight_value,
#         intakeoutputtime,
#         ROW_NUMBER() OVER (ORDER BY intakeoutputtime) as measurement_order
#     FROM intakeoutput i
#     JOIN first_visit f ON i.patientunitstayid = f.patientunitstayid
#     WHERE LOWER(celllabel) LIKE '%weight%'
#     ORDER BY intakeoutputtime
# )
# SELECT
#     (SELECT weight_value FROM weight_measurements WHERE measurement_order = 2) -
#     (SELECT weight_value FROM weight_measurements WHERE measurement_order = 1) as weight_shift
# FROM weight_measurements
# LIMIT 1;
# 2025-07-28 20:53:43.688 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-28 20:53:43.688 | INFO     | __main__:run_predictions_async:14 - Processing chunk 60 to 64
# 2025-07-28 20:53:43.689 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-28 20:53:50.024 | INFO     | __main__:get_prediction:51 - Generated SQL for index 65: SELECT
#     dischargeweight - admissionweight as weight_difference
# FROM patient
# WHERE uniquepid = '007-9115'
#     AND hospitaladmittime = (
#         SELECT MIN(hospitaladmittime)
#         FROM patient
#         WHERE uniquepid = '007-9115'
#     );
# 2025-07-28 20:53:51.014 | INFO     | __main__:get_prediction:51 - Generated SQL for index 62: None
# 2025-07-28 20:53:51.094 | INFO     | __main__:get_prediction:51 - Generated SQL for index 63: SELECT
#     (p.dischargeweight - p.admissionweight) AS weight_difference
# FROM patient p
# WHERE p.uniquepid = '007-13494'
#     AND p.hospitaladmittime = (
#         SELECT MIN(hospitaladmittime)
#         FROM patient
#         WHERE uniquepid = '007-13494'
#     );
# 2025-07-28 20:53:52.179 | INFO     | __main__:get_prediction:51 - Generated SQL for index 61: SELECT
#     p.dischargeweight - p.admissionweight AS weight_change
# FROM patient p
# WHERE p.uniquepid = '006-202970'
#     AND p.dischargeweight IS NOT NULL
#     AND p.admissionweight IS NOT NULL;
# 2025-07-28 20:53:53.589 | INFO     | __main__:get_prediction:51 - Generated SQL for index 64: WITH first_visit AS (
#     SELECT MIN(patienthealthsystemstayid) as first_stay_id
#     FROM patient
#     WHERE uniquepid = '006-161415'
# ),
# weight_measurements AS (
#     SELECT io.cellvaluenumeric as weight_value,
#            io.intakeoutputtime,
#            ROW_NUMBER() OVER (ORDER BY io.intakeoutputtime DESC) as rn
#     FROM intakeoutput io
#     INNER JOIN patient p ON io.patientunitstayid = p.patientunitstayid
#     INNER JOIN first_visit fv ON p.patienthealthsystemstayid = fv.first_stay_id
#     WHERE LOWER(io.celllabel) LIKE '%weight%'
#        OR LOWER(io.cellpath) LIKE '%weight%'
# ),
# last_two_weights AS (
#     SELECT weight_value, rn
#     FROM weight_measurements
#     WHERE rn IN (1, 2)
# )
# SELECT
#     (SELECT weight_value FROM last_two_weights WHERE rn = 1) -
#     (SELECT weight_value FROM last_two_weights WHERE rn = 2) as weight_change
# FROM last_two_weights
# LIMIT 1;
# 2025-07-28 20:53:53.590 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-28 20:53:53.590 | INFO     | __main__:run_predictions_async:14 - Processing chunk 65 to 69
# 2025-07-28 20:53:53.590 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-28 20:54:01.018 | INFO     | __main__:get_prediction:51 - Generated SQL for index 67: WITH current_visit AS (
#     SELECT patienthealthsystemstayid
#     FROM patient
#     WHERE uniquepid = '006-195316'
#     ORDER BY hospitaladmittime DESC
#     LIMIT 1
# ),
# creatinine_results AS (
#     SELECT l.labresult, l.labresulttime,
#            ROW_NUMBER() OVER (ORDER BY l.labresulttime DESC) as rn
#     FROM lab l
#     JOIN patient p ON l.patientunitstayid = p.patientunitstayid
#     JOIN current_visit cv ON p.patienthealthsystemstayid = cv.patienthealthsystemstayid
#     WHERE LOWER(l.labname) LIKE '%creatinine%'
# )
# SELECT
#     (SELECT labresult FROM creatinine_results WHERE rn = 1) -
#     (SELECT labresult FROM creatinine_results WHERE rn = 2) as creatinine_difference
# FROM creatinine_results
# LIMIT 1;
# 2025-07-28 20:54:02.541 | INFO     | __main__:get_prediction:51 - Generated SQL for index 68: WITH patient_current_visit AS (
#     SELECT patientunitstayid, patienthealthsystemstayid
#     FROM patient
#     WHERE uniquepid = '035-24054'
#     AND patienthealthsystemstayid = (
#         SELECT MAX(patienthealthsystemstayid)
#         FROM patient
#         WHERE uniquepid = '035-24054'
#     )
# ),
# hgb_values AS (
#     SELECT l.labresult, l.labresulttime,
#            ROW_NUMBER() OVER (ORDER BY l.labresulttime) as measurement_order
#     FROM lab l
#     JOIN patient_current_visit p ON l.patientunitstayid = p.patientunitstayid
#     WHERE LOWER(l.labname) LIKE '%hgb%' OR LOWER(l.labname) LIKE '%hemoglobin%'
# )
# SELECT
#     (SELECT labresult FROM hgb_values WHERE measurement_order = 2) -
#     (SELECT labresult FROM hgb_values WHERE measurement_order = 1) as hgb_change
# FROM hgb_values
# WHERE measurement_order <= 2
# LIMIT 1;
# 2025-07-28 20:54:02.789 | INFO     | __main__:get_prediction:51 - Generated SQL for index 70: WITH last_visit AS (
#   SELECT MAX(patienthealthsystemstayid) as last_stay_id
#   FROM patient
#   WHERE uniquepid = '005-68848'
# ),
# sodium_levels AS (
#   SELECT l.labresult, l.labresulttime
#   FROM lab l
#   JOIN patient p ON l.patientunitstayid = p.patientunitstayid
#   JOIN last_visit lv ON p.patienthealthsystemstayid = lv.last_stay_id
#   WHERE LOWER(l.labname) LIKE '%sodium%'
#   ORDER BY l.labresulttime
# )
# SELECT
#   (SELECT labresult FROM sodium_levels ORDER BY labresulttime DESC LIMIT 1) -
#   (SELECT labresult FROM sodium_levels ORDER BY labresulttime ASC LIMIT 1) as sodium_difference;
# 2025-07-28 20:54:03.034 | INFO     | __main__:get_prediction:51 - Generated SQL for index 66: WITH first_visit AS (
#     SELECT patientunitstayid
#     FROM patient
#     WHERE uniquepid = '006-146580'
#     ORDER BY hospitaladmittime ASC
#     LIMIT 1
# ),
# weight_measurements AS (
#     SELECT cellvaluenumeric, intakeoutputtime,
#            ROW_NUMBER() OVER (ORDER BY intakeoutputtime ASC) as rn
#     FROM intakeoutput i
#     JOIN first_visit f ON i.patientunitstayid = f.patientunitstayid
#     WHERE LOWER(celllabel) LIKE '%weight%'
# )
# SELECT
#     (SELECT cellvaluenumeric FROM weight_measurements WHERE rn = 2) -
#     (SELECT cellvaluenumeric FROM weight_measurements WHERE rn = 1) as weight_difference;
# 2025-07-28 20:54:05.603 | INFO     | __main__:get_prediction:51 - Generated SQL for index 69: SELECT
#     (SELECT labresult
#      FROM lab l2
#      WHERE l2.patientunitstayid IN (
#          SELECT patientunitstayid
#          FROM patient
#          WHERE uniquepid = '010-37499'
#          AND patienthealthsystemstayid = (
#              SELECT MIN(patienthealthsystemstayid)
#              FROM patient
#              WHERE uniquepid = '010-37499'
#          )
#      )
#      AND LOWER(l2.labname) LIKE '%hct%'
#      ORDER BY l2.labresulttime DESC
#      LIMIT 1
#     ) -
#     (SELECT labresult
#      FROM lab l1
#      WHERE l1.patientunitstayid IN (
#          SELECT patientunitstayid
#          FROM patient
#          WHERE uniquepid = '010-37499'
#          AND patienthealthsystemstayid = (
#              SELECT MIN(patienthealthsystemstayid)
#              FROM patient
#              WHERE uniquepid = '010-37499'
#          )
#      )
#      AND LOWER(l1.labname) LIKE '%hct%'
#      ORDER BY l1.labresulttime ASC
#      LIMIT 1
#     ) AS hct_difference;
# 2025-07-28 20:54:05.603 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-28 20:54:05.604 | INFO     | __main__:run_predictions_async:14 - Processing chunk 70 to 74
# 2025-07-28 20:54:05.604 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-28 20:54:13.024 | INFO     | __main__:get_prediction:51 - Generated SQL for index 73: Looking at the available tables and columns in the DDL, I don't see PEEP (Positive End-Expiratory Pressure) measurements stored in any of the tables. PEEP is a ventilator setting that would typically be found in a respiratory monitoring or ventilator settings table, but such a table is not included in the provided schema.
#
# None;
# 2025-07-28 20:54:14.062 | INFO     | __main__:get_prediction:51 - Generated SQL for index 72: SELECT
#     l1.labresult - l2.labresult as bun_change
# FROM lab l1
# JOIN patient p ON l1.patientunitstayid = p.patientunitstayid
# JOIN lab l2 ON l2.patientunitstayid = p.patientunitstayid
# WHERE p.uniquepid = '030-16826'
#     AND l1.labname = 'bun'
#     AND l2.labname = 'bun'
#     AND l1.labresulttime = '2104-06-17 13:25:00'
#     AND l2.labresulttime = '2104-06-13 12:26:00';
# 2025-07-28 20:54:14.363 | INFO     | __main__:get_prediction:51 - Generated SQL for index 71: WITH last_visit AS (
#     SELECT patienthealthsystemstayid
#     FROM patient
#     WHERE uniquepid = '027-10308'
#     ORDER BY hospitaladmittime DESC
#     LIMIT 1
# ),
# glucose_measurements AS (
#     SELECT l.labresult, l.labresulttime,
#            ROW_NUMBER() OVER (ORDER BY l.labresulttime DESC) as rn
#     FROM lab l
#     JOIN patient p ON l.patientunitstayid = p.patientunitstayid
#     JOIN last_visit lv ON p.patienthealthsystemstayid = lv.patienthealthsystemstayid
#     WHERE l.labname LIKE '%glucose%' AND l.labname LIKE '%bedside%'
# )
# SELECT
#     (SELECT labresult FROM glucose_measurements WHERE rn = 1) -
#     (SELECT labresult FROM glucose_measurements WHERE rn = 2) as glucose_difference
# FROM glucose_measurements
# WHERE rn <= 2
# LIMIT 1;
# 2025-07-28 20:54:14.837 | INFO     | __main__:get_prediction:51 - Generated SQL for index 75: WITH first_visit AS (
#     SELECT patientunitstayid
#     FROM patient
#     WHERE uniquepid = '016-3041'
#     ORDER BY hospitaladmittime ASC
#     LIMIT 1
# ),
# sodium_values AS (
#     SELECT labresult, labresulttime,
#            ROW_NUMBER() OVER (ORDER BY labresulttime ASC) as rn
#     FROM lab l
#     JOIN first_visit fv ON l.patientunitstayid = fv.patientunitstayid
#     WHERE l.labname = 'sodium'
# )
# SELECT (SELECT labresult FROM sodium_values WHERE rn = 2) -
#        (SELECT labresult FROM sodium_values WHERE rn = 1) as sodium_difference;
# 2025-07-28 20:54:18.734 | INFO     | __main__:get_prediction:51 - Generated SQL for index 74: WITH patient_current_stay AS (
#     SELECT patientunitstayid
#     FROM patient
#     WHERE uniquepid = '005-4471'
#     ORDER BY unitadmittime DESC
#     LIMIT 1
# ),
# bun_results AS (
#     SELECT labresult, labresulttime,
#            ROW_NUMBER() OVER (ORDER BY labresulttime) as rn
#     FROM lab l
#     JOIN patient_current_stay pcs ON l.patientunitstayid = pcs.patientunitstayid
#     WHERE LOWER(labname) LIKE '%bun%'
# )
# SELECT
#     (SELECT labresult FROM bun_results WHERE rn = 2) -
#     (SELECT labresult FROM bun_results WHERE rn = 1) as bun_change
# FROM bun_results
# LIMIT 1;
# 2025-07-28 20:54:18.735 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-28 20:54:18.735 | INFO     | __main__:run_predictions_async:14 - Processing chunk 75 to 79
# 2025-07-28 20:54:18.736 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-28 20:54:24.765 | INFO     | __main__:get_prediction:51 - Generated SQL for index 78: WITH first_icu_stay AS (
#     SELECT patientunitstayid
#     FROM patient
#     WHERE uniquepid = '004-93782'
#     ORDER BY unitadmittime
#     LIMIT 1
# ),
# sao2_measurements AS (
#     SELECT sao2,
#            ROW_NUMBER() OVER (ORDER BY observationtime) as measurement_order
#     FROM vitalperiodic v
#     JOIN first_icu_stay f ON v.patientunitstayid = f.patientunitstayid
#     WHERE sao2 IS NOT NULL
# )
# SELECT
#     (SELECT sao2 FROM sao2_measurements WHERE measurement_order = 2) -
#     (SELECT sao2 FROM sao2_measurements WHERE measurement_order = 1) AS sao2_change
# FROM sao2_measurements
# LIMIT 1;
# 2025-07-28 20:54:25.408 | INFO     | __main__:get_prediction:51 - Generated SQL for index 76: SELECT
#     (SELECT l1.labresult
#      FROM lab l1
#      JOIN patient p1 ON l1.patientunitstayid = p1.patientunitstayid
#      WHERE p1.uniquepid = '027-120477'
#        AND l1.labname = 'sodium'
#        AND l1.labresulttime = '2104-01-04 13:15:00') -
#     (SELECT l2.labresult
#      FROM lab l2
#      JOIN patient p2 ON l2.patientunitstayid = p2.patientunitstayid
#      WHERE p2.uniquepid = '027-120477'
#        AND l2.labname = 'sodium'
#        AND l2.labresulttime = '2104-01-03 05:32:00') AS sodium_difference;
# 2025-07-28 20:54:26.202 | INFO     | __main__:get_prediction:51 - Generated SQL for index 77: WITH first_visit AS (
#     SELECT patientunitstayid, hospitaladmittime
#     FROM patient
#     WHERE uniquepid = '015-67291'
#     ORDER BY hospitaladmittime
#     LIMIT 1
# ),
# hct_values AS (
#     SELECT l.labresult, l.labresulttime,
#            ROW_NUMBER() OVER (ORDER BY l.labresulttime DESC) as rn
#     FROM lab l
#     INNER JOIN first_visit fv ON l.patientunitstayid = fv.patientunitstayid
#     WHERE LOWER(l.labname) LIKE '%hct%' OR LOWER(l.labname) LIKE '%hematocrit%'
# )
# SELECT
#     (SELECT labresult FROM hct_values WHERE rn = 1) -
#     (SELECT labresult FROM hct_values WHERE rn = 2) as hct_change
# FROM hct_values
# WHERE rn <= 2
# LIMIT 1;
# 2025-07-28 20:54:26.629 | INFO     | __main__:get_prediction:51 - Generated SQL for index 80: WITH patient_stay AS (
#     SELECT patientunitstayid
#     FROM patient
#     WHERE uniquepid = '027-203413'
#     AND unitdischargetime IS NULL
# ),
# respiration_measurements AS (
#     SELECT respiration, observationtime,
#            ROW_NUMBER() OVER (ORDER BY observationtime DESC) as rn
#     FROM vitalperiodic v
#     JOIN patient_stay ps ON v.patientunitstayid = ps.patientunitstayid
#     WHERE respiration IS NOT NULL
# )
# SELECT
#     (SELECT respiration FROM respiration_measurements WHERE rn = 1) -
#     (SELECT respiration FROM respiration_measurements WHERE rn = 2) as difference;
# 2025-07-28 20:54:27.491 | INFO     | __main__:get_prediction:51 - Generated SQL for index 79: WITH temp_readings AS (
#     SELECT v.temperature, v.observationtime
#     FROM vitalperiodic v
#     JOIN patient p ON v.patientunitstayid = p.patientunitstayid
#     WHERE p.uniquepid = '004-13127'
#     AND v.observationtime IN ('2105-12-31 22:54:00', '2105-12-31 22:49:00')
# )
# SELECT
#     (SELECT temperature FROM temp_readings WHERE observationtime = '2105-12-31 22:54:00') -
#     (SELECT temperature FROM temp_readings WHERE observationtime = '2105-12-31 22:49:00') AS temperature_change;
# 2025-07-28 20:54:27.492 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-28 20:54:27.492 | INFO     | __main__:run_predictions_async:14 - Processing chunk 80 to 84
# 2025-07-28 20:54:27.492 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-28 20:54:33.329 | INFO     | __main__:get_prediction:51 - Generated SQL for index 83: SELECT
#   (SELECT heartrate FROM vitalperiodic v
#    JOIN patient p ON v.patientunitstayid = p.patientunitstayid
#    WHERE p.uniquepid = '015-96048'
#    AND v.observationtime = '2105-08-15 09:57:00') -
#   (SELECT heartrate FROM vitalperiodic v
#    JOIN patient p ON v.patientunitstayid = p.patientunitstayid
#    WHERE p.uniquepid = '015-96048'
#    AND v.observationtime = '2105-08-15 09:52:00') AS heartrate_change;
# 2025-07-28 20:54:34.076 | INFO     | __main__:get_prediction:51 - Generated SQL for index 85: SELECT
#     v1.heartrate - v2.heartrate AS heartrate_difference
# FROM patient p
# JOIN vitalperiodic v1 ON p.patientunitstayid = v1.patientunitstayid
# JOIN vitalperiodic v2 ON p.patientunitstayid = v2.patientunitstayid
# WHERE p.uniquepid = '027-94096'
#     AND v1.observationtime = '2104-07-27 12:18:40'
#     AND v2.observationtime = '2104-07-27 12:13:40';
# 2025-07-28 20:54:34.318 | INFO     | __main__:get_prediction:51 - Generated SQL for index 84: WITH first_icu_stay AS (
#     SELECT patientunitstayid
#     FROM patient
#     WHERE uniquepid = '015-94586'
#     ORDER BY unitadmittime
#     LIMIT 1
# ),
# heart_rates AS (
#     SELECT heartrate, observationtime,
#            ROW_NUMBER() OVER (ORDER BY observationtime) as rn
#     FROM vitalperiodic v
#     JOIN first_icu_stay f ON v.patientunitstayid = f.patientunitstayid
#     WHERE heartrate IS NOT NULL
#     ORDER BY observationtime
#     LIMIT 2
# )
# SELECT
#     (SELECT heartrate FROM heart_rates WHERE rn = 2) -
#     (SELECT heartrate FROM heart_rates WHERE rn = 1) as heartrate_difference
# FROM heart_rates
# LIMIT 1;
# 2025-07-28 20:54:34.504 | INFO     | __main__:get_prediction:51 - Generated SQL for index 82: WITH heart_rates AS (
#     SELECT
#         v.heartrate,
#         ROW_NUMBER() OVER (ORDER BY v.observationtime) as measurement_order
#     FROM vitalperiodic v
#     JOIN patient p ON v.patientunitstayid = p.patientunitstayid
#     WHERE p.uniquepid = '013-28507'
#         AND v.heartrate IS NOT NULL
# )
# SELECT
#     (SELECT heartrate FROM heart_rates WHERE measurement_order = 2) -
#     (SELECT heartrate FROM heart_rates WHERE measurement_order = 1) as heartrate_change;
# 2025-07-28 20:54:34.667 | INFO     | __main__:get_prediction:51 - Generated SQL for index 81: WITH last_icu_stay AS (
#     SELECT patientunitstayid
#     FROM patient
#     WHERE uniquepid = '022-67644'
#     ORDER BY unitadmittime DESC
#     LIMIT 1
# ),
# respiration_measurements AS (
#     SELECT respiration, observationtime,
#            ROW_NUMBER() OVER (ORDER BY observationtime) as measurement_order
#     FROM vitalperiodic v
#     JOIN last_icu_stay l ON v.patientunitstayid = l.patientunitstayid
#     WHERE respiration IS NOT NULL
# ),
# first_second_measurements AS (
#     SELECT
#         MAX(CASE WHEN measurement_order = 1 THEN respiration END) as first_respiration,
#         MAX(CASE WHEN measurement_order = 2 THEN respiration END) as second_respiration
#     FROM respiration_measurements
#     WHERE measurement_order IN (1, 2)
# )
# SELECT second_respiration - first_respiration as respiration_change
# FROM first_second_measurements;
# 2025-07-28 20:54:34.667 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-28 20:54:34.667 | INFO     | __main__:run_predictions_async:14 - Processing chunk 85 to 89
# 2025-07-28 20:54:34.668 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-28 20:54:42.736 | INFO     | __main__:get_prediction:51 - Generated SQL for index 86: WITH first_visit AS (
#     SELECT MIN(patientunitstayid) as first_stay_id
#     FROM patient
#     WHERE uniquepid = '006-36108'
# ),
# respiration_values AS (
#     SELECT
#         respiration,
#         observationtime,
#         ROW_NUMBER() OVER (ORDER BY observationtime ASC) as rn_asc,
#         ROW_NUMBER() OVER (ORDER BY observationtime DESC) as rn_desc
#     FROM vitalperiodic v
#     JOIN first_visit f ON v.patientunitstayid = f.first_stay_id
#     WHERE respiration IS NOT NULL
# )
# SELECT
#     (SELECT respiration FROM respiration_values WHERE rn_desc = 1) -
#     (SELECT respiration FROM respiration_values WHERE rn_asc = 1) as respiration_difference;
# 2025-07-28 20:54:43.922 | INFO     | __main__:get_prediction:51 - Generated SQL for index 89: WITH first_visit AS (
#     SELECT patientunitstayid
#     FROM patient
#     WHERE uniquepid = '027-69449'
#     ORDER BY hospitaladmittime
#     LIMIT 1
# ),
# platelets_measurements AS (
#     SELECT labresult, labresulttime,
#            ROW_NUMBER() OVER (ORDER BY labresulttime DESC) as rn
#     FROM lab l
#     JOIN first_visit fv ON l.patientunitstayid = fv.patientunitstayid
#     WHERE LOWER(labname) LIKE '%platelet%'
# ),
# last_two AS (
#     SELECT
#         MAX(CASE WHEN rn = 1 THEN labresult END) as last_value,
#         MAX(CASE WHEN rn = 2 THEN labresult END) as second_last_value
#     FROM platelets_measurements
#     WHERE rn <= 2
# )
# SELECT
#     CASE
#         WHEN last_value < second_last_value THEN 1
#         ELSE 0
#     END as is_last_less_than_second_last
# FROM last_two;
# 2025-07-28 20:54:44.617 | INFO     | __main__:get_prediction:51 - Generated SQL for index 90: WITH last_visit AS (
#     SELECT patientunitstayid
#     FROM patient
#     WHERE uniquepid = '022-98345'
#     ORDER BY hospitaladmittime DESC
#     LIMIT 1
# ),
# mch_measurements AS (
#     SELECT labresult,
#            ROW_NUMBER() OVER (ORDER BY labresulttime) as measurement_order
#     FROM lab l
#     JOIN last_visit lv ON l.patientunitstayid = lv.patientunitstayid
#     WHERE LOWER(labname) LIKE '%mch%'
# )
# SELECT
#     (SELECT labresult FROM mch_measurements WHERE measurement_order = 2) <
#     (SELECT labresult FROM mch_measurements WHERE measurement_order = 1) as second_less_than_first
# FROM mch_measurements
# WHERE measurement_order = 1;
# 2025-07-28 20:54:45.183 | INFO     | __main__:get_prediction:51 - Generated SQL for index 88: WITH current_stay AS (
#     SELECT patienthealthsystemstayid
#     FROM patient
#     WHERE uniquepid = '006-133605'
#     ORDER BY hospitaladmittime DESC
#     LIMIT 1
# ),
# lactate_measurements AS (
#     SELECT l.labresult, l.labresulttime
#     FROM lab l
#     JOIN patient p ON l.patientunitstayid = p.patientunitstayid
#     WHERE p.patienthealthsystemstayid = (SELECT patienthealthsystemstayid FROM current_stay)
#     AND LOWER(l.labname) LIKE '%lactate%'
#     ORDER BY l.labresulttime
# ),
# first_last AS (
#     SELECT
#         (SELECT labresult FROM lactate_measurements LIMIT 1) as first_lactate,
#         (SELECT labresult FROM lactate_measurements ORDER BY labresulttime DESC LIMIT 1) as last_lactate
# )
# SELECT last_lactate > first_lactate as is_last_greater_than_first
# FROM first_last;
# 2025-07-28 20:54:45.442 | INFO     | __main__:get_prediction:51 - Generated SQL for index 87: WITH patient_visits AS (
#     SELECT uniquepid, patienthealthsystemstayid, hospitaladmittime,
#            ROW_NUMBER() OVER (PARTITION BY uniquepid ORDER BY hospitaladmittime) as visit_rank
#     FROM patient
#     WHERE uniquepid = '035-11731'
# ),
# first_visit AS (
#     SELECT patienthealthsystemstayid
#     FROM patient_visits
#     WHERE visit_rank = 1
# ),
# eos_results AS (
#     SELECT l.labresult, l.labresulttime,
#            ROW_NUMBER() OVER (ORDER BY l.labresulttime DESC) as result_rank
#     FROM lab l
#     JOIN patient p ON l.patientunitstayid = p.patientunitstayid
#     JOIN first_visit fv ON p.patienthealthsystemstayid = fv.patienthealthsystemstayid
#     WHERE l.labname = '-eos'
# ),
# comparison_values AS (
#     SELECT
#         MAX(CASE WHEN result_rank = 1 THEN labresult END) as last_value,
#         MAX(CASE WHEN result_rank = 2 THEN labresult END) as second_last_value
#     FROM eos_results
#     WHERE result_rank IN (1, 2)
# )
# SELECT last_value < second_last_value as is_last_less_than_second_last
# FROM comparison_values
# WHERE last_value IS NOT NULL AND second_last_value IS NOT NULL;
# 2025-07-28 20:54:45.442 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-28 20:54:45.443 | INFO     | __main__:run_predictions_async:14 - Processing chunk 90 to 94
# 2025-07-28 20:54:45.443 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-28 20:54:53.499 | INFO     | __main__:get_prediction:51 - Generated SQL for index 93: WITH first_visit AS (
#     SELECT patientunitstayid
#     FROM patient
#     WHERE uniquepid = '012-11090'
#     ORDER BY hospitaladmittime ASC
#     LIMIT 1
# ),
# chloride_results AS (
#     SELECT labresult, labresulttime
#     FROM lab l
#     JOIN first_visit fv ON l.patientunitstayid = fv.patientunitstayid
#     WHERE LOWER(l.labname) LIKE '%chloride%'
#     ORDER BY labresulttime ASC
# ),
# first_last_values AS (
#     SELECT
#         (SELECT labresult FROM chloride_results ORDER BY labresulttime ASC LIMIT 1) as first_value,
#         (SELECT labresult FROM chloride_results ORDER BY labresulttime DESC LIMIT 1) as last_value
# )
# SELECT last_value < first_value as is_last_less_than_first
# FROM first_last_values;
# 2025-07-28 20:54:53.789 | INFO     | __main__:get_prediction:51 - Generated SQL for index 92: SELECT
#     (SELECT labresult
#      FROM lab l JOIN patient p ON l.patientunitstayid = p.patientunitstayid
#      WHERE p.uniquepid = '007-15837'
#        AND LOWER(l.labname) LIKE '%wbc%'
#      ORDER BY l.labresulttime DESC
#      LIMIT 1) <
#     (SELECT labresult
#      FROM lab l JOIN patient p ON l.patientunitstayid = p.patientunitstayid
#      WHERE p.uniquepid = '007-15837'
#        AND LOWER(l.labname) LIKE '%wbc%'
#      ORDER BY l.labresulttime DESC
#      LIMIT 1 OFFSET 1) AS is_last_less_than_second_last;
# 2025-07-28 20:54:53.953 | INFO     | __main__:get_prediction:51 - Generated SQL for index 91: WITH glucose_measurements AS (
#     SELECT
#         l.labresult,
#         l.labresulttime,
#         ROW_NUMBER() OVER (ORDER BY l.labresulttime ASC) as first_rank,
#         ROW_NUMBER() OVER (ORDER BY l.labresulttime DESC) as last_rank
#     FROM patient p
#     JOIN lab l ON p.patientunitstayid = l.patientunitstayid
#     WHERE p.uniquepid = '009-5001'
#     AND LOWER(l.labname) LIKE '%glucose%'
#     AND LOWER(l.labname) LIKE '%bedside%'
# ),
# first_last AS (
#     SELECT
#         MAX(CASE WHEN first_rank = 1 THEN labresult END) as first_glucose,
#         MAX(CASE WHEN last_rank = 1 THEN labresult END) as last_glucose
#     FROM glucose_measurements
# )
# SELECT
#     CASE
#         WHEN last_glucose > first_glucose THEN 1
#         ELSE 0
#     END as is_last_greater_than_first
# FROM first_last;
# 2025-07-28 20:54:54.435 | INFO     | __main__:get_prediction:51 - Generated SQL for index 94: WITH current_visit AS (
#     SELECT patientunitstayid
#     FROM patient
#     WHERE uniquepid = '021-111547'
#       AND patienthealthsystemstayid = (
#         SELECT MAX(patienthealthsystemstayid)
#         FROM patient
#         WHERE uniquepid = '021-111547'
#       )
# ),
# calcium_values AS (
#     SELECT labresult, labresulttime
#     FROM lab l
#     JOIN current_visit cv ON l.patientunitstayid = cv.patientunitstayid
#     WHERE LOWER(l.labname) LIKE '%calcium%'
#     ORDER BY l.labresulttime
# )
# SELECT
#     (SELECT labresult FROM calcium_values ORDER BY labresulttime DESC LIMIT 1) <
#     (SELECT labresult FROM calcium_values ORDER BY labresulttime ASC LIMIT 1) as is_last_less_than_first
# FROM calcium_values
# LIMIT 1;
# 2025-07-28 20:54:54.627 | INFO     | __main__:get_prediction:51 - Generated SQL for index 95: WITH first_icu_stay AS (
#     SELECT patientunitstayid
#     FROM patient
#     WHERE uniquepid = '006-146580'
#     ORDER BY unitadmittime ASC
#     LIMIT 1
# ),
# first_systolic AS (
#     SELECT systemicsystolic
#     FROM vitalperiodic v
#     JOIN first_icu_stay f ON v.patientunitstayid = f.patientunitstayid
#     WHERE systemicsystolic IS NOT NULL
#     ORDER BY observationtime ASC
#     LIMIT 1
# ),
# last_systolic AS (
#     SELECT systemicsystolic
#     FROM vitalperiodic v
#     JOIN first_icu_stay f ON v.patientunitstayid = f.patientunitstayid
#     WHERE systemicsystolic IS NOT NULL
#     ORDER BY observationtime DESC
#     LIMIT 1
# )
# SELECT
#     l.systemicsystolic < f.systemicsystolic AS is_last_less_than_first
# FROM last_systolic l
# CROSS JOIN first_systolic f;
# 2025-07-28 20:54:54.628 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# ...
# JOIN lab l ON p.patientunitstayid = l.patientunitstayid
# WHERE p.uniquepid = '006-254232'
# AND l.labname LIKE '%genetic%';
# 2025-07-28 21:46:43.041 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1749: SELECT l.labname
# FROM lab l
# JOIN patient p ON l.patientunitstayid = p.patientunitstayid
# WHERE p.uniquepid = '035-9846'
# AND l.labname LIKE '%genetic%';
# 2025-07-28 21:46:44.866 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1746: None
# 2025-07-28 21:46:46.320 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1747: Looking at the available tables and columns in the DDL, there is no specific field for blood type information in any of the tables. While blood type testing might potentially be recorded in the `lab` table as a lab test result, there's no guarantee that this information exists or how it would be formatted.
#
# None;
# 2025-07-28 21:46:46.710 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1750: SELECT DISTINCT
#     p.uniquepid,
#     l.labname as test_name,
#     l.labresulttime as test_time,
#     'lab' as test_type
# FROM patient p
# JOIN lab l ON p.patientunitstayid = l.patientunitstayid
# WHERE p.uniquepid = '022-187132'
#     AND (l.labname LIKE '%genetic%'
#          OR l.labname LIKE '%gene%'
#          OR l.labname LIKE '%dna%'
#          OR l.labname LIKE '%chromosome%'
#          OR l.labname LIKE '%mutation%')
#
# UNION ALL
#
# SELECT DISTINCT
#     p.uniquepid,
#     t.treatmentname as test_name,
#     t.treatmenttime as test_time,
#     'treatment' as test_type
# FROM patient p
# JOIN treatment t ON p.patientunitstayid = t.patientunitstayid
# WHERE p.uniquepid = '022-187132'
#     AND (t.treatmentname LIKE '%genetic%'
#          OR t.treatmentname LIKE '%gene%'
#          OR t.treatmentname LIKE '%dna%'
#          OR t.treatmentname LIKE '%chromosome%'
#          OR t.treatmentname LIKE '%mutation%')
#
# ORDER BY test_time;
# 2025-07-28 21:46:46.711 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-28 21:46:46.711 | INFO     | __main__:run_predictions_async:14 - Processing chunk 1750 to 1754
# 2025-07-28 21:46:46.711 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-28 21:46:52.177 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1753: SELECT l.labname, l.labresult, l.labresulttime
# FROM patient p
# JOIN lab l ON p.patientunitstayid = l.patientunitstayid
# WHERE p.uniquepid = '035-4312'
# AND (l.labname LIKE '%genetic%'
#      OR l.labname LIKE '%gene%'
#      OR l.labname LIKE '%dna%'
#      OR l.labname LIKE '%chromosome%'
#      OR l.labname LIKE '%genomic%');
# 2025-07-28 21:46:52.539 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1754: SELECT l.labname, l.labresult, l.labresulttime
# FROM lab l
# JOIN patient p ON l.patientunitstayid = p.patientunitstayid
# WHERE p.uniquepid = '031-3507'
# AND (l.labname LIKE '%genetic%' OR l.labname LIKE '%gene%' OR l.labname LIKE '%dna%' OR l.labname LIKE '%chromosome%');
# 2025-07-28 21:46:52.586 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1752: SELECT DISTINCT l.labname
# FROM patient p
# JOIN lab l ON p.patientunitstayid = l.patientunitstayid
# WHERE p.uniquepid = '025-57841'
# AND l.labname LIKE '%genetic%';
# 2025-07-28 21:46:53.935 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1751: SELECT l.labname, l.labresult, l.labresulttime
# FROM lab l
# JOIN patient p ON l.patientunitstayid = p.patientunitstayid
# WHERE p.uniquepid = '008-40862'
#   AND (l.labname LIKE '%gene%'
#        OR l.labname LIKE '%genetic%'
#        OR l.labname LIKE '%dna%'
#        OR l.labname LIKE '%mutation%'
#        OR l.labname LIKE '%genomic%');
# 2025-07-28 21:46:56.094 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1755: SELECT labname
# FROM lab l
# JOIN patient p ON l.patientunitstayid = p.patientunitstayid
# WHERE p.uniquepid = '015-21757'
# AND (labname LIKE '%genetic%' OR labname LIKE '%dna%' OR labname LIKE '%gene%' OR labname LIKE '%chromosome%' OR labname LIKE '%mutation%');
# 2025-07-28 21:46:56.095 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-28 21:46:56.095 | INFO     | __main__:run_predictions_async:14 - Processing chunk 1755 to 1759
# 2025-07-28 21:46:56.095 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-28 21:47:02.163 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1757: SELECT l.labname, l.labresult, l.labresulttime
# FROM lab l
# JOIN patient p ON l.patientunitstayid = p.patientunitstayid
# WHERE p.uniquepid = '012-18025'
# AND l.labname LIKE '%genetic%';
# 2025-07-28 21:47:02.643 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1756: SELECT l.labname, l.labresult, l.labresulttime
# FROM patient p
# JOIN lab l ON p.patientunitstayid = l.patientunitstayid
# WHERE p.uniquepid = '010-9756'
# AND (l.labname LIKE '%genetic%' OR l.labname LIKE '%gene%' OR l.labname LIKE '%dna%' OR l.labname LIKE '%chromosome%' OR l.labname LIKE '%mutation%');
# 2025-07-28 21:47:02.655 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1759: SELECT
#     CASE
#         WHEN COUNT(l.labid) > 0 OR COUNT(m.microlabid) > 0 THEN 'Yes'
#         ELSE 'No'
#     END AS has_tests
# FROM patient p
# LEFT JOIN lab l ON p.patientunitstayid = l.patientunitstayid
# LEFT JOIN microlab m ON p.patientunitstayid = m.patientunitstayid
# WHERE p.uniquepid = '028-55503';
# 2025-07-28 21:47:02.819 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1758: SELECT l.labname, l.labresult, l.labresulttime
# FROM patient p
# JOIN lab l ON p.patientunitstayid = l.patientunitstayid
# WHERE p.uniquepid = '027-95744'
#   AND (LOWER(l.labname) LIKE '%genetic%'
#        OR LOWER(l.labname) LIKE '%dna%'
#        OR LOWER(l.labname) LIKE '%chromosome%'
#        OR LOWER(l.labname) LIKE '%mutation%'
#        OR LOWER(l.labname) LIKE '%gene%');
# 2025-07-28 21:47:03.246 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1760: SELECT l.labname, l.labresult, l.labresulttime
# FROM patient p
# JOIN lab l ON p.patientunitstayid = l.patientunitstayid
# WHERE p.uniquepid = '035-15069'
# AND (LOWER(l.labname) LIKE '%genetic%'
#      OR LOWER(l.labname) LIKE '%dna%'
#      OR LOWER(l.labname) LIKE '%chromosome%'
#      OR LOWER(l.labname) LIKE '%gene%');
# 2025-07-28 21:47:03.247 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-28 21:47:03.247 | INFO     | __main__:run_predictions_async:14 - Processing chunk 1760 to 1764
# 2025-07-28 21:47:03.247 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-28 21:47:08.879 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1764: SELECT DISTINCT l.labname
# FROM patient p
# JOIN lab l ON p.patientunitstayid = l.patientunitstayid
# WHERE p.uniquepid = '027-136480'
# AND l.labname LIKE '%sputum%expectorated%';
# 2025-07-28 21:47:09.153 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1761: SELECT DISTINCT l.labname, l.labresult, l.labresulttime
# FROM patient p
# JOIN lab l ON p.patientunitstayid = l.patientunitstayid
# WHERE p.uniquepid = '016-35481'
# AND (l.labname LIKE '%genetic%' OR l.labname LIKE '%gene%' OR l.labname LIKE '%dna%' OR l.labname LIKE '%chromosome%' OR l.labname LIKE '%genomic%')
# ORDER BY l.labresulttime;
# 2025-07-28 21:47:09.742 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1765: None
#
# The question asks about future medical tests ("will get"), but the database contains historical medical records and cannot predict or show scheduled future procedures or tests.;
# 2025-07-28 21:47:09.797 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1763: SELECT
#     p.uniquepid,
#     t.treatmentname,
#     t.treatmenttime,
#     l.labname,
#     l.labresulttime
# FROM patient p
# LEFT JOIN treatment t ON p.patientunitstayid = t.patientunitstayid
#     AND t.treatmentname LIKE '%blood%'
# LEFT JOIN lab l ON p.patientunitstayid = l.patientunitstayid
# WHERE p.uniquepid = '006-80884'
#     AND (t.treatmentname IS NOT NULL OR l.labname IS NOT NULL)
# ORDER BY COALESCE(t.treatmenttime, l.labresulttime);
# 2025-07-28 21:47:09.937 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1762: SELECT DISTINCT l.labname
# FROM patient p
# JOIN lab l ON p.patientunitstayid = l.patientunitstayid
# WHERE p.uniquepid = '030-10407'
# AND LOWER(l.labname) LIKE '%genetic%';
# 2025-07-28 21:47:09.938 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-28 21:47:09.938 | INFO     | __main__:run_predictions_async:14 - Processing chunk 1765 to 1769
# 2025-07-28 21:47:09.938 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-28 21:47:14.009 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1770: None
# 2025-07-28 21:47:15.846 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1768: None
# 2025-07-28 21:47:17.037 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1766: SELECT DISTINCT m.culturesite, m.organism, m.culturetakentime
# FROM patient p
# JOIN microlab m ON p.patientunitstayid = m.patientunitstayid
# WHERE p.uniquepid = '010-20205'
#   AND (m.culturesite LIKE '%sputum%' OR m.culturesite LIKE '%tracheal%')
# ORDER BY m.culturetakentime;
# 2025-07-28 21:47:18.347 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1767: SELECT l.labname, l.labresult, l.labresulttime
# FROM lab l
# JOIN patient p ON l.patientunitstayid = p.patientunitstayid
# WHERE p.uniquepid = '007-16517'
# AND (l.labname LIKE '%sputum%' OR l.labname LIKE '%expectorated%')
# ORDER BY l.labresulttime;
# 2025-07-28 21:47:18.713 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1769: SELECT DISTINCT
#     'Blood Administration' as type,
#     m.drugname as name,
#     m.drugstarttime as time
# FROM patient p
# JOIN medication m ON p.patientunitstayid = m.patientunitstayid
# WHERE p.uniquepid = '005-77687'
#     AND (m.drugname LIKE '%blood%' OR m.drugname LIKE '%transfusion%' OR m.drugname LIKE '%rbc%' OR m.drugname LIKE '%packed cells%')
#
# UNION
#
# SELECT DISTINCT
#     'Venipuncture/Lab Test' as type,
#     l.labname as name,
#     l.labresulttime as time
# FROM patient p
# JOIN lab l ON p.patientunitstayid = l.patientunitstayid
# WHERE p.uniquepid = '005-77687'
#     AND (l.labname LIKE '%venipuncture%' OR l.labname LIKE '%blood%' OR l.labname LIKE '%draw%')
#
# UNION
#
# SELECT DISTINCT
#     'Blood-related Treatment' as type,
#     t.treatmentname as name,
#     t.treatmenttime as time
# FROM patient p
# JOIN treatment t ON p.patientunitstayid = t.patientunitstayid
# WHERE p.uniquepid = '005-77687'
#     AND (t.treatmentname LIKE '%blood%' OR t.treatmentname LIKE '%venipuncture%' OR t.treatmentname LIKE '%transfusion%')
#
# ORDER BY time;
# 2025-07-28 21:47:18.713 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-28 21:47:18.714 | INFO     | __main__:run_predictions_async:14 - Processing chunk 1770 to 1774
# 2025-07-28 21:47:18.714 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-28 21:47:25.002 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1775: SELECT DISTINCT m.culturesite, m.organism, m.culturetakentime
# FROM patient p
# JOIN microlab m ON p.patientunitstayid = m.patientunitstayid
# WHERE p.uniquepid = '009-424'
# AND m.culturesite LIKE '%urine%'
# ORDER BY m.culturetakentime;
# 2025-07-28 21:47:25.463 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1773: SELECT m.culturesite, m.organism, m.culturetakentime
# FROM patient p
# JOIN microlab m ON p.patientunitstayid = m.patientunitstayid
# WHERE p.uniquepid = '010-32430'
# AND (m.culturesite LIKE '%sputum%' OR m.culturesite LIKE '%tracheal%');
# 2025-07-28 21:47:25.965 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1771: SELECT
#     'lab' as test_type,
#     l.labname,
#     l.labresult,
#     l.labresulttime
# FROM patient p
# JOIN lab l ON p.patientunitstayid = l.patientunitstayid
# WHERE p.uniquepid = '032-9230'
#
# UNION ALL
#
# SELECT
#     'microlab' as test_type,
#     m.culturesite,
#     m.organism,
#     m.culturetakentime
# FROM patient p
# JOIN microlab m ON p.patientunitstayid = m.patientunitstayid
# WHERE p.uniquepid = '032-9230'
#
# ORDER BY test_type, labresulttime;
# 2025-07-28 21:47:25.969 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1772: None
# 2025-07-28 21:47:26.173 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1774: None
# 2025-07-28 21:47:26.173 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-28 21:47:26.174 | INFO     | __main__:run_predictions_async:14 - Processing chunk 1775 to 1779
# 2025-07-28 21:47:26.174 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-28 21:47:30.640 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1777: None
# 2025-07-28 21:47:30.757 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1780: None
# 2025-07-28 21:47:30.872 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1779: None
# 2025-07-28 21:47:31.806 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1778: None
# 2025-07-28 21:47:34.660 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1776: SELECT l.labname, l.labresulttime, l.labresult
# FROM patient p
# JOIN lab l ON p.patientunitstayid = l.patientunitstayid
# WHERE p.uniquepid = '027-203413'
# AND l.labname LIKE '%nasopharynx%'
# ORDER BY l.labresulttime;
# 2025-07-28 21:47:34.661 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-28 21:47:34.661 | INFO     | __main__:run_predictions_async:14 - Processing chunk 1780 to 1784
# 2025-07-28 21:47:34.661 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-28 21:47:38.663 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1782: None
# 2025-07-28 21:47:39.307 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1781: None
# 2025-07-28 21:47:39.385 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1783: None
# 2025-07-28 21:47:39.426 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1784: None
# 2025-07-28 21:47:39.674 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1785: None
# 2025-07-28 21:47:39.674 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-28 21:47:39.675 | INFO     | __main__:run_predictions_async:14 - Processing chunk 1785 to 1789
# 2025-07-28 21:47:39.675 | INFO     | __main__:run_predictions_async:18 - Sending 5 requests to the vLLM server...
# 2025-07-28 21:47:43.469 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1788: None
# 2025-07-28 21:47:43.872 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1786: None
# 2025-07-28 21:47:44.343 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1790: None
# 2025-07-28 21:47:44.507 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1789: None
# 2025-07-28 21:47:46.812 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1787: None
# 2025-07-28 21:47:46.812 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-28 21:47:46.813 | INFO     | __main__:run_predictions_async:14 - Processing chunk 1790 to 1794
# 2025-07-28 21:47:46.813 | INFO     | __main__:run_predictions_async:18 - Sending 2 requests to the vLLM server...
# 2025-07-28 21:47:50.390 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1792: None
# 2025-07-28 21:47:51.538 | INFO     | __main__:get_prediction:51 - Generated SQL for index 1791: None
# 2025-07-28 21:47:51.538 | SUCCESS  | __main__:run_predictions_async:20 - All predictions done.
# 2025-07-28 21:47:51.553 | SUCCESS  | __main__:run_predictions_async:36 - Predictions saved to ../model_predictions/eICU/claude_4_sonnet_thinking/trial_1/predictions.json
# 2025-07-28 21:47:51.554 | SUCCESS  | __main__:<module>:16 - Model claude_4_sonnet_thinking. Trial 1 completed. Time taken: 3338.76 seconds

# %% [markdown]
# Note the time taken to run the prediction, from the logs above

# %% [markdown]
# # Evaluate

# %%
import os
from utils import preprare_directory

# create output directory for evaluation results, relative to the path of model_evaluation directory
# note that the evaluate results need a clean new folder, because it will overwrite any existing files in the folder
pred_directory = f"../model_predictions/eICU/{model_name}/trial_{trial_number}"
eval_directory = os.path.join(pred_directory, "evaluation")
preprare_directory(eval_directory, exist_ok=False)

# the predicted file from previous step
pred_file = os.path.join(pred_directory, "predictions.json")

print("Using predictions from: ", pred_file)

# path to the eICU database
db_path = "../model_evaluation/databases/eicu.sqlite"
# Out:
# Using predictions from:  ../model_predictions/eICU/claude_4_sonnet_thinking/trial_1/predictions.json

# %%
# run evaluation
# !python ../model_evaluation/ehrsql_eval.py \
    --pred_file {pred_file} \
    --db_path {db_path} \
    --num_workers -1 \
    --timeout 60 \
    --out_file {eval_directory} \
    --ndigits 2
# Out:
# Exception ignored in thread started by <bound method Thread._bootstrap of <StoppableThread(Thread-12 (funcwrap), started daemon 140536364836416)>>:
# Traceback (most recent call last):
#   File "/root/.local/share/uv/python/cpython-3.13.5-linux-x86_64-gnu/lib/python3.13/threading.py", line 1014, in _bootstrap
#     self._bootstrap_inner()
#   File "/root/.local/share/uv/python/cpython-3.13.5-linux-x86_64-gnu/lib/python3.13/threading.py", line 1047, in _bootstrap_inner
#     self._delete()
#   File "/root/.local/share/uv/python/cpython-3.13.5-linux-x86_64-gnu/lib/python3.13/threading.py", line 1049, in _delete
#     def _delete(self):
# func_timeout.dafunc.FunctionTimedOut-9131368032737615173: Function execute (args=("select observationtime \nfrom vitalperiodic v\njoin patient p on v.patientunitstayid = p.patientunitstayid\nwhere p.uniquepid = '027-85328'\n  and v.observationtime >= '2104-11-09 00:00:00'\n  and v.heartrate is not null\n  and v.heartrate = (\n    select min(v2.heartrate)\n    from vitalperiodic v2\n    join patient p2 on v2.patientunitstayid = p2.patientunitstayid\n    where p2.uniquepid = '027-85328'\n      and v2.observationtime >= '2104-11-09 00:00:00'\n      and v2.heartrate is not null\n  )\norder by observationtime desc\nlimit 1;", '../model_evaluation/databases/eicu.sqlite')) (kwargs={}) timed out after 60.000000 seconds.

# %% [markdown]
# # Interpret Results

# %%
fp = f"../model_predictions/eICU/{model_name}/trial_{trial_number}/evaluation/predictions_metrics.json"
print("Reading from file: ", fp)

with open(fp, "r") as f:
    metrics = json.load(f)

print(json.dumps(metrics, indent=4))
# Out:
# Reading from file:  ../model_predictions/eICU/claude_4_sonnet_thinking/trial_1/evaluation/predictions_metrics.json
# {
#     "precision_ans": 100.0,
#     "recall_ans": 78.91,
#     "f1_ans": 88.21,
#     "precision_exec": 40.66,
#     "recall_exec": 32.09,
#     "f1_exec": 35.87,
#     "acc": 32.09
# }
