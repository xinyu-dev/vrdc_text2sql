# %% [markdown]
# # Benchmark eICU using finetuned mistral nemo minitron 8B

# %%
import os
from openai import OpenAI
from loguru import logger
import sys
import json
sys.path.append(os.path.abspath(os.path.join('..', 'model_evaluation')))

# %% [markdown]
# # Set up dataset
#
# To evaluate the finetuned mistral 8B model, we will use the  `model_evaluation/dataset/test/test_ehrsql_eicu_data_benchmark.json` test dataset. This dataset contains **1792 Q&A pairs**.

# %%
# input test set directory
test_data_dir = "../model_evaluation/dataset/test"
test_data_fp = os.path.join(test_data_dir, "test_ehrsql_eicu_data_benchmark.json")

# try loading the test set
with open(test_data_fp, "r") as f:
    test_set = json.load(f)

print("Size of test set:", len(test_set))

print("Example of a test set item:")
print(json.dumps(test_set[0], indent=4))
# Out:
# Size of test set: 1792
# Example of a test set item:
# {
#     "index": 1,
#     "system": "Based on DDL statements, instructions, and the current date, generate a SQL query in the following sqlite to answer the question.\n If the question cannot be answered using the available tables and columns in the DDL (i.e., it is out of scope), return only: None.\nToday is 2105-12-31 23:59:00\nDDL statements:\nDROP TABLE IF EXISTS patient;\nCREATE TABLE patient    -- store patient demographics and admission information\n(\n    uniquepid VARCHAR(10) NOT NULL, -- Unique patient identifier across the system\n    patienthealthsystemstayid INT NOT NULL, -- unique identifier for a single ICU stay of a patient.\n    patientunitstayid INT NOT NULL PRIMARY KEY, -- Unique ID for the patient's ICU stay\n    gender VARCHAR(25) NOT NULL, -- Gender of the patient (\"female\" or \"male\") (lowercase)\n    age VARCHAR(10) NOT NULL, -- Age at admission (can be in years or an age category)\n    ethnicity VARCHAR(50), -- Ethnicity of the patient (e.g: \"caucasian\", \"native american\", \"hispanic\", \"african american\", \"other/unknown\", \"asian\" or null) (lowercase)\n    hospitalid INT NOT NULL, -- ID of the hospital\n    wardid INT NOT NULL, -- ID of the hospital ward/unit\n    admissionheight NUMERIC(10,2), -- Patient's height on admission (in cm)\n    admissionweight NUMERIC(10,2), -- Weight on admission (in kg)\n    dischargeweight NUMERIC(10,2), -- Weight at discharge (in kg)\n    hospitaladmittime TIMESTAMP(0) NOT NULL, -- Time patient was admitted to hospital\n    hospitaladmitsource VARCHAR(30) NOT NULL, -- Source of hospital admission (e.g., \"operating room\", \"floor\", \"other hospital\", \"emergency department\", \"direct admit\", \"step-down unit (sdu)\", \"acute care/floor\", \"recovery room\", \"icu to sdu\", \"other icu\" or \"pacu\") (lowercase)\n    unitadmittime TIMESTAMP(0) NOT NULL, -- Time of ICU admission\n    unitdischargetime TIMESTAMP(0), -- time of discharge from the ICU unit\n    hospitaldischargetime TIMESTAMP(0), -- Time of hospital discharge\n    hospitaldischargestatus VARCHAR(10) -- Discharge status (e.g., \"alive\", \"expired\" or null)\n);\n\nDROP TABLE IF EXISTS diagnosis;\nCREATE TABLE diagnosis  -- store diagnoses assigned during ICU stay\n(\n    diagnosisid INT NOT NULL PRIMARY KEY, -- Unique diagnosis record ID\n    patientunitstayid INT NOT NULL, -- ICU stay ID (FK to patient)\n    diagnosisname VARCHAR(200) NOT NULL, -- Full name of diagnosis (lowercase)\n    diagnosistime TIMESTAMP(0) NOT NULL, -- Time diagnosis was recorded\n    icd9code VARCHAR(100), -- ICD-9 code of the diagnosis\n    FOREIGN KEY(patientunitstayid) REFERENCES patient(patientunitstayid)\n);\n\nDROP TABLE IF EXISTS treatment;\nCREATE TABLE treatment  -- store treatments administered during ICU stay\n(\n    treatmentid INT NOT NULL PRIMARY KEY, -- Unique treatment record ID\n    patientunitstayid INT NOT NULL, -- ICU stay ID (FK to patient)\n    treatmentname VARCHAR(200) NOT NULL, -- Name of the treatment administered (lowercase)\n    treatmenttime TIMESTAMP(0) NOT NULL, -- Time the treatment was given\n    FOREIGN KEY(patientunitstayid) REFERENCES patient(patientunitstayid)\n);\n\nDROP TABLE IF EXISTS lab;\nCREATE TABLE lab  -- store lab test results\n(\n    labid INT NOT NULL PRIMARY KEY, -- Unique lab test result ID\n    patientunitstayid INT NOT NULL, -- ICU stay ID (FK to patient)\n    labname VARCHAR(256) NOT NULL, -- Name of the lab test (lowercase)\n    labresult NUMERIC(11,4) NOT NULL, -- Result value\n    labresulttime TIMESTAMP(0) NOT NULL, -- Time when the lab result was recorded\n    FOREIGN KEY(patientunitstayid) REFERENCES patient(patientunitstayid)\n);\n\nDROP TABLE IF EXISTS medication;\nCREATE TABLE medication  -- store medication administration records\n(\n    medicationid INT NOT NULL PRIMARY KEY, -- Unique medication record ID\n    patientunitstayid INT NOT NULL, -- ICU stay ID (FK to patient)\n    drugname VARCHAR(220) NOT NULL, -- Name of the medication (lowercase)\n    dosage VARCHAR(60) NOT ...
#     "user": "tell me the method of dextrose 5% in water (d5w) iv : 1000 ml bag intake?",
#     "real": "select distinct medication.routeadmin from medication where medication.drugname = 'dextrose 5% in water (d5w) iv : 1000 ml bag';"
# }

# %% [markdown]
# # Set up client

# %%
import asyncio
from openai import AsyncOpenAI
import json
from loguru import logger

# Re-using vLLM server details from previous cells
IP = "localhost"
PORT = 8000
BASE_URL = f"http://{IP}:{PORT}/v1"

# path to the model folder
MODEL_PATH = "/root/workspace/mistral-nemo-minitron-8b-healthcare-text2sql_v1.0"

# Initialize the AsyncOpenAI client
async_client = AsyncOpenAI(
    api_key="not-needed",
    base_url=BASE_URL,
)

# %%
from utils import postprocess_sql_query_from_markdown

async def get_prediction(record: dict, language: str = "SQLite") -> str:
    """
    Generates a SQL query for a given record asynchronously
    Args:
        record: a dictionary of Q&A pairs
    Returns:
        A dictionary containing the input, predict, and real fields
    """
    index = record['index']
    system = record['system']
    user = record['user']
    real = record['real']

    prompt_chat_template = [
        {
            "role": "system",
            "content": f"{system}",
        },
        {
            "role": "user",
            "content": f"{user}"
        }
    ]

    try:
        response = await async_client.chat.completions.create(
            model=MODEL_PATH,
            messages=prompt_chat_template,
            temperature=0.0,
            max_tokens=512,
            stop=["<extra_id_1>"]
        )
        generated_sql = response.choices[0].message.content
        prediction = postprocess_sql_query_from_markdown(generated_sql)
        logger.info(f"Generated SQL for index {index}: {prediction}") 

        return {
            "index": index,
            "input": user, # user query
            "predict": prediction,  # model predicted SQL
            "real": real # ground truth SQL
        }
        
    except Exception as e:
        logger.error(f"An error occurred for index {record.get('index', 'N/A')}: {e}")
        return f"Error: {e}"

# %%
async def run_predictions_async(test_fp: str, output_fp: str):
    """
    Loads a test set and runs predictions asynchronously.
    """
    # Path to the mini test set
    with open(test_fp, "r") as f:
        test_data = json.load(f)

    # chunk the data into 5 items at a time to avoid timeout
    chunk_size = 5
    results = []


    for i in range(0, len(test_data), chunk_size):
        logger.info(f"Processing chunk {i} to {i+chunk_size-1}")
        chunk = test_data[i:i+chunk_size]
        tasks = [get_prediction(record = record) for record in chunk]
        
        logger.info(f"Sending {len(tasks)} requests to the vLLM server...")
        predictions = await asyncio.gather(*tasks)
        logger.success("All predictions done.")

        # add predictions to the test data by looking up the index
        for pred in predictions:
            # create a dictionary with the index and prediction
            results.append({
                "index": pred['index'],
                "input": pred['input'],
                "predict": pred['predict'], 
                "real": pred['real']
            })

    # handle if the output file does not exist
    with open(output_fp, "w") as f:
        json.dump(results, f, indent=4)

    logger.success(f"Predictions saved to {output_fp}")

# %% [markdown]
# # Generate queries

# %%
from utils import preprare_directory
from time import time

# model name 
model_name = "mistral_nemo_minitron_8B_finetuned"

# trial number 
trial_number = 1    

# create output directory. set exist_ok=False to delete the old results and re-create a fresh folder
output_dir = f"../model_predictions/eICU/{model_name}/trial_{trial_number}"    
preprare_directory(output_dir, exist_ok=False)


# run predictions
start_time = time()
# run predictions
await run_predictions_async(
    test_fp = test_data_fp,
    output_fp = os.path.join(output_dir, "predictions.json")
)
end_time = time()
logger.success(f"Model {model_name}. Trial {trial_number} completed. Time taken: {end_time - start_time:.2f} seconds")
# Out:
# 2025-07-30 02:07:53.611 | INFO     | __main__:run_predictions_async:15 - Processing chunk 0 to 4
# 2025-07-30 02:07:53.612 | INFO     | __main__:run_predictions_async:19 - Sending 5 requests to the vLLM server...
# 2025-07-30 02:07:55.132 | INFO     | __main__:get_prediction:37 - Generated SQL for index 5: select distinct medication.routeadmin from medication where medication.drugname = 'zolpidem tartrate 5 mg po tabs';
# 2025-07-30 02:07:55.187 | INFO     | __main__:get_prediction:37 - Generated SQL for index 3: select distinct medication.routeadmin from medication where medication.drugname = 'morphine 2 mg/1 ml 1 ml syr';
# 2025-07-30 02:07:55.214 | INFO     | __main__:get_prediction:37 - Generated SQL for index 2: select distinct intakeoutput.celllabel from intakeoutput where intakeoutput.celllabel = 'clonidine' and intakeoutput.cellpath like '%intake%';
# 2025-07-30 02:07:55.307 | INFO     | __main__:get_prediction:37 - Generated SQL for index 1: select distinct treatment.treatmentname from treatment where treatment.treatmentname = 'dextrose 5% in water (d5w) iv : 1000 ml bag';
# 2025-07-30 02:07:55.854 | INFO     | __main__:get_prediction:37 - Generated SQL for index 4: select distinct intakeoutput.celllabel from intakeoutput where intakeoutput.cellpath like '%intake%' and intakeoutput.celllabel = 'propofol 1000 mg/100 ml (pmx)';
# 2025-07-30 02:07:55.855 | SUCCESS  | __main__:run_predictions_async:21 - All predictions done.
# 2025-07-30 02:07:55.855 | INFO     | __main__:run_predictions_async:15 - Processing chunk 5 to 9
# 2025-07-30 02:07:55.855 | INFO     | __main__:run_predictions_async:19 - Sending 5 requests to the vLLM server...
# 2025-07-30 02:07:56.394 | INFO     | __main__:get_prediction:37 - Generated SQL for index 6: select distinct treatment.treatmentname from treatment where treatment.treatmentname = 'vancomycin inj 1,000 mg vial.';
# 2025-07-30 02:07:56.719 | INFO     | __main__:get_prediction:37 - Generated SQL for index 8: select distinct cost.cost from cost where cost.eventtype = 'treatment' and cost.eventid in ( select treatment.treatmentid from treatment where treatment.treatmentname = 'angiography - pulmonary angiogram' ) order by cost.cost asc;
# 2025-07-30 02:07:56.720 | INFO     | __main__:get_prediction:37 - Generated SQL for index 7: select distinct cost.cost from cost where cost.eventtype = 'treatment' and cost.eventid in ( select treatment.treatmentid from treatment where treatment.treatmentname = 'internal fixation' ) order by cost.chargetime desc limit 1;
# 2025-07-30 02:07:57.060 | INFO     | __main__:get_prediction:37 - Generated SQL for index 10: select distinct cost.cost from cost where cost.eventtype = 'treatment' and cost.eventid in ( select treatment.treatmentid from treatment where treatment.treatmentname = 'insertion of venous catheter for hemodialysis - percutaneous catheter' ) and cost.chargetime <= datetime('2105-12-31 23:59:00');
# 2025-07-30 02:07:57.502 | INFO     | __main__:get_prediction:37 - Generated SQL for index 9: select distinct cost.cost from cost where cost.eventtype = 'treatment' and cost.eventid in ( select treatment.treatmentid from treatment where treatment.treatmentname = 'thoracoscopic procedure - wedge resection' ) and cost.chargetime <= datetime('2105-12-31 23:59:00');
# 2025-07-30 02:07:57.503 | SUCCESS  | __main__:run_predictions_async:21 - All predictions done.
# 2025-07-30 02:07:57.503 | INFO     | __main__:run_predictions_async:15 - Processing chunk 10 to 14
# 2025-07-30 02:07:57.504 | INFO     | __main__:run_predictions_async:19 - Sending 5 requests to the vLLM server...
# 2025-07-30 02:07:58.090 | INFO     | __main__:get_prediction:37 - Generated SQL for index 11: select distinct cost.cost from cost join treatment on cost.eventid = treatment.treatmentid where treatment.treatmentname = 'focussed abdominal sonography';
# 2025-07-30 02:07:58.126 | INFO     | __main__:get_prediction:37 - Generated SQL for index 15: select distinct cost.cost from cost join medication on cost.eventid = medication.medicationid where medication.drugname = 'nitroglycerin - oral';
# 2025-07-30 02:07:58.414 | INFO     | __main__:get_prediction:37 - Generated SQL for index 12: select distinct cost.cost from cost where cost.eventtype = 'treatment' and cost.eventid in ( select treatment.treatmentid from treatment where treatment.treatmentname = 'bronchodilator - beta-agonist' ) and cost.cost is not null;
# 2025-07-30 02:07:58.440 | INFO     | __main__:get_prediction:37 - Generated SQL for index 13: select distinct cost.cost from cost where cost.eventtype = 'medication' and cost.eventid in ( select medication.medicationid from medication where medication.drugname = 'antihypertensives - hydralazine' ) order by cost.chargetime asc;
# 2025-07-30 02:07:58.610 | INFO     | __main__:get_prediction:37 - Generated SQL for index 14: select distinct cost.cost from cost where cost.eventtype = 'lab' and cost.eventname = 'bicarbonate - sodium bicarbonate';
# 2025-07-30 02:07:58.611 | SUCCESS  | __main__:run_predictions_async:21 - All predictions done.
# 2025-07-30 02:07:58.611 | INFO     | __main__:run_predictions_async:15 - Processing chunk 15 to 19
# 2025-07-30 02:07:58.611 | INFO     | __main__:run_predictions_async:19 - Sending 5 requests to the vLLM server...
# 2025-07-30 02:07:59.160 | INFO     | __main__:get_prediction:37 - Generated SQL for index 17: select distinct cost.cost from cost join lab on cost.eventid = lab.labid where lab.labname = 'folate';
# 2025-07-30 02:07:59.324 | INFO     | __main__:get_prediction:37 - Generated SQL for index 18: select sum(cost) from cost where eventtype = 'lab' and eventid in ( select lab.labid from lab where lab.labname = 'total co2' );
# 2025-07-30 02:07:59.417 | INFO     | __main__:get_prediction:37 - Generated SQL for index 16: select distinct cost.cost from cost where cost.eventtype = 'lab' and cost.eventid in ( select lab.labid from lab where lab.labname = 'methemoglobin' ) order by cost.chargetime asc;
# 2025-07-30 02:07:59.430 | INFO     | __main__:get_prediction:37 - Generated SQL for index 20: select distinct cost.cost from cost where cost.eventtype = 'treatment' and cost.eventid in ( select treatment.treatmentid from treatment where treatment.treatmentname = '-basos' ) order by cost.chargetime asc;
# 2025-07-30 02:07:59.911 | INFO     | __main__:get_prediction:37 - Generated SQL for index 19: select distinct cost.cost from cost where cost.eventtype = 'lab' and cost.eventid in ( select lab.labid from lab where lab.labname = 'ph' ) order by cost.chargetime asc;
# 2025-07-30 02:07:59.912 | SUCCESS  | __main__:run_predictions_async:21 - All predictions done.
# 2025-07-30 02:07:59.912 | INFO     | __main__:run_predictions_async:15 - Processing chunk 20 to 24
# 2025-07-30 02:07:59.912 | INFO     | __main__:run_predictions_async:19 - Sending 5 requests to the vLLM server...
# 2025-07-30 02:08:00.500 | INFO     | __main__:get_prediction:37 - Generated SQL for index 23: select distinct cost.cost from cost join medication on cost.eventid = medication.medicationid where medication.drugname = 'klonopin';
# 2025-07-30 02:08:00.705 | INFO     | __main__:get_prediction:37 - Generated SQL for index 21: select distinct cost.cost from cost where cost.eventtype = 'treatment' and cost.eventid in ( select treatment.treatmentid from treatment where treatment.treatmentname = 'vent other' ) order by cost.cost asc;
# 2025-07-30 02:08:00.718 | INFO     | __main__:get_prediction:37 - Generated SQL for index 22: select distinct cost.cost from cost where cost.eventtype = 'lab' and cost.eventid in ( select lab.labid from lab where lab.labname = 'chloride' ) order by cost.chargetime asc;
# 2025-07-30 02:08:01.139 | INFO     | __main__:get_prediction:37 - Generated SQL for index 25: select distinct cost.cost from cost where cost.eventtype = 'medication' and cost.eventid in ( select medication.medicationid from medication where medication.drugname = 'milk of magnesia ud liq 30 ml' ) and cost.chargetime <= datetime('2105-12-31 23:59:00');
# 2025-07-30 02:08:01.451 | INFO     | __main__:get_prediction:37 - Generated SQL for index 24: select distinct cost.cost from cost where cost.eventtype = 'medication' and cost.eventid in ( select medication.medicationid from medication where medication.drugname = 'aspirin 81 mg chewable tablet' ) order by cost.chargetime asc limit 1;
# 2025-07-30 02:08:01.452 | SUCCESS  | __main__:run_predictions_async:21 - All predictions done.
# 2025-07-30 02:08:01.452 | INFO     | __main__:run_predictions_async:15 - Processing chunk 25 to 29
# 2025-07-30 02:08:01.453 | INFO     | __main__:run_predictions_async:19 - Sending 5 requests to the vLLM server...
# 2025-07-30 02:08:02.308 | INFO     | __main__:get_prediction:37 - Generated SQL for index 30: select distinct cost.cost from cost where cost.eventtype = 'diagnosis' and cost.eventid in ( select diagnosis.diagnosisid from diagnosis where diagnosis.diagnosisname = 'oral thrush' ) order by cost.chargetime asc;
# 2025-07-30 02:08:02.310 | INFO     | __main__:get_prediction:37 - Generated SQL for index 27: select distinct cost.cost from cost where cost.eventtype = 'medication' and cost.eventid in ( select medication.medicationid from medication where medication.drugname = 'cephulac' ) order by cost.chargetime asc;
# 2025-07-30 02:08:02.352 | INFO     | __main__:get_prediction:37 - Generated SQL for index 28: select distinct cost.cost from cost where cost.eventtype = 'medication' and cost.eventid in ( select medication.medicationid from medication where medication.drugname = 'sodium chloride 0.9%' ) and cost.cost is not null;
# 2025-07-30 02:08:02.496 | INFO     | __main__:get_prediction:37 - Generated SQL for index 26: select distinct cost.cost from cost where cost.eventtype = 'medication' and cost.eventid in ( select medication.medicationid from medication where medication.drugname = '4 ml vial: furosemide 10 mg/ml ij soln' ) order by cost.chargetime desc limit 1;
# 2025-07-30 02:08:03.042 | INFO     | __main__:get_prediction:37 - Generated SQL for index 29: SELECT cost.cost FROM cost WHERE cost.eventtype = 'medication' AND cost.eventid IN (SELECT medication.medicationid FROM medication WHERE medication.drugname = 'epinephrine' ) ORDER BY cost.chargetime ASC;
# 2025-07-30 02:08:03.042 | SUCCESS  | __main__:run_predictions_async:21 - All predictions done.
# 2025-07-30 02:08:03.043 | INFO     | __main__:run_predictions_async:15 - Processing chunk 30 to 34
# 2025-07-30 02:08:03.043 | INFO     | __main__:run_predictions_async:19 - Sending 5 requests to the vLLM server...
# 2025-07-30 02:08:03.843 | INFO     | __main__:get_prediction:37 - Generated SQL for index 35: select distinct cost.cost from cost where cost.eventtype = 'diagnosis' and cost.eventid in ( select diagnosis.diagnosisid from diagnosis where diagnosis.diagnosisname = 'coronary artery disease - known' );
# 2025-07-30 02:08:03.928 | INFO     | __main__:get_prediction:37 - Generated SQL for index 33: select distinct cost.cost from cost where cost.eventtype = 'diagnosis' and cost.eventid in ( select diagnosis.diagnosisid from diagnosis where diagnosis.diagnosisname = 'acute pulmonary edema' ) order by cost.cost asc limit 1;
# 2025-07-30 02:08:03.982 | INFO     | __main__:get_prediction:37 - Generated SQL for index 32: select distinct cost.cost from cost where cost.eventtype = 'diagnosis' and cost.eventid in ( select diagnosis.diagnosisid from diagnosis where diagnosis.diagnosisname = 'acute respiratory distress - etiology unknown' ) order by cost.chargetime desc limit 1;
# 2025-07-30 02:08:04.022 | INFO     | __main__:get_prediction:37 - Generated SQL for index 31: select distinct cost.cost from cost where cost.eventtype = 'diagnosis' and cost.eventid in ( select diagnosis.diagnosisid from diagnosis where diagnosis.diagnosisname = 'benzodiazepine overdose - with decreased mental status' ) order by cost.cost asc limit 1;
# 2025-07-30 02:08:04.958 | INFO     | __main__:get_prediction:37 - Generated SQL for index 34: select distinct cost.cost from cost where cost.eventtype = 'diagnosis' and cost.eventid in ( select diagnosis.diagnosisid from diagnosis where diagnosis.diagnosisname = 'acute lung injury - etiology unknown' ) and cost.chargetime <= datetime('2105-12-31 23:59:00');
# 2025-07-30 02:08:04.958 | SUCCESS  | __main__:run_predictions_async:21 - All predictions done.
# 2025-07-30 02:08:04.959 | INFO     | __main__:run_predictions_async:15 - Processing chunk 35 to 39
# 2025-07-30 02:08:04.959 | INFO     | __main__:run_predictions_async:19 - Sending 5 requests to the vLLM server...
# 2025-07-30 02:08:05.374 | INFO     | __main__:get_prediction:37 - Generated SQL for index 38: SELECT patient.gender FROM patient WHERE patient.uniquepid = '015-66570';
# 2025-07-30 02:08:05.389 | INFO     | __main__:get_prediction:37 - Generated SQL for index 40: SELECT patient.gender FROM patient WHERE patient.uniquepid = '006-227759';
# 2025-07-30 02:08:05.432 | INFO     | __main__:get_prediction:37 - Generated SQL for index 37: select patient.gender from patient where patient.uniquepid = '028-40370';
# 2025-07-30 02:08:05.761 | INFO     | __main__:get_prediction:37 - Generated SQL for index 39: SELECT patient.gender FROM patient WHERE patient.uniquepid = '015-76706';
# 2025-07-30 02:08:06.112 | INFO     | __main__:get_prediction:37 - Generated SQL for index 36: select distinct cost.cost from cost where cost.eventtype = 'diagnosis' and cost.eventid in ( select diagnosis.diagnosisid from diagnosis where diagnosis.diagnosisname = 'pacemaker/aicd dysfunction' ) and cost.chargetime <= datetime('2105-12-31 23:59:00');
# 2025-07-30 02:08:06.112 | SUCCESS  | __main__:run_predictions_async:21 - All predictions done.
# 2025-07-30 02:08:06.113 | INFO     | __main__:run_predictions_async:15 - Processing chunk 40 to 44
# 2025-07-30 02:08:06.113 | INFO     | __main__:run_predictions_async:19 - Sending 5 requests to the vLLM server...
# 2025-07-30 02:08:07.091 | INFO     | __main__:get_prediction:37 - Generated SQL for index 43: select strftime('%J',hospitaldischargetime) - strftime('%J',hospitaladmittime) from patient where uniquepid = '028-47306' and hospitaldischargetime is not null order by hospitaladmittime desc limit 1;
# 2025-07-30 02:08:07.216 | INFO     | __main__:get_prediction:37 - Generated SQL for index 41: select strftime('%J',patient.hospitaldischargetime) - strftime('%J',patient.hospitaladmittime) from patient where patient.uniquepid = '006-146580' and patient.hospitaldischargetime is not null order by patient.hospitaladmittime desc limit 1;
# 2025-07-30 02:08:07.243 | INFO     | __main__:get_prediction:37 - Generated SQL for index 45: select strftime('%J',patient.hospitaldischargetime) - strftime('%J',patient.hospitaladmittime) from patient where patient.uniquepid = '006-65780' and patient.hospitaldischargetime is not null order by patient.patienthealthsystemstayid desc limit 1;
# 2025-07-30 02:08:07.770 | INFO     | __main__:get_prediction:37 - Generated SQL for index 42: select
#     strftime('%J',patient.hospitaldischargetime)) -
#     strftime('%J',patient.hospitaladmittime))
# from patient
# where patient.uniquepid = '002-52932'
#     and patient.hospitaldischargetime is not null
#     and patient.patienthealthsystemstayid =
#         ( select max(patienthealthsystemstayid) from patient where uniquepid = '002-52932' );
# 2025-07-30 02:08:08.173 | INFO     | __main__:get_prediction:37 - Generated SQL for index 44: select strftime('%J',patient.hospitaldischargetime) - strftime('%J',patient.hospitaladmittime) from patient where patient.uniquepid = '015-75226' and patient.hospitaldischargetime is not null order by patient.patienthealthsystemstayid asc limit 1;
# 2025-07-30 02:08:08.174 | SUCCESS  | __main__:run_predictions_async:21 - All predictions done.
# 2025-07-30 02:08:08.174 | INFO     | __main__:run_predictions_async:15 - Processing chunk 45 to 49
# 2025-07-30 02:08:08.174 | INFO     | __main__:run_predictions_async:19 - Sending 5 requests to the vLLM server...
# 2025-07-30 02:08:09.135 | INFO     | __main__:get_prediction:37 - Generated SQL for index 46: select strftime('%J',hospitaldischargetime) - strftime('%J',hospitaladmittime) from patient where uniquepid = '017-74343' and hospitaldischargetime is not null order by hospitaladmittime desc limit 1;
# 2025-07-30 02:08:09.298 | INFO     | __main__:get_prediction:37 - Generated SQL for index 50: select ( strftime('%J',hospitaldischargetime) - strftime('%J',hospitaladmittime) ) * 86400 as los from patient where uniquepid = '032-32248' and hospitaldischargetime is not null order by hospitaladmittime desc limit 1;
# 2025-07-30 02:08:09.312 | INFO     | __main__:get_prediction:37 - Generated SQL for index 48: select strftime('%J',patient.hospitaldischargetime) - strftime('%J',patient.hospitaladmittime) from patient where patient.uniquepid = '017-101310' and patient.hospitaldischargetime is not null order by patient.patienthealthsystemstayid asc limit 1;
# 2025-07-30 02:08:09.404 | INFO     | __main__:get_prediction:37 - Generated SQL for index 47: select ( strftime('%J',patient.hospitaldischargetime) - strftime('%J',patient.hospitaladmittime) ) * 86400 from patient where patient.uniquepid = '016-5052' and patient.hospitaldischargetime is not null order by patient.patienthealthsystemstayid asc limit 1;
# 2025-07-30 02:08:10.183 | INFO     | __main__:get_prediction:37 - Generated SQL for index 49: select strftime('%J',patient.hospitaldischargetime) - strftime('%J',patient.hospitaladmittime) from patient where patient.uniquepid = '011-58352' and patient.hospitaldischargetime is not null order by patient.hospitaladmittime desc limit 1;
# 2025-07-30 02:08:10.183 | SUCCESS  | __main__:run_predictions_async:21 - All predictions done.
# 2025-07-30 02:08:10.184 | INFO     | __main__:run_predictions_async:15 - Processing chunk 50 to 54
# 2025-07-30 02:08:10.184 | INFO     | __main__:run_predictions_async:19 - Sending 5 requests to the vLLM server...
# 2025-07-30 02:08:11.236 | INFO     | __main__:get_prediction:37 - Generated SQL for index 53: select ( strftime('%J',hospitaldischargetime) - strftime('%J',hospitaladmittime) ) * 24 from patient where uniquepid = '035-22706' and hospitaldischargetime is not null order by hospitaladmittime desc limit 1;
# 2025-07-30 02:08:11.293 | INFO     | __main__:get_prediction:37 - Generated SQL for index 51: select ( strftime('%J',patient.hospitaldischargetime) - strftime('%J',patient.hospitaladmittime) ) * 86400 as los
# from patient
# where patient.uniquepid = '016-1459'
# order by patient.hospitaladmittime desc
# limit 1;
# 2025-07-30 02:08:11.865 | INFO     | __main__:get_prediction:37 - Generated SQL for index 55: select ( strftime('%J',patient.unitdischargetime) - strftime('%J',patient.hospitaladmittime) ) * 24 from patient where patient.uniquepid = '025-37114' and patient.patienthealthsystemstayid = ( select patient.patienthealthsystemstayid from patient where patient.uniquepid = '025-37114' order by patient.hospitaladmittime asc limit 1 ) order by patient.unitadmittime asc limit 1;
# 2025-07-30 02:08:11.944 | INFO     | __main__:get_prediction:37 - Generated SQL for index 52: select ( strftime('%J',patient.hospitaldischargetime) - strftime('%J',patient.hospitaladmittime) ) * 86400 from patient where patient.uniquepid = '027-107035' and patient.patienthealthsystemstayid = ( select patient.patienthealthsystemstayid from patient where patient.uniquepid = '027-107035' order by patient.hospitaladmittime asc limit 1 ) order by patient.unitadmittime asc limit 1;
# 2025-07-30 02:08:12.334 | INFO     | __main__:get_prediction:37 - Generated SQL for index 54: select strftime('%J',patient.hospitaldischargetime) - strftime('%J',patient.hospitaladmittime) from patient where patient.uniquepid = '006-245995' and patient.hospitaldischargetime is not null order by patient.patienthealthsystemstayid asc limit 1;
# 2025-07-30 02:08:12.335 | SUCCESS  | __main__:run_predictions_async:21 - All predictions done.
# 2025-07-30 02:08:12.336 | INFO     | __main__:run_predictions_async:15 - Processing chunk 55 to 59
# 2025-07-30 02:08:12.336 | INFO     | __main__:run_predictions_async:19 - Sending 5 requests to the vLLM server...
# 2025-07-30 02:08:14.038 | INFO     | __main__:get_prediction:37 - Generated SQL for index 56: select (lab.labresult - lab.labresulttime) * 24 * 60 * 60 from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '018-47575' and patient.hospitaldischargetime is not null order by patient.hospitaldischargetime desc limit 1 ) and lab.labname = 'admissionweight' order by lab.labresulttime asc limit 1 offset 1;
# 2025-07-30 02:08:14.168 | INFO     | __main__:get_prediction:37 - Generated SQL for index 57: select (dischargeweight - admissionweight) * 100 from patient where uniquepid = '010-12376' and patienthealthsystemstayid = ( select patienthealthsystemstayid from patient where patient.uniquepid = '010-12376' and patient.patienthealthsystemstayid = ( select min(patient.patienthealthsystemstayid) from patient where patient.uniquepid = '010-12376' ) ) and ( dischargeweight is not null or admissionweight is not null );
# 2025-07-30 02:08:14.767 | INFO     | __main__:get_prediction:37 - Generated SQL for index 60: select ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '021-49416' and patient.hospitaldischargestatus = 'alive' ) and lab.labname = 'admissionweight' order by lab.labresulttime asc limit 1 offset 1 ) - ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '021-49416' and patient.hospitaldischargestatus = 'alive' ) and lab.labname = 'admissionweight' order by lab.labresulttime asc limit 1 );
# 2025-07-30 02:08:15.055 | INFO     | __main__:get_prediction:37 - Generated SQL for index 58: select (dischargeweight - ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '006-161415' and patient.hospitaldischargestatus = 'alive' order by patient.hospitaladmittime asc limit 1 ) and lab.labname = 'dischargeweight' order by lab.labresulttime desc limit 1 ) ) from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '006-161415' and patient.hospitaldischargestatus = 'alive' order by patient.hospitaladmittime asc limit 1 ) and lab.labname = 'dischargeweight' order by lab.labresulttime desc limit 1 );
# 2025-07-30 02:08:16.927 | INFO     | __main__:get_prediction:37 - Generated SQL for index 59: select (lab.labresult - lab2.labresultnumeric) from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '021-240586' ) and lab.labname = 'admissionweight' and lab.labresulttime = '2101-12-16 20:24:00' union all select (lab.labresult - lab2.labresultnumeric) from lab lab2 join lab on lab2.patientunitstayid = lab.patientunitstayid where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '021-240586' ) and lab.labname = 'admissionweight' and lab.labresulttime = '2101-10-12 15:58:00';
# 2025-07-30 02:08:16.927 | SUCCESS  | __main__:run_predictions_async:21 - All predictions done.
# 2025-07-30 02:08:16.928 | INFO     | __main__:run_predictions_async:15 - Processing chunk 60 to 64
# 2025-07-30 02:08:16.928 | INFO     | __main__:run_predictions_async:19 - Sending 5 requests to the vLLM server...
# 2025-07-30 02:08:17.709 | INFO     | __main__:get_prediction:37 - Generated SQL for index 61: select (dischargeweight - admissionweight) * 100.0 / admissionweight from patient where uniquepid = '006-202970' and hospitaldischargestatus is null;
# 2025-07-30 02:08:19.428 | INFO     | __main__:get_prediction:37 - Generated SQL for index 62: select ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '012-4131' ) and lab.labname = 'admissionweight' and lab.labresulttime = '2105-11-20 19:30:00' ) - ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '012-4131' ) and lab.labname = 'admissionweight' and lab.labresulttime = '2105-02-17 01:25:00' );
# 2025-07-30 02:08:19.454 | INFO     | __main__:get_prediction:37 - Generated SQL for index 65: select ( select patient.admissionweight from patient where patient.uniquepid = '007-9115' and patient.patienthealthsystemstayid = ( select patient.patienthealthsystemstayid from patient where patient.uniquepid = '007-9115' order by patient.hospitaladmittime asc limit 1 ) order by patient.unitadmittime desc limit 1 ) - ( select patient.admissionweight from patient where patient.uniquepid = '007-9115' and patient.patienthealthsystemstayid = ( select patient.patienthealthsystemstayid from patient where patient.uniquepid = '007-9115' order by patient.hospitaladmittime asc limit 1 ) order by patient.unitadmittime asc limit 1 );
# 2025-07-30 02:08:19.705 | INFO     | __main__:get_prediction:37 - Generated SQL for index 63: select ( select patient.admissionweight from patient where patient.uniquepid = '007-13494' and patient.patienthealthsystemstayid = ( select patient.patienthealthsystemstayid from patient where patient.uniquepid = '007-13494' and patient.hospitaldischargestatus = 'alive' order by patient.hospitaladmittime asc limit 1 ) ) - ( select patient.dischargeweight from patient where patient.uniquepid = '007-13494' and patient.patienthealthsystemstayid = ( select patient.patienthealthsystemstayid from patient where patient.uniquepid = '007-13494' and patient.hospitaldischargestatus = 'alive' order by patient.hospitaladmittime asc limit 1 ) order by patient.unitadmittime desc limit 1 );
# 2025-07-30 02:08:20.317 | INFO     | __main__:get_prediction:37 - Generated SQL for index 64: select ( select patient.admissionweight from patient where patient.uniquepid = '006-161415' and patient.patienthealthsystemstayid = ( select patient.patienthealthsystemstayid from patient where patient.uniquepid = '006-161415' order by patient.hospitaladmittime asc limit 1 ) order by patient.unitadmittime desc limit 1 ) - ( select patient.admissionweight from patient where patient.uniquepid = '006-161415' and patient.patienthealthsystemstayid = ( select patient.patienthealthsystemstayid from patient where patient.uniquepid = '006-161415' order by patient.hospitaladmittime asc limit 1 ) order by patient.unitadmittime desc limit 2 );
# 2025-07-30 02:08:20.318 | SUCCESS  | __main__:run_predictions_async:21 - All predictions done.
# 2025-07-30 02:08:20.319 | INFO     | __main__:run_predictions_async:15 - Processing chunk 65 to 69
# 2025-07-30 02:08:20.319 | INFO     | __main__:run_predictions_async:19 - Sending 5 requests to the vLLM server...
# 2025-07-30 02:08:22.653 | INFO     | __main__:get_prediction:37 - Generated SQL for index 68: select ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '035-24054' and patient.hospitaldischargestatus is null ) and lab.labname = 'hgb' order by lab.labresulttime asc limit 1 offset 1 ) - ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '035-24054' and patient.hospitaldischargestatus is null ) and lab.labname = 'hgb' order by lab.labresulttime asc limit 1 );
# 2025-07-30 02:08:22.684 | INFO     | __main__:get_prediction:37 - Generated SQL for index 67: select ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '006-195316' and patient.hospitaldischargetime is null ) and lab.labname = 'creatinine' order by lab.labresulttime desc limit 1 ) - ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '006-195316' and patient.hospitaldischargetime is null ) and lab.labname = 'creatinine' order by lab.labresulttime desc limit 2 offset 1 );
# 2025-07-30 02:08:22.698 | INFO     | __main__:get_prediction:37 - Generated SQL for index 70: select ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '005-68848' order by patient.hospitaldischargetime desc limit 1 ) and lab.labname = 'sodium' order by lab.labresulttime desc limit 1 ) - ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '005-68848' order by patient.hospitaldischargetime desc limit 1 ) and lab.labname = 'sodium' order by lab.labresulttime asc limit 1 );
# 2025-07-30 02:08:22.961 | INFO     | __main__:get_prediction:37 - Generated SQL for index 66: select ( select patient.admissionweight from patient where patient.uniquepid = '006-146580' and patient.patienthealthsystemstayid = ( select patient.patienthealthsystemstayid from patient where patient.uniquepid = '006-146580' order by patient.hospitaladmittime asc limit 1 ) order by patient.unitadmittime asc limit 1 offset 1 ) - ( select patient.admissionweight from patient where patient.uniquepid = '006-146580' and patient.patienthealthsystemstayid = ( select patient.patienthealthsystemstayid from patient where patient.uniquepid = '006-146580' order by patient.hospitaladmittime asc limit 1 ) order by patient.unitadmittime asc limit 1 );
# 2025-07-30 02:08:25.896 | INFO     | __main__:get_prediction:37 - Generated SQL for index 69: select ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '010-37449' and patient.patienthealthsystemstayid = ( select patient.patienthealthsystemstayid from patient where patient.uniquepid = '010-37449' order by patient.hospitaladmittime asc limit 1 ) ) and lab.labname = 'hct' order by lab.labresulttime desc limit 1 ) - ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '010-37449' and patient.patienthealthsystemstayid = ( select patient.patienthealthsystemstayid from patient where patient.uniquepid = '010-37449' order by patient.hospitaladmittime asc limit 1 ) ) and lab.labname = 'hct' order by lab.labresulttime asc limit 1 );
# 2025-07-30 02:08:25.897 | SUCCESS  | __main__:run_predictions_async:21 - All predictions done.
# 2025-07-30 02:08:25.897 | INFO     | __main__:run_predictions_async:15 - Processing chunk 70 to 74
# 2025-07-30 02:08:25.898 | INFO     | __main__:run_predictions_async:19 - Sending 5 requests to the vLLM server...
# 2025-07-30 02:08:28.392 | INFO     | __main__:get_prediction:37 - Generated SQL for index 72: select ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '030-16826' ) and lab.labname = 'bun' and lab.labresulttime = '2104-06-17 13:25:00' ) - ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '030-16826' ) and lab.labname = 'bun' and lab.labresulttime = '2104-06-13 12:26:00' );
# 2025-07-30 02:08:28.643 | INFO     | __main__:get_prediction:37 - Generated SQL for index 71: select ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '027-10308' and patient.hospitaldischargetime is not null order by patient.hospitaldischargetime desc limit 1 ) and lab.labname = 'bedside glucose' order by lab.labresulttime desc limit 1 ) - ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '027-10308' and patient.hospitaldischargetime is not null order by patient.hospitaldischargetime desc limit 1 ) and lab.labname = 'bedside glucose' order by lab.labresulttime desc limit 1 offset 1 );
# 2025-07-30 02:08:28.644 | INFO     | __main__:get_prediction:37 - Generated SQL for index 75: select ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '016-3041' and patient.hospitaldischargestatus = 'alive' order by patient.hospitaladmittime asc limit 1 ) and lab.labname = 'sodium' order by lab.labresulttime asc limit 2 offset 1 ) - ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '016-3041' and patient.hospitaldischargestatus = 'alive' order by patient.hospitaladmittime asc limit 1 ) and lab.labname = 'sodium' order by lab.labresulttime asc limit 1 ) );
# 2025-07-30 02:08:28.671 | INFO     | __main__:get_prediction:37 - Generated SQL for index 73: select ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '002-59265' and patient.hospitaldischargestatus = 'alive' order by patient.hospitaladmittime asc limit 1 ) and lab.labname = 'peep' order by lab.labresulttime desc limit 1 ) - ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '002-59265' and patient.hospitaldischargestatus = 'alive' order by patient.hospitaladmittime asc limit 1 ) and lab.labname = 'peep' order by lab.labresulttime desc limit 1 offset 1 ) );
# 2025-07-30 02:08:30.593 | INFO     | __main__:get_prediction:37 - Generated SQL for index 74: select ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '005-4471' and patient.hospitaldischargestatus is null ) and lab.labname = 'bun' order by lab.labresulttime asc limit 1 offset 1 ) - ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '005-4471' and patient.hospitaldischargestatus is null ) and lab.labname = 'bun' order by lab.labresulttime asc limit 1 );
# 2025-07-30 02:08:30.594 | SUCCESS  | __main__:run_predictions_async:21 - All predictions done.
# 2025-07-30 02:08:30.594 | INFO     | __main__:run_predictions_async:15 - Processing chunk 75 to 79
# 2025-07-30 02:08:30.595 | INFO     | __main__:run_predictions_async:19 - Sending 5 requests to the vLLM server...
# 2025-07-30 02:08:32.858 | INFO     | __main__:get_prediction:37 - Generated SQL for index 80: select ( select vitalperiodic.respiration from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '027-203413' ) and vitalperiodic.respiration is not null order by vitalperiodic.observationtime desc limit 1 ) - ( select vitalperiodic.respiration from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '027-203413' ) and vitalperiodic.respiration is not null order by vitalperiodic.observationtime desc limit 1 offset 1 );
# 2025-07-30 02:08:33.111 | INFO     | __main__:get_prediction:37 - Generated SQL for index 76: select ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '027-120477' ) and lab.labname = 'sodium' and lab.labresulttime = '2104-01-04 13:15:00' ) - ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '027-120477' ) and lab.labname = 'sodium' and lab.labresulttime = '2104-01-03 05:32:00' );
# 2025-07-30 02:08:33.191 | INFO     | __main__:get_prediction:37 - Generated SQL for index 78: select (select vitalperiodic.sao2 from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '004-93782' and patient.unitdischargetime is not null order by patient.unitadmittime asc limit 1 ) order by vitalperiodic.observationtime asc limit 1 offset 1) - (select vitalperiodic.sao2 from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '004-93782' and patient.unitdischargetime is not null order by patient.unitadmittime asc limit 1 ) order by vitalperiodic.observationtime asc limit 1);
# 2025-07-30 02:08:33.362 | INFO     | __main__:get_prediction:37 - Generated SQL for index 77: select ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '015-67291' and patient.hospitaldischargestatus = 'alive' order by patient.hospitaladmittime asc limit 1 ) and lab.labname = 'hct' order by lab.labresulttime desc limit 1 ) - ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '015-67291' and patient.hospitaldischargestatus = 'alive' order by patient.hospitaladmittime asc limit 1 ) and lab.labname = 'hct' order by lab.labresulttime desc limit 2 offset 1 ) );
# 2025-07-30 02:08:35.155 | INFO     | __main__:get_prediction:37 - Generated SQL for index 79: select ( select vitalperiodic.temperature from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '004-13127' ) and vitalperiodic.observationtime = '2105-12-31 22:49:00' ) - ( select vitalperiodic.temperature from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '004-13127' ) and vitalperiodic.observationtime = '2105-12-31 22:54:00' );
# 2025-07-30 02:08:35.155 | SUCCESS  | __main__:run_predictions_async:21 - All predictions done.
# 2025-07-30 02:08:35.156 | INFO     | __main__:run_predictions_async:15 - Processing chunk 80 to 84
# 2025-07-30 02:08:35.156 | INFO     | __main__:run_predictions_async:19 - Sending 5 requests to the vLLM server...
# 2025-07-30 02:08:37.432 | INFO     | __main__:get_prediction:37 - Generated SQL for index 81: select ( select vitalperiodic.respiration from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '022-67644' order by patient.unitadmittime desc limit 1 ) order by vitalperiodic.observationtime asc limit 1 ) - ( select vitalperiodic.respiration from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '022-67644' order by patient.unitadmittime desc limit 1 ) order by vitalperiodic.observationtime asc limit 1 offset 1 );
# 2025-07-30 02:08:37.446 | INFO     | __main__:get_prediction:37 - Generated SQL for index 82: select ( select vitalperiodic.heartrate from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '013-28507' ) and vitalperiodic.heartrate is not null order by vitalperiodic.observationtime asc limit 1 ) - ( select vitalperiodic.heartrate from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '013-28507' ) and vitalperiodic.heartrate is not null order by vitalperiodic.observationtime asc limit 1 offset 1 );
# 2025-07-30 02:08:37.600 | INFO     | __main__:get_prediction:37 - Generated SQL for index 83: select ( select vitalperiodic.heartrate from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '015-96048' ) and vitalperiodic.observationtime = '2105-08-15 09:57:00' ) - ( select vitalperiodic.heartrate from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '015-96048' ) and vitalperiodic.observationtime = '2105-08-15 09:52:00' );
# 2025-07-30 02:08:37.601 | INFO     | __main__:get_prediction:37 - Generated SQL for index 85: select ( select vitalperiodic.heartrate from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '027-94096' ) and vitalperiodic.observationtime = '2104-07-27 12:18:40' ) - ( select vitalperiodic.heartrate from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '027-94096' ) and vitalperiodic.observationtime = '2104-07-27 12:13:40' );
# 2025-07-30 02:08:39.900 | INFO     | __main__:get_prediction:37 - Generated SQL for index 84: select ( select vitalperiodic.heartrate from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '015-94586' and patient.unitdischargetime is not null order by patient.unitadmittime asc limit 1 ) order by vitalperiodic.observationtime asc limit 1 offset 1 ) - ( select vitalperiodic.heartrate from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '015-94586' and patient.unitdischargetime is not null order by patient.unitadmittime asc limit 1 ) order by vitalperiodic.observationtime asc limit 1 ) );
# 2025-07-30 02:08:39.901 | SUCCESS  | __main__:run_predictions_async:21 - All predictions done.
# 2025-07-30 02:08:39.901 | INFO     | __main__:run_predictions_async:15 - Processing chunk 85 to 89
# 2025-07-30 02:08:39.902 | INFO     | __main__:run_predictions_async:19 - Sending 5 requests to the vLLM server...
# 2025-07-30 02:08:42.251 | INFO     | __main__:get_prediction:37 - Generated SQL for index 88: select ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '006-133605' and patient.hospitaldischargestatus is null ) and lab.labname = 'lactate' order by lab.labresulttime desc limit 1 ) > ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '006-133605' and patient.hospitaldischargestatus is null ) and lab.labname = 'lactate' order by lab.labresulttime asc limit 1 );
# 2025-07-30 02:08:42.419 | INFO     | __main__:get_prediction:37 - Generated SQL for index 86: select ( select vitalperiodic.respiration from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '006-36108' and patient.unitdischargetime is not null order by patient.unitadmittime asc limit 1 ) order by vitalperiodic.observationtime desc limit 1 ) - ( select vitalperiodic.respiration from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '006-36108' and patient.unitdischargetime is not null order by patient.unitadmittime asc limit 1 ) order by vitalperiodic.observationtime asc limit 1 ) );
# 2025-07-30 02:08:42.619 | INFO     | __main__:get_prediction:37 - Generated SQL for index 90: select ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '022-98345' and patient.hospitaldischargetime is not null order by patient.hospitaldischargetime desc limit 1 ) and lab.labname = 'mch' order by lab.labresulttime asc limit 1 offset 1 ) < ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '022-98345' and patient.hospitaldischargetime is not null order by patient.hospitaldischargetime desc limit 1 ) and lab.labname = 'mch' order by lab.labresulttime asc limit 1 );
# 2025-07-30 02:08:43.329 | INFO     | __main__:get_prediction:37 - Generated SQL for index 87: select ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '035-11731' and patient.patienthealthsystemstayid = ( select patient.patienthealthsystemstayid from patient where patient.uniquepid = '035-11731' order by patient.hospitaladmittime asc limit 1 ) ) and lab.labname = '-eos' order by lab.labresulttime desc limit 1 ) < ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '035-11731' and patient.patienthealthsystemstayid = ( select patient.patienthealthsystemstayid from patient where patient.uniquepid = '035-11731' order by patient.hospitaladmittime asc limit 1 ) ) and lab.labname = '-eos' order by lab.labresulttime desc limit 2 offset 1 );
# 2025-07-30 02:08:45.705 | INFO     | __main__:get_prediction:37 - Generated SQL for index 89: select ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '027-69449' and patient.patienthealthsystemstayid = ( select patient.patienthealthsystemstayid from patient where patient.uniquepid = '027-69449' order by patient.hospitaladmittime asc limit 1 ) ) and lab.labname = 'platelets x 1000' order by lab.labresulttime desc limit 1 ) < ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '027-69449' and patient.patienthealthsystemstayid = ( select patient.patienthealthsystemstayid from patient where patient.uniquepid = '027-69449' order by patient.hospitaladmittime asc limit 1 ) ) and lab.labname = 'platelets x 1000' order by lab.labresulttime desc limit 2 offset 1 );
# 2025-07-30 02:08:45.706 | SUCCESS  | __main__:run_predictions_async:21 - All predictions done.
# 2025-07-30 02:08:45.706 | INFO     | __main__:run_predictions_async:15 - Processing chunk 90 to 94
# 2025-07-30 02:08:45.707 | INFO     | __main__:run_predictions_async:19 - Sending 5 requests to the vLLM server...
# 2025-07-30 02:08:47.986 | INFO     | __main__:get_prediction:37 - Generated SQL for index 91: select ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '009-5001' and patient.hospitaldischargestatus is null ) and lab.labname = 'bedside glucose' order by lab.labresulttime desc limit 1 ) > ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '009-5001' and patient.hospitaldischargestatus is null ) and lab.labname = 'bedside glucose' order by lab.labresulttime asc limit 1 );
# 2025-07-30 02:08:48.210 | INFO     | __main__:get_prediction:37 - Generated SQL for index 92: select ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '007-15837' and patient.hospitaldischargestatus is null ) and lab.labname = 'wbc x 1000' order by lab.labresulttime desc limit 1 ) < ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '007-15837' and patient.hospitaldischargestatus is null ) and lab.labname = 'wbc x 1000' order by lab.labresulttime desc limit 2 offset 1 );
# 2025-07-30 02:08:48.304 | INFO     | __main__:get_prediction:37 - Generated SQL for index 95: select ( select vitalperiodic.systemicsystolic from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '006-146580' and patient.unitdischargetime is not null order by patient.unitadmittime asc limit 1 ) order by vitalperiodic.observationtime desc limit 1 ) < ( select vitalperiodic.systemicsystolic from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '006-146580' and patient.unitdischargetime is not null order by patient.unitadmittime asc limit 1 ) order by vitalperiodic.observationtime asc limit 1 );
# ...
# 2025-07-30 02:23:34.835 | INFO     | __main__:get_prediction:37 - Generated SQL for index 1755: select count(*) > 0 from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '015-21757' ) and lab.labname like '%genetic%';
# 2025-07-30 02:23:35.666 | INFO     | __main__:get_prediction:37 - Generated SQL for index 1754: select count(*) > 0 from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '031-3507' ) and lab.labname like '%genetic%';
# 2025-07-30 02:23:35.667 | SUCCESS  | __main__:run_predictions_async:21 - All predictions done.
# 2025-07-30 02:23:35.667 | INFO     | __main__:run_predictions_async:15 - Processing chunk 1755 to 1759
# 2025-07-30 02:23:35.668 | INFO     | __main__:run_predictions_async:19 - Sending 5 requests to the vLLM server...
# 2025-07-30 02:23:36.549 | INFO     | __main__:get_prediction:37 - Generated SQL for index 1756: select lab.labname from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '010-9756' ) and lab.labname like '%genetic%';
# 2025-07-30 02:23:36.579 | INFO     | __main__:get_prediction:37 - Generated SQL for index 1757: select lab.labname from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '012-18025' ) and lab.labname like '%genetic%';
# 2025-07-30 02:23:36.581 | INFO     | __main__:get_prediction:37 - Generated SQL for index 1758: select lab.labname from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '027-95744' ) and lab.labname like '%genetic%';
# 2025-07-30 02:23:36.593 | INFO     | __main__:get_prediction:37 - Generated SQL for index 1760: select count(*) > 0 from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '035-15069' ) and lab.labname like '%genetic%';
# 2025-07-30 02:23:37.306 | INFO     | __main__:get_prediction:37 - Generated SQL for index 1759: select count(*) > 0 from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '028-55503' );
# 2025-07-30 02:23:37.307 | SUCCESS  | __main__:run_predictions_async:21 - All predictions done.
# 2025-07-30 02:23:37.308 | INFO     | __main__:run_predictions_async:15 - Processing chunk 1760 to 1764
# 2025-07-30 02:23:37.308 | INFO     | __main__:run_predictions_async:19 - Sending 5 requests to the vLLM server...
# 2025-07-30 02:23:38.215 | INFO     | __main__:get_prediction:37 - Generated SQL for index 1761: select count(*) > 0 from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '016-35481' ) and lab.labname = 'genetic test';
# 2025-07-30 02:23:38.228 | INFO     | __main__:get_prediction:37 - Generated SQL for index 1762: select count(*) > 0 from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '030-10407' ) and lab.labname = 'genetic test';
# 2025-07-30 02:23:38.272 | INFO     | __main__:get_prediction:37 - Generated SQL for index 1765: select count(*) > 0 from treatment where treatment.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '007-4119' ) and treatment.treatmentname = 'sputum, tracheal specimen';
# 2025-07-30 02:23:39.086 | INFO     | __main__:get_prediction:37 - Generated SQL for index 1764: select count(*) > 0 from treatment where treatmentname = 'additional sputum, expectorated test' and patientunitstayid in ( select patientunitstayid from patient where uniquepid = '027-136480' );
# 2025-07-30 02:23:39.827 | INFO     | __main__:get_prediction:37 - Generated SQL for index 1763: select
#     t1.uniquepid,
#     t1.patienthealthsystemstayid,
#     t1.hospitaladmittime,
#     t2.treatmentname,
#     t2.treatmenttime,
#     t3.labname,
#     t3.labresulttime
# from patient t1
# left join treatment t2 on t1.patientunitstayid = t2.patientunitstayid
# left join lab t3 on t1.patientunitstayid = t3.patientunitstayid
# where
#     t1.uniquepid = '006-80884'
#     and (t2.treatmentname like '%additional blood%'
#          or t3.labname like '%venipuncture%');
# 2025-07-30 02:23:39.827 | SUCCESS  | __main__:run_predictions_async:21 - All predictions done.
# 2025-07-30 02:23:39.828 | INFO     | __main__:run_predictions_async:15 - Processing chunk 1765 to 1769
# 2025-07-30 02:23:39.828 | INFO     | __main__:run_predictions_async:19 - Sending 5 requests to the vLLM server...
# 2025-07-30 02:23:40.429 | INFO     | __main__:get_prediction:37 - Generated SQL for index 1770: select count(*) > 0 from patient where patient.uniquepid = '007-15837' and patient.gender = 'female';
# 2025-07-30 02:23:40.793 | INFO     | __main__:get_prediction:37 - Generated SQL for index 1766: select count(*) > 0 from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '010-20205' ) and lab.labname = 'sputum, tracheal specimen';
# 2025-07-30 02:23:40.806 | INFO     | __main__:get_prediction:37 - Generated SQL for index 1767: select count(*) > 0 from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '007-16517' ) and lab.labname = 'sputum, expectorated';
# 2025-07-30 02:23:40.807 | INFO     | __main__:get_prediction:37 - Generated SQL for index 1768: select count(*) > 0 from treatment where treatment.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '005-11182' ) and treatment.treatmentname = 'additional blood, venipuncture test';
# 2025-07-30 02:23:41.611 | INFO     | __main__:get_prediction:37 - Generated SQL for index 1769: select count(*) > 0 from treatment where treatmentname = 'additional blood, venipuncture test' and patientunitstayid in ( select patientunitstayid from patient where uniquepid = '005-77687' ) and treatmenttime < datetime('2105-12-31 23:59:00');
# 2025-07-30 02:23:41.611 | SUCCESS  | __main__:run_predictions_async:21 - All predictions done.
# 2025-07-30 02:23:41.612 | INFO     | __main__:run_predictions_async:15 - Processing chunk 1770 to 1774
# 2025-07-30 02:23:41.612 | INFO     | __main__:run_predictions_async:19 - Sending 5 requests to the vLLM server...
# 2025-07-30 02:23:42.299 | INFO     | __main__:get_prediction:37 - Generated SQL for index 1771: select count(*) > 1 from lab where patientunitstayid in (select patientunitstayid from patient where uniquepid = '032-9230' );
# 2025-07-30 02:23:42.556 | INFO     | __main__:get_prediction:37 - Generated SQL for index 1775: select count(*) > 0 from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '009-424' ) and lab.labname = 'urine, voided specimen';
# 2025-07-30 02:23:42.557 | INFO     | __main__:get_prediction:37 - Generated SQL for index 1773: select count(*) from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '010-32430' ) and lab.labname = 'sputum, tracheal specimen';
# 2025-07-30 02:23:42.582 | INFO     | __main__:get_prediction:37 - Generated SQL for index 1772: select count(*) > 0 from microlab where patientunitstayid in ( select patientunitstayid from patient where uniquepid = '030-10407' ) and culturesite in ( 'sputum', 'tracheal specimen' );
# 2025-07-30 02:23:43.272 | INFO     | __main__:get_prediction:37 - Generated SQL for index 1774: select count(*) > 0 from treatment where treatment.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '021-50282' ) and treatment.treatmentname in ( 'additional blood', 'venipuncture test' );
# 2025-07-30 02:23:43.273 | SUCCESS  | __main__:run_predictions_async:21 - All predictions done.
# 2025-07-30 02:23:43.273 | INFO     | __main__:run_predictions_async:15 - Processing chunk 1775 to 1779
# 2025-07-30 02:23:43.273 | INFO     | __main__:run_predictions_async:19 - Sending 5 requests to the vLLM server...
# 2025-07-30 02:23:44.126 | INFO     | __main__:get_prediction:37 - Generated SQL for index 1777: select distinct t1.treatmenttime from treatment t1 where t1.treatmentname = 'dr. young's rounds' union select distinct t2.treatmenttime from treatment t2 where t2.treatmentname = 'dr. young's procedures';
# 2025-07-30 02:23:44.156 | INFO     | __main__:get_prediction:37 - Generated SQL for index 1780: select distinct t1.treatmenttime from treatment t1 where t1.treatmentname = 'dr. oneill's rounds' union select distinct t2.treatmenttime from treatment t2 where t2.treatmentname = 'dr. oneill's procedures';
# 2025-07-30 02:23:44.209 | INFO     | __main__:get_prediction:37 - Generated SQL for index 1776: select count(*) > 0 from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '027-203413' ) and lab.labname = 'nasopharynx test';
# 2025-07-30 02:23:45.298 | INFO     | __main__:get_prediction:37 - Generated SQL for index 1778: select
#     treatment.treatmenttime,
#     patient.uniquepid,
#     patient.patientunitstayid,
#     patient.wardid,
#     patient.hospitalid,
#     treatment.treatmentname
# from treatment
# join patient on treatment.patientunitstayid = patient.patientunitstayid
# where treatment.treatmentname like '%dr. canpos%'
#     or treatment.treatmentname like '%rounds%'
#     or treatment.treatmentname like '%procedures%'
#     or treatment.treatmentname like '%dr. canpos%'
# order by treatment.treatmenttime asc;
# 2025-07-30 02:23:45.960 | INFO     | __main__:get_prediction:37 - Generated SQL for index 1779: select
#     treatment.treatmenttime,
#     patient.uniquepid,
#     patient.patientunitstayid,
#     patient.hospitalid,
#     patient.wardid,
#     treatment.treatmentname
# from treatment
# join patient on treatment.patientunitstayid = patient.patientunitstayid
# where treatment.treatmentname like '%dr. sullivan%'
#     or treatment.treatmentname like '%sullivan%'
#     or treatment.treatmentname like '%rounds%'
#     or treatment.treatmentname like '%procedures%';
# 2025-07-30 02:23:45.961 | SUCCESS  | __main__:run_predictions_async:21 - All predictions done.
# 2025-07-30 02:23:45.961 | INFO     | __main__:run_predictions_async:15 - Processing chunk 1780 to 1784
# 2025-07-30 02:23:45.962 | INFO     | __main__:run_predictions_async:19 - Sending 5 requests to the vLLM server...
# 2025-07-30 02:23:46.844 | INFO     | __main__:get_prediction:37 - Generated SQL for index 1782: select distinct t1.treatmenttime from treatment t1 where t1.treatmentname = 'dr. williams's rounds' union select distinct t2.treatmenttime from treatment t2 where t2.treatmentname = 'dr. williams's procedures';
# 2025-07-30 02:23:46.846 | INFO     | __main__:get_prediction:37 - Generated SQL for index 1783: select distinct t1.treatmenttime from treatment t1 where t1.treatmentname = 'dr. lail's rounds' union select distinct t2.treatmenttime from treatment t2 where t2.treatmentname = 'dr. lail's procedures';
# 2025-07-30 02:23:46.858 | INFO     | __main__:get_prediction:37 - Generated SQL for index 1781: select distinct t1.treatmenttime from treatment t1 where t1.treatmentname = 'dr. shears's rounds' union select distinct t2.treatmenttime from treatment t2 where t2.treatmentname = 'dr. shears's procedures';
# 2025-07-30 02:23:47.845 | INFO     | __main__:get_prediction:37 - Generated SQL for index 1785: select
#     treatment.treatmenttime,
#     patient.uniquepid,
#     patient.patientunitstayid,
#     patient.wardid,
#     patient.hospitalid,
#     treatment.treatmentname
# from treatment
# join patient on treatment.patientunitstayid = patient.patientunitstayid
# where treatment.treatmentname like '%dr. moore%'
#     or treatment.treatmentname like '%moore%'
#     or treatment.treatmentname like '%rounds%'
#     or treatment.treatmentname like '%procedures%';
# 2025-07-30 02:23:48.636 | INFO     | __main__:get_prediction:37 - Generated SQL for index 1784: select
#     treatment.treatmenttime,
#     patient.uniquepid,
#     patient.patientunitstayid,
#     patient.hospitalid,
#     patient.wardid,
#     treatment.treatmentname
# from treatment
# join patient on treatment.patientunitstayid = patient.patientunitstayid
# where treatment.treatmentname like '%dr. conerly%'
#     or treatment.treatmentname like '%rounds%'
#     or treatment.treatmentname like '%procedures%'
# order by treatment.treatmenttime asc;
# 2025-07-30 02:23:48.637 | SUCCESS  | __main__:run_predictions_async:21 - All predictions done.
# 2025-07-30 02:23:48.637 | INFO     | __main__:run_predictions_async:15 - Processing chunk 1785 to 1789
# 2025-07-30 02:23:48.638 | INFO     | __main__:run_predictions_async:19 - Sending 5 requests to the vLLM server...
# 2025-07-30 02:23:49.118 | INFO     | __main__:get_prediction:37 - Generated SQL for index 1787: select distinct treatment.treatmenttime from treatment where treatment.treatmentname = 'dr. ford's rounds and procedures';
# 2025-07-30 02:23:49.508 | INFO     | __main__:get_prediction:37 - Generated SQL for index 1786: select distinct t1.treatmenttime from treatment t1 where t1.treatmentname = 'dr. martin's rounds' union select distinct t2.treatmenttime from treatment t2 where t2.treatmentname = 'dr. martin's procedures';
# 2025-07-30 02:23:49.521 | INFO     | __main__:get_prediction:37 - Generated SQL for index 1788: select distinct t1.treatmenttime from treatment t1 where t1.treatmentname = 'dr. smith's rounds' union select distinct t2.treatmenttime from treatment t2 where t2.treatmentname = 'dr. smith's procedure';
# 2025-07-30 02:23:49.966 | INFO     | __main__:get_prediction:37 - Generated SQL for index 1789: select distinct t1.treatmenttime from treatment t1 where t1.treatmentname = 'dr. hurdle's rounds' union select distinct t2.treatmenttime from treatment t2 where t2.treatmentname = 'dr. hurdle's procedures';
# 2025-07-30 02:23:50.758 | INFO     | __main__:get_prediction:37 - Generated SQL for index 1790: select
#     treatment.treatmenttime,
#     patient.uniquepid,
#     patient.patientunitstayid,
#     patient.hospitalid,
#     patient.wardid,
#     treatment.treatmentname
# from treatment
# join patient on treatment.patientunitstayid = patient.patientunitstayid
# where treatment.treatmentname like '%dr. coburn%'
#     or treatment.treatmentname like '%rounds%'
#     or treatment.treatmentname like '%procedures%'
#     or treatment.treatmentname like '%dr. coburn rounds%'
#     or treatment.treatmentname like '%dr. coburn procedures%';
# 2025-07-30 02:23:50.759 | SUCCESS  | __main__:run_predictions_async:21 - All predictions done.
# 2025-07-30 02:23:50.760 | INFO     | __main__:run_predictions_async:15 - Processing chunk 1790 to 1794
# 2025-07-30 02:23:50.760 | INFO     | __main__:run_predictions_async:19 - Sending 2 requests to the vLLM server...
# 2025-07-30 02:23:51.605 | INFO     | __main__:get_prediction:37 - Generated SQL for index 1791: select distinct t1.treatmenttime from treatment t1 where t1.treatmentname = 'dr. davis's rounds' union select distinct t2.treatmenttime from treatment t2 where t2.treatmentname = 'dr. davis's procedures';
# 2025-07-30 02:23:51.618 | INFO     | __main__:get_prediction:37 - Generated SQL for index 1792: select distinct t1.treatmenttime from treatment t1 where t1.treatmentname = 'dr. holmes's rounds' union select distinct t2.treatmenttime from treatment t2 where t2.treatmentname = 'dr. holmes's procedures';
# 2025-07-30 02:23:51.619 | SUCCESS  | __main__:run_predictions_async:21 - All predictions done.
# 2025-07-30 02:23:51.636 | SUCCESS  | __main__:run_predictions_async:37 - Predictions saved to ../model_predictions/eICU/mistral_nemo_minitron_8B_finetuned/trial_1/predictions.json
# 2025-07-30 02:23:51.638 | SUCCESS  | __main__:<module>:23 - Model mistral_nemo_minitron_8B_finetuned. Trial 1 completed. Time taken: 958.07 seconds

# %% [markdown]
# Note the time taken

# %% [markdown]
# # Evaluate SQL query
#
# To evaluate the SQL query, we will execute BOTH the ground truth SQL statement and the predicted SQL statement against the SQL database, and compare their outcomes

# %%
import os
from utils import preprare_directory

# create output directory for evaluation results, relative to the path of model_evaluation directory
# note that the evaluate results need a clean new folder, because it will overwrite any existing files in the folder
pred_directory = f"../model_predictions/eICU/mistral_nemo_minitron_8B_finetuned/trial_{trial_number}"
eval_directory = os.path.join(pred_directory, "evaluation")
preprare_directory(eval_directory, exist_ok=False)

# the predicted file from previous step
pred_file = os.path.join(pred_directory, "predictions.json")

print("Using predictions from: ", pred_file)

# path to the eICU database
db_path = "../model_evaluation/databases/eicu.sqlite"
# Out:
# Using predictions from:  ../model_predictions/eICU/mistral_nemo_minitron_8B_finetuned/trial_1/predictions.json

# %%
# run evaluation
# !python ../model_evaluation/ehrsql_eval.py \
    --pred_file {pred_file} \
    --db_path {db_path} \
    --num_workers -1 \
    --timeout 60 \
    --out_file {eval_directory} \
    --ndigits 2

# %% [markdown]
# # Interpret results

# %%
fp = f"../model_predictions/eICU/mistral_nemo_minitron_8B_finetuned/trial_{trial_number}/evaluation/predictions_metrics.json"

with open(fp, "r") as f:
    metrics = json.load(f)

print(json.dumps(metrics, indent=4))
# Out:
# {
#     "precision_ans": 100.0,
#     "recall_ans": 95.81,
#     "f1_ans": 97.86,
#     "precision_exec": 47.35,
#     "recall_exec": 45.37,
#     "f1_exec": 46.34,
#     "acc": 45.37
# }
