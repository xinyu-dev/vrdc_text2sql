# %% [markdown]
# # Benchmark eICU using finetuned mistral nemo minitron 8B

# %%
import os
from openai import OpenAI
from loguru import logger
import sys
sys.path.append(os.path.abspath(os.path.join('..', 'model_evaluation')))

# %% [markdown]
# # Set up client

# %%
import asyncio
from openai import AsyncOpenAI
import json
from loguru import logger

# Re-using vLLM server details from previous cells
IP = "localhost"
PORT = 8000
BASE_URL = f"http://{IP}:{PORT}/v1"
MODEL_PATH = "/home/ubuntu/workspace/mistral-nemo-minitron-8b-instruct-healthcare-text2sql_vV2.8"

# Initialize the AsyncOpenAI client
async_client = AsyncOpenAI(
    api_key="not-needed",
    base_url=BASE_URL,
)

# %%
from utils import postprocess_sql_query_from_markdown

async def get_prediction(record: dict) -> str:
    """
    Generates a SQL query for a given record asynchronously.
    """
    index = record['index']
    ddl = record['ddl']
    instruction = record['instructions']
    question = record['user_query']
    output = record['output'] # ground truth SQL statement

    prompt_chat_template = [
        {
            "role": "system",
            "content": f"Based on DDL statements, instructions, generate a SQLite query to answer the user's question.\n\nDDL statements:\n{ddl}\nInstructions:\n{instruction}",
        },
        {
            "role": "user",
            "content": f"{question}"
        }
    ]

    try:
        response = await async_client.chat.completions.create(
            model=MODEL_PATH,
            messages=prompt_chat_template,
            temperature=0.0,
            max_tokens=512,
            stop=["<extra_id_1>"]
        )
        generated_sql = response.choices[0].message.content
        prediction = postprocess_sql_query_from_markdown(generated_sql)
        logger.info(f"Generated SQL for index {index}: {prediction}") 

        return {
            "index": index,
            "input": question, # user query
            "predict": prediction,  # model predicted SQL
            "real": output # ground truth SQL
        }
        
    except Exception as e:
        logger.error(f"An error occurred for index {record.get('index', 'N/A')}: {e}")
        return f"Error: {e}"

# %%
async def run_predictions_async(test_fp: str, output_fp: str):
    """
    Loads a test set and runs predictions asynchronously.
    """
    # Path to the mini test set
    with open(test_fp, "r") as f:
        test_data = json.load(f)

    tasks = [get_prediction(record) for record in test_data]
    
    logger.info(f"Sending {len(tasks)} requests to the vLLM server...")
    predictions = await asyncio.gather(*tasks)
    logger.success("All predictions done.")

    # add predictions to the test data by looking up the index
    results = []
    for pred in predictions:
        # create a dictionary with the index and prediction
        results.append({
            "index": pred['index'],
            "input": pred['input'],
            "predict": pred['predict'], 
            "real": pred['real']
        })

    # handle if the output file does not exist
    with open(output_fp, "w") as f:
        json.dump(results, f, indent=2)

    logger.success(f"Predictions saved to {output_fp}")

# %% [markdown]
# # Generate queries

# %%
from utils import preprare_directory
from time import time

# model name 
model_name = "mistral_nemo_minitron_8B_finetuned"

# trial number 
trial_number = 1    

# create output directory. set exist_ok=False to delete the old results and re-create a fresh folder
output_dir = f"../model_predictions/eICU/{model_name}/trial_{trial_number}"    
preprare_directory(output_dir, exist_ok=False)

# input test set directory
test_data_dir = "../model_evaluation/dataset/test"
test_data_fp = os.path.join(test_data_dir, "test_ehrsql_eicu_data.json")


# run predictions
start_time = time()
# run predictions
await run_predictions_async(
    test_fp = test_data_fp,
    output_fp = os.path.join(output_dir, "predictions.json")
)
end_time = time()
logger.success(f"Model {model_name}. Trial {trial_number} completed. Time taken: {end_time - start_time:.2f} seconds")
# Out:
# 2025-07-27 04:55:28.285 | INFO     | __main__:run_predictions_async:11 - Sending 1792 requests to the vLLM server...
# 2025-07-27 04:56:36.148 | INFO     | __main__:get_prediction:34 - Generated SQL for index 2: select distinct medication.routeadmin from medication where medication.drugname = 'clonidine';
# 2025-07-27 04:56:36.386 | INFO     | __main__:get_prediction:34 - Generated SQL for index 5: select distinct medication.routeadmin from medication where medication.drugname = 'zolpidem tartrate 5 mg po tabs';
# 2025-07-27 04:56:36.861 | INFO     | __main__:get_prediction:34 - Generated SQL for index 6: select distinct treatment.treatmentname from treatment where treatment.treatmentname = 'vancomycin inj 1,000 mg vial';
# 2025-07-27 04:56:36.862 | INFO     | __main__:get_prediction:34 - Generated SQL for index 3: select distinct medication.routeadmin from medication where medication.drugname = 'morphine 2 mg/1 ml 1 ml syr';
# 2025-07-27 04:56:37.546 | INFO     | __main__:get_prediction:34 - Generated SQL for index 11: select distinct cost.cost from cost join treatment on cost.patienthealthsystemstayid = treatment.patientunitstayid where treatment.treatmentname = 'focussed abdominal sonography';
# 2025-07-27 04:56:37.969 | INFO     | __main__:get_prediction:34 - Generated SQL for index 10: select distinct cost.cost from cost where cost.eventtype = 'Procedure' and cost.uniquepid in ( select patient.uniquepid from patient ) and cost.eventtype = 'Insertion of venous catheter for hemodialysis - percutaneous catheter';
# 2025-07-27 04:56:38.201 | INFO     | __main__:get_prediction:34 - Generated SQL for index 9: select distinct cost.cost from cost where cost.eventtype = 'Procedure' and cost.eventid = ( select diagnosis.diagnosisid from diagnosis where diagnosis.diagnosisname = 'thoracoscopic procedure - wedge resection' );
# 2025-07-27 04:56:38.441 | INFO     | __main__:get_prediction:34 - Generated SQL for index 14: select distinct cost.cost from cost where cost.eventtype = 'Medication' and cost.eventid in ( select medication.medicationid from medication where medication.drugname = 'bicarbonate - sodium bicarbonate' ) order by cost.cost asc limit 1;
# 2025-07-27 04:56:38.678 | INFO     | __main__:get_prediction:34 - Generated SQL for index 4: select distinct medication.routeadmin from medication where medication.drugname = 'propofol 1000 mg/100 ml (pmx)';
# 2025-07-27 04:56:39.217 | INFO     | __main__:get_prediction:34 - Generated SQL for index 17: select distinct cost.cost from cost join lab on cost.patienthealthsystemstayid = lab.patientunitstayid where lab.labname = 'folate';
# 2025-07-27 04:56:39.888 | INFO     | __main__:get_prediction:34 - Generated SQL for index 12: select distinct cost.cost from cost where cost.eventtype = 'Medication' and cost.eventid in ( select medication.medicationid from medication where medication.drugname = 'bronchodilator - beta-agonist' ) order by cost.cost;
# 2025-07-27 04:56:39.889 | INFO     | __main__:get_prediction:34 - Generated SQL for index 18: select sum(cost) from cost where cost.eventtype = 'LAB' and cost.eventid in ( select lab.labid from lab where lab.labname = 'total co2' );
# 2025-07-27 04:56:40.766 | INFO     | __main__:get_prediction:34 - Generated SQL for index 8: select distinct cost.cost from cost where cost.eventtype = 'Procedure' and cost.eventid in ( select treatment.treatmentid from treatment where treatment.treatmentname = 'angiography - pulmonary angiogram' ) order by cost.cost asc;
# 2025-07-27 04:56:40.995 | INFO     | __main__:get_prediction:34 - Generated SQL for index 19: select distinct cost.cost from cost join lab on cost.patienthealthsystemstayid = lab.patientunitstayid where lab.labname = 'ph';
# 2025-07-27 04:56:41.418 | INFO     | __main__:get_prediction:34 - Generated SQL for index 20: select distinct cost.cost from cost where cost.eventtype = 'medication' and cost.uniquepid in ( select patient.uniquepid from patient where patient.uniquepid in ( select diagnosis.patientunitstayid from diagnosis where diagnosis.diagnosisname = '-basos' ) ) and cost.chargetime is not null;
# 2025-07-27 04:56:41.649 | INFO     | __main__:get_prediction:34 - Generated SQL for index 7: select distinct cost.cost from cost where cost.eventtype = 'Procedure' and cost.eventid in ( select treatment.treatmentid from treatment where treatment.treatmentname = 'internal fixation' ) order by cost.cost;
# 2025-07-27 04:56:42.025 | INFO     | __main__:get_prediction:34 - Generated SQL for index 16: select distinct cost.cost from cost join lab on cost.patienthealthsystemstayid = lab.patientunitstayid where lab.labname = 'methemoglobin';
# 2025-07-27 04:56:42.475 | INFO     | __main__:get_prediction:34 - Generated SQL for index 22: select distinct cost.cost from cost where cost.eventtype = 'Lab' and cost.uniquepid in ( select patient.uniquepid from patient ) and cost.cost is not null;
# 2025-07-27 04:56:43.111 | INFO     | __main__:get_prediction:34 - Generated SQL for index 21: select distinct cost.cost from cost where cost.eventtype = 'vent other';
# 2025-07-27 04:56:43.579 | INFO     | __main__:get_prediction:34 - Generated SQL for index 23: select distinct cost.cost from cost join medication on cost.patienthealthsystemstayid = medication.patientunitstayid where medication.drugname = 'klonopin';
# 2025-07-27 04:56:43.580 | INFO     | __main__:get_prediction:34 - Generated SQL for index 24: select distinct cost.cost from cost join medication on cost.uniquepid = medication.patientunitstayid where medication.drugname = 'aspirin 81 mg chewable tablet';
# 2025-07-27 04:56:43.809 | INFO     | __main__:get_prediction:34 - Generated SQL for index 15: select distinct cost.cost from cost join medication on cost.patienthealthsystemstayid = medication.patientunitstayid where medication.drugname = 'nitroglycerin - oral';
# 2025-07-27 04:56:44.411 | INFO     | __main__:get_prediction:34 - Generated SQL for index 31: select distinct cost.cost from cost join diagnosis on cost.patienthealthsystemstayid = diagnosis.patientunitstayid where diagnosis.diagnosisname = 'benzodiazepine overdose - with decreased mental status';
# 2025-07-27 04:56:44.412 | INFO     | __main__:get_prediction:34 - Generated SQL for index 25: select distinct cost.cost from cost join medication on cost.patienthealthsystemstayid = medication.patientunitstayid where medication.drugname = 'milk of magnesia ud liq 30 ml';
# 2025-07-27 04:56:44.829 | INFO     | __main__:get_prediction:34 - Generated SQL for index 26: select distinct cost.cost from cost where cost.eventtype = 'Medication' and cost.eventid in ( select medication.medicationid from medication where medication.drugname = '4 ml vial: furosemide 10 mg/ml ij soln' ) order by cost.chargetime desc limit 1;
# 2025-07-27 04:56:45.474 | INFO     | __main__:get_prediction:34 - Generated SQL for index 34: select distinct cost.cost from cost join diagnosis on cost.patienthealthsystemstayid = diagnosis.patientunitstayid where diagnosis.diagnosisname = 'acute lung injury - etiology unknown';
# 2025-07-27 04:56:45.703 | INFO     | __main__:get_prediction:34 - Generated SQL for index 28: select distinct cost.cost from cost where cost.eventtype = 'Medication' and cost.uniquepid in ( select patient.uniquepid from patient ) and cost.eventid in ( select medication.medicationid from medication where medication.drugname = 'Sodium Chloride 0.9%' ) order by cost.chargetime asc;
# 2025-07-27 04:56:45.930 | INFO     | __main__:get_prediction:34 - Generated SQL for index 35: select distinct cost.cost from cost where cost.uniquepid in ( select patient.uniquepid from patient where patient.patientunitstayid in ( select diagnosis.patientunitstayid from diagnosis where diagnosis.diagnosisname = 'coronary artery disease - known' ) ) and cost.eventtype = 'diagnosis';
# 2025-07-27 04:56:46.493 | INFO     | __main__:get_prediction:34 - Generated SQL for index 32: select distinct cost.cost from cost join diagnosis on cost.patienthealthsystemstayid = diagnosis.patientunitstayid where diagnosis.diagnosisname = 'acute respiratory distress - etiology unknown';
# 2025-07-27 04:56:46.494 | INFO     | __main__:get_prediction:34 - Generated SQL for index 36: select distinct cost.cost from cost where cost.uniquepid in ( select patient.uniquepid from patient where patient.patienthealthsystemstayid in ( select diagnosis.patientunitstayid from diagnosis where diagnosis.diagnosisname = 'pacemaker/aicd dysfunction' ) ) and cost.eventtype = 'diagnosis';
# 2025-07-27 04:56:46.943 | INFO     | __main__:get_prediction:34 - Generated SQL for index 39: SELECT patient.gender FROM patient WHERE patient.uniquepid = '015-76706';
# 2025-07-27 04:56:46.944 | INFO     | __main__:get_prediction:34 - Generated SQL for index 30: select distinct cost.cost from cost join diagnosis on cost.patienthealthsystemstayid = diagnosis.patientunitstayid where diagnosis.diagnosisname = 'oral thrush';
# 2025-07-27 04:56:47.170 | INFO     | __main__:get_prediction:34 - Generated SQL for index 38: SELECT patient.gender FROM patient WHERE patient.uniquepid = '015-66570';
# 2025-07-27 04:56:47.400 | INFO     | __main__:get_prediction:34 - Generated SQL for index 37: SELECT gender FROM patient WHERE uniquepid = '028-40370';
# 2025-07-27 04:56:48.312 | INFO     | __main__:get_prediction:34 - Generated SQL for index 27: select distinct cost.cost from cost where cost.eventtype = 'Medication' and cost.uniquepid in ( select patient.uniquepid from patient where patient.uniquepid in ( select diagnosis.patientunitstayid from diagnosis where diagnosis.diagnosisname = 'cephulac' ) ) order by cost.cost asc limit 1;
# 2025-07-27 04:56:48.655 | INFO     | __main__:get_prediction:34 - Generated SQL for index 41: select strftime('%J',patient.hospitaldischargetime) - strftime('%J',patient.hospitaladmittime) from patient where patient.uniquepid = '006-146580' and patient.hospitaldischargestatus = 'Discharged' order by patient.patienthealthsystemstayid desc limit 1;
# 2025-07-27 04:56:49.118 | INFO     | __main__:get_prediction:34 - Generated SQL for index 43: select strftime('%J',hospitaldischargetime) - strftime('%J',hospitaladmittime) from patient where uniquepid = '028-47306' and hospitaldischargestatus = 'Discharged' order by hospitaladmittime desc limit 1;
# 2025-07-27 04:56:49.411 | INFO     | __main__:get_prediction:34 - Generated SQL for index 40: SELECT patient.gender FROM patient WHERE patient.uniquepid = '006-227759';
# 2025-07-27 04:56:49.873 | INFO     | __main__:get_prediction:34 - Generated SQL for index 42: select ( strftime('%J',patient.hospitaldischargetime) - strftime('%J',patient.hospitaladmittime) ) / 100 as length_of_stay
# from patient
# where patient.uniquepid = '002-52932'
#     and patient.hospitaldischargestatus = 'Discharged'
#     and patient.hospitaldischargetime is not null
# order by patient.hospitaladmittime desc
# limit 1;
# 2025-07-27 04:56:50.098 | INFO     | __main__:get_prediction:34 - Generated SQL for index 44: SELECT  strftime('%J',hospitaldischargetime) - strftime('%J',hospitaladmittime) FROM patient WHERE uniquepid = '015-75226' AND hospitaldischargetime IS NOT NULL ORDER BY hospitaladmittime ASC LIMIT 1;
# 2025-07-27 04:56:51.094 | INFO     | __main__:get_prediction:34 - Generated SQL for index 46: SELECT MAX(hospitaldischargetime) - MIN(hospitaladmittime) FROM patient WHERE uniquepid = '017-74343';
# 2025-07-27 04:56:51.579 | INFO     | __main__:get_prediction:34 - Generated SQL for index 13: select distinct cost.cost from cost where cost.eventtype = 'Medication' and cost.uniquepid in ( select patient.uniquepid from patient where patient.uniquepid in ( select diagnosis.patientunitstayid from diagnosis where diagnosis.diagnosisname = 'Antihypertensives - Hydralazine' ) ) and cost.chargetime is not null;
# 2025-07-27 04:56:52.246 | INFO     | __main__:get_prediction:34 - Generated SQL for index 47: select ( strftime('%J',patient.hospitaldischargetime) - strftime('%J',patient.hospitaladmittime) ) * 24 from patient where patient.uniquepid = '016-5052' and patient.patienthealthsystemstayid = ( select patient.patienthealthsystemstayid from patient where patient.uniquepid = '016-5052' order by patient.hospitaladmittime asc limit 1 ) order by patient.unitadmittime asc limit 1;
# 2025-07-27 04:56:52.786 | INFO     | __main__:get_prediction:34 - Generated SQL for index 50: select
#     strftime('%J',patient.hospitaldischargetime)) -
#     strftime('%J',patient.hospitaladmittime)) as los
# from patient
# where patient.uniquepid = '032-32248'
#     and patient.hospitaldischargestatus = 'Discharged'
#     and patient.hospitaldischargetime is not null
# order by patient.hospitaladmittime desc limit 1;
# 2025-07-27 04:56:53.246 | INFO     | __main__:get_prediction:34 - Generated SQL for index 53: select (dischargeweight - admissionweight) * 1.0 from patient where uniquepid = '035-22706' and hospitaldischargestatus = 'Discharged' order by hospitaladmittime desc limit 1;
# 2025-07-27 04:56:53.657 | INFO     | __main__:get_prediction:34 - Generated SQL for index 48: select ( strftime('%J',patient.hospitaldischargetime) - strftime('%J',patient.hospitaladmittime) ) / ( 24 * 60 * 60 ) from patient where patient.uniquepid = '017-101310' and patient.hospitaldischargestatus = 'Discharged' order by patient.hospitaladmittime asc limit 1;
# 2025-07-27 04:56:54.628 | INFO     | __main__:get_prediction:34 - Generated SQL for index 54: select ( strftime('%J',hospitaldischargetime) - strftime('%J',hospitaladmittime) ) / ( 24 * 60 * 60 ) from patient where uniquepid = '006-245995' and hospitaldischargestatus = 'Discharged' order by patienthealthsystemstayid asc limit 1;
# 2025-07-27 04:56:54.884 | INFO     | __main__:get_prediction:34 - Generated SQL for index 29: select distinct cost.cost from cost join medication on cost.patienthealthsystemstayid = medication.patientunitstayid where medication.drugname = 'epinephrine';
# 2025-07-27 04:56:55.984 | INFO     | __main__:get_prediction:34 - Generated SQL for index 55: select ( strftime('%J', patient.hospitaldischargetime) - strftime('%J', patient.hospitaladmittime) ) * 24 from patient where patient.uniquepid = '025-37141' and patient.patienthealthsystemstayid = ( select patient.patienthealthsystemstayid from patient where patient.uniquepid = '025-37141' order by patient.hospitaladmittime asc limit 1 ) order by patient.unitadmittime asc limit 1;
# 2025-07-27 04:56:56.751 | INFO     | __main__:get_prediction:34 - Generated SQL for index 33: select distinct cost.cost from cost where cost.eventtype = 'Diagnosis' and cost.uniquepid in ( select patient.uniquepid from patient where patient.patientunitstayid in ( select diagnosis.patientunitstayid from diagnosis where diagnosis.diagnosisname = 'acute pulmonary edema' ) ) order by cost.cost asc limit 1;
# 2025-07-27 04:56:58.030 | INFO     | __main__:get_prediction:34 - Generated SQL for index 49: SELECT  strftime('%J',patient.hospitaldischargetime) - strftime('%J',patient.hospitaladmittime) FROM patient WHERE patient.uniquepid = '011-58352' AND patient.hospitaldischargestatus = 'Discharged' ORDER BY patient.hospitaladmittime DESC LIMIT 1;
# 2025-07-27 04:56:58.415 | INFO     | __main__:get_prediction:34 - Generated SQL for index 56: select ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '018-47575' and patient.hospitaldischargestatus = 'Discharged' order by patient.hospitaladmittime desc limit 1 ) and lab.labname = 'admissionweight' order by lab.labresulttime desc limit 1 ) - ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '018-47575' and patient.hospitaldischargestatus = 'Discharged' order by patient.hospitaladmittime desc limit 1 ) and lab.labname = 'admissionweight' order by lab.labresulttime asc limit 1 ) );
# 2025-07-27 04:57:00.104 | INFO     | __main__:get_prediction:34 - Generated SQL for index 58: select (t2.dischargeweight - t1.dischargeweight) from ( select dischargeweight from patient where patient.uniquepid = '006-161415' and patient.hospitaldischargestatus = 'Discharged' and patient.hospitaladmittime = ( select min(hospitaladmittime) from patient where uniquepid = '006-161415' ) order by dischargeweight desc limit 1 ) as t1 join ( select dischargeweight from patient where patient.uniquepid = '006-161415' and patient.hospitaldischargestatus = 'Discharged' and patient.hospitaladmittime = ( select min(hospitaladmittime) from patient where uniquepid = '006-161415' ) order by dischargeweight desc limit 2 ) as t2 on 1 = 1;
# 2025-07-27 04:57:00.566 | INFO     | __main__:get_prediction:34 - Generated SQL for index 51: select ( strftime('%J',hospitaldischargetime) - strftime('%J',hospitaladmittime) ) * 86400 as los from patient where uniquepid = '016-1459' and hospitaldischargestatus = 'Discharged' order by hospitaladmittime desc limit 1;
# 2025-07-27 04:57:00.788 | INFO     | __main__:get_prediction:34 - Generated SQL for index 52: select
#     strftime('%J',patient.hospitaldischargetime)) -
#     strftime('%J',patient.hospitaladmittime)) as los
# from patient
# where patient.uniquepid = '027-107035'
#     and patient.patienthealthsystemstayid = ( select patient.patienthealthsystemstayid from patient where patient.uniquepid = '027-107035' order by patient.hospitaladmittime asc limit 1 )
#     and patient.hospitaldischargestatus = 'Discharged'
# order by patient.hospitaladmittime asc limit 1;
# 2025-07-27 04:57:02.936 | INFO     | __main__:get_prediction:34 - Generated SQL for index 62: select ( select admissionweight from patient where patient.uniquepid = '012-4131' and unitadmittime = '2105-02-17 01:25:00' ) - ( select admissionweight from patient where patient.uniquepid = '012-4131' and unitadmittime = '2105-11-20 19:30:00' );
# 2025-07-27 04:57:05.261 | INFO     | __main__:get_prediction:34 - Generated SQL for index 60: select ( select admissionweight from patient where patient.uniquepid = '021-49416' and patient.patienthealthsystemstayid = ( select patient.patienthealthsystemstayid from patient where patient.uniquepid = '021-49416' order by patient.hospitaladmittime asc limit 1 ) order by patient.admissionweight asc limit 1 offset 1 ) - ( select admissionweight from patient where patient.uniquepid = '021-49416' and patient.patienthealthsystemstayid = ( select patient.patienthealthsystemstayid from patient where patient.uniquepid = '021-49416' order by patient.hospitaladmittime asc limit 1 ) order by patient.admissionweight asc limit 1 );
# 2025-07-27 04:57:05.695 | INFO     | __main__:get_prediction:34 - Generated SQL for index 59: select (lab.labresult - ( select lab.labresult from lab where lab.patientunitstayid = ( select patient.patientunitstayid from patient where patient.uniquepid = '021-240586' ) and lab.labname = 'admissionweight' and lab.labresulttime = '2101-10-12 15:58:00' )) * 100.0 / ( select lab.labresult from lab where lab.patientunitstayid = ( select patient.patientunitstayid from patient where patient.uniquepid = '021-240586' ) and lab.labname = 'admissionweight' and lab.labresulttime = '2101-10-12 15:58:00' ) as weight_variation
# from lab
# where lab.patientunitstayid = ( select patient.patientunitstayid from patient where patient.uniquepid = '021-240586' )
#   and lab.labname = 'admissionweight'
#   and lab.labresulttime = '2101-12-16 20:24:00';
# 2025-07-27 04:57:05.695 | INFO     | __main__:get_prediction:34 - Generated SQL for index 65: select ( select patient.admissionweight from patient where patient.uniquepid = '007-9115' and patient.patienthealthsystemstayid = ( select patient.patienthealthsystemstayid from patient where patient.uniquepid = '007-9115' order by patient.hospitaladmittime asc limit 1 ) order by patient.unitadmittime desc limit 1 ) - ( select patient.admissionweight from patient where patient.uniquepid = '007-9115' and patient.patienthealthsystemstayid = ( select patient.patienthealthsystemstayid from patient where patient.uniquepid = '007-9115' order by patient.hospitaladmittime asc limit 1 ) order by patient.unitadmittime asc limit 1 );
# 2025-07-27 04:57:08.019 | INFO     | __main__:get_prediction:34 - Generated SQL for index 66: select ( select patient.admissionweight from patient where patient.uniquepid = '006-146580' and patient.patienthealthsystemstayid = ( select patient.patienthealthsystemstayid from patient where patient.uniquepid = '006-146580' order by patient.hospitaladmittime asc limit 1 ) order by patient.unitadmittime asc limit 1 ) - ( select patient.admissionweight from patient where patient.uniquepid = '006-146580' and patient.patienthealthsystemstayid = ( select patient.patienthealthsystemstayid from patient where patient.uniquepid = '006-146580' order by patient.hospitaladmittime asc limit 1 ) order by patient.unitadmittime asc limit 1 offset 1 ) as weight_difference;
# 2025-07-27 04:57:09.653 | INFO     | __main__:get_prediction:34 - Generated SQL for index 67: select ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '006-195316' and patient.hospitaldischargestatus is null ) and lab.labname = 'creatinine' order by lab.labresulttime desc limit 1 ) - ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '006-195316' and patient.hospitaldischargestatus is null ) and lab.labname = 'creatinine' order by lab.labresulttime desc limit 2 offset 1 );
# 2025-07-27 04:57:09.870 | INFO     | __main__:get_prediction:34 - Generated SQL for index 68: select ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '035-24054' and patient.hospitaldischargestatus is null ) and lab.labname = 'Hgb' order by lab.labresulttime asc limit 1 offset 1 ) - ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '035-24054' and patient.hospitaldischargestatus is null ) and lab.labname = 'Hgb' order by lab.labresulttime asc limit 1 );
# 2025-07-27 04:57:10.654 | INFO     | __main__:get_prediction:34 - Generated SQL for index 57: select ( select patient.admissionweight from patient where patient.uniquepid = '010-12376' and patient.patienthealthsystemstayid = ( select patient.patienthealthsystemstayid from patient where patient.uniquepid = '010-12376' order by patient.hospitaladmittime asc limit 1 ) ) - ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '010-12376' and patient.patienthealthsystemstayid = ( select patient.patienthealthsystemstayid from patient where patient.uniquepid = '010-12376' order by patient.hospitaladmittime asc limit 1 ) ) and lab.labname = 'admissionweight' order by lab.labresulttime desc limit 1 );
# 2025-07-27 04:57:12.216 | INFO     | __main__:get_prediction:34 - Generated SQL for index 64: select ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '006-161415' and patient.hospitaldischargestatus = 'Discharged' ) order by lab.labresulttime desc limit 1 ) - ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '006-161415' and patient.hospitaldischargestatus = 'Discharged' ) order by lab.labresulttime desc limit 2 offset 1 ) as weight_change;
# 2025-07-27 04:57:14.261 | INFO     | __main__:get_prediction:34 - Generated SQL for index 70: select ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '005-68848' and patient.hospitaldischargestatus = 'Discharged' order by patient.hospitaladmittime desc limit 1 ) order by lab.labresulttime desc limit 1 ) - ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '005-68848' and patient.hospitaldischargestatus = 'Discharged' order by patient.hospitaladmittime desc limit 1 ) order by lab.labresulttime asc limit 1 ) );
# 2025-07-27 04:57:15.004 | INFO     | __main__:get_prediction:34 - Generated SQL for index 71: select ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '027-10308' and patient.hospitaldischargestatus = 'Discharged' order by patient.hospitaladmittime desc limit 1 ) and lab.labname = 'bedside glucose' order by lab.labresulttime desc limit 1 ) - ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '027-10308' and patient.hospitaldischargestatus = 'Discharged' order by patient.hospitaladmittime desc limit 1 ) and lab.labname = 'bedside glucose' order by lab.labresulttime desc limit 2 offset 1 ) );
# 2025-07-27 04:57:15.284 | INFO     | __main__:get_prediction:34 - Generated SQL for index 72: select ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '030-16826' ) and lab.labname = 'bun' and lab.labresulttime = '2104-06-17 13:25:00' ) - ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '030-16826' ) and lab.labname = 'bun' and lab.labresulttime = '2104-06-13 12:26:00' );
# 2025-07-27 04:57:16.945 | INFO     | __main__:get_prediction:34 - Generated SQL for index 73: select ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '002-59265' and patient.hospitaldischargestatus = 'Discharged' ) and lab.labname = 'peep' order by lab.labresulttime desc limit 1 ) - ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '002-59265' and patient.hospitaldischargestatus = 'Discharged' ) and lab.labname = 'peep' order by lab.labresulttime desc limit 1 offset 1 ) as change_in_peep;
# 2025-07-27 04:57:18.551 | INFO     | __main__:get_prediction:34 - Generated SQL for index 74: select ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '005-4471' and patient.hospitaldischargestatus is null ) and lab.labname = 'bun' order by lab.labresulttime asc limit 1 offset 1 ) - ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '005-4471' and patient.hospitaldischargestatus is null ) and lab.labname = 'bun' order by lab.labresulttime asc limit 1 );
# 2025-07-27 04:57:19.502 | INFO     | __main__:get_prediction:34 - Generated SQL for index 75: select ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '016-3041' and patient.hospitaldischargestatus = 'Discharged' ) and lab.labname = 'Sodium' order by lab.labresulttime asc limit 1 offset 1 ) - ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '016-3041' and patient.hospitaldischargestatus = 'Discharged' ) and lab.labname = 'Sodium' order by lab.labresulttime asc limit 1 );
# 2025-07-27 04:57:19.964 | INFO     | __main__:get_prediction:34 - Generated SQL for index 76: select ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '027-120477' ) and lab.labname = 'Sodium' and lab.labresulttime = '2104-01-04 13:15:00' ) - ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '027-120477' ) and lab.labname = 'Sodium' and lab.labresulttime = '2104-01-03 05:32:00' );
# 2025-07-27 04:57:21.680 | INFO     | __main__:get_prediction:34 - Generated SQL for index 78: select (vitalperiodic.sao2 - t1.sao2) from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '004-93782' and patient.hospitaldischargestatus = 'Discharged' order by patient.unitadmittime asc limit 1 ) and vitalperiodic.sao2 is not null order by vitalperiodic.observationtime asc limit 1 offset 1;
# 2025-07-27 04:57:23.977 | INFO     | __main__:get_prediction:34 - Generated SQL for index 79: select ( select vitalperiodic.temperature from vitalperiodic where vitalperiodic.patientunitstayid = ( select patient.patientunitstayid from patient where patient.uniquepid = '004-13127' ) and vitalperiodic.observationtime = '2105-12-31 22:54:00' ) - ( select vitalperiodic.temperature from vitalperiodic where vitalperiodic.patientunitstayid = ( select patient.patientunitstayid from patient where patient.uniquepid = '004-13127' ) and vitalperiodic.observationtime = '2105-12-31 22:49:00' );
# 2025-07-27 04:57:24.187 | INFO     | __main__:get_prediction:34 - Generated SQL for index 80: select ( select vitalperiodic.respiration from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '027-203413' ) and vitalperiodic.respiration is not null order by vitalperiodic.observationtime desc limit 1 ) - ( select vitalperiodic.respiration from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '027-203413' ) and vitalperiodic.respiration is not null order by vitalperiodic.observationtime desc limit 1 offset 1 );
# 2025-07-27 04:57:25.752 | INFO     | __main__:get_prediction:34 - Generated SQL for index 81: select ( select vitalperiodic.respiration from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '022-67644' ) and vitalperiodic.respiration is not null order by vitalperiodic.observationtime desc limit 1 ) - ( select vitalperiodic.respiration from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '022-67644' ) and vitalperiodic.respiration is not null order by vitalperiodic.observationtime asc limit 1 );
# 2025-07-27 04:57:26.266 | INFO     | __main__:get_prediction:34 - Generated SQL for index 77: select ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '015-67291' and patient.patienthealthsystemstayid = ( select patient.patienthealthsystemstayid from patient where patient.uniquepid = '015-67291' order by patient.hospitaladmittime asc limit 1 ) ) and lab.labname = 'HCT' order by lab.labresulttime desc limit 1 ) - ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '015-67291' and patient.patienthealthsystemstayid = ( select patient.patienthealthsystemstayid from patient where patient.uniquepid = '015-67291' order by patient.hospitaladmittime asc limit 1 ) ) and lab.labname = 'HCT' order by lab.labresulttime desc limit 2 offset 1 ) from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '015-67291' and patient.patienthealthsystemstayid = ( select patient.patienthealthsystemstayid from patient where patient.uniquepid = '015-67291' order by patient.hospitaladmittime asc limit 1 ) ) and lab.labname = 'HCT' order by lab.labresulttime desc limit 1 );
# 2025-07-27 04:57:28.237 | INFO     | __main__:get_prediction:34 - Generated SQL for index 82: select ( select vitalperiodic.heartrate from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '013-28507' ) and vitalperiodic.heartrate is not null order by vitalperiodic.observationtime asc limit 1 offset 1 ) - ( select vitalperiodic.heartrate from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '013-28507' ) and vitalperiodic.heartrate is not null order by vitalperiodic.observationtime asc limit 1 );
# 2025-07-27 04:57:28.702 | INFO     | __main__:get_prediction:34 - Generated SQL for index 83: select ( select vitalperiodic.heartrate from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '015-96048' ) and vitalperiodic.observationtime = '2105-08-15 09:57:00' ) - ( select vitalperiodic.heartrate from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '015-96048' ) and vitalperiodic.observationtime = '2105-08-15 09:52:00' );
# 2025-07-27 04:57:30.002 | INFO     | __main__:get_prediction:34 - Generated SQL for index 84: select ( select vitalperiodic.heartrate from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '015-94586' ) and vitalperiodic.heartrate is not null order by vitalperiodic.observationtime asc limit 1 offset 1 ) - ( select vitalperiodic.heartrate from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '015-94586' ) and vitalperiodic.heartrate is not null order by vitalperiodic.observationtime asc limit 1 );
# 2025-07-27 04:57:30.804 | INFO     | __main__:get_prediction:34 - Generated SQL for index 85: select ( select vitalperiodic.heartrate from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '027-94096' ) and vitalperiodic.observationtime = '2104-07-27 12:18:40' ) - ( select vitalperiodic.heartrate from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '027-94096' ) and vitalperiodic.observationtime = '2104-07-27 12:13:40' );
# 2025-07-27 04:57:32.558 | INFO     | __main__:get_prediction:34 - Generated SQL for index 86: select ( select vitalperiodic.respiration from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '006-36108' and patient.unitdischargetime is not null order by patient.unitadmittime asc ) order by vitalperiodic.observationtime desc limit 1 ) - ( select vitalperiodic.respiration from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '006-36108' and patient.unitdischargetime is not null order by patient.unitadmittime asc ) ) as respiration_difference;
# 2025-07-27 04:57:34.373 | INFO     | __main__:get_prediction:34 - Generated SQL for index 88: select ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '006-133605' and patient.hospitaldischargestatus is null ) and lab.labname = 'lactate' order by lab.labresulttime desc limit 1 ) > ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '006-133605' and patient.hospitaldischargestatus is null ) and lab.labname = 'lactate' order by lab.labresulttime asc limit 1 );
# 2025-07-27 04:57:35.143 | INFO     | __main__:get_prediction:34 - Generated SQL for index 87: select ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '035-11731' and patient.patienthealthsystemstayid = ( select patient.patienthealthsystemstayid from patient where patient.uniquepid = '035-11731' order by patient.hospitaladmittime asc limit 1 ) ) and lab.labname = '-eos' order by lab.labresulttime desc limit 1 ) < ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '035-11731' and patient.patienthealthsystemstayid = ( select patient.patienthealthsystemstayid from patient where patient.uniquepid = '035-11731' order by patient.hospitaladmittime asc limit 1 ) ) and lab.labname = '-eos' order by lab.labresulttime desc limit 2 offset 1 );
# 2025-07-27 04:57:37.543 | INFO     | __main__:get_prediction:34 - Generated SQL for index 89: select ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '027-69449' and patient.patienthealthsystemstayid = ( select patient.patienthealthsystemstayid from patient where patient.uniquepid = '027-69449' order by patient.hospitaladmittime asc limit 1 ) ) and lab.labname = 'platelets x 1000' order by lab.labresulttime desc limit 1 ) < ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '027-69449' and patient.patienthealthsystemstayid = ( select patient.patienthealthsystemstayid from patient where patient.uniquepid = '027-69449' order by patient.hospitaladmittime asc limit 1 ) ) and lab.labname = 'platelets x 1000' order by lab.labresulttime desc limit 2 offset 1 );
# 2025-07-27 04:57:37.751 | INFO     | __main__:get_prediction:34 - Generated SQL for index 90: select ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '022-98345' and patient.hospitaldischargestatus = 'Discharged' order by patient.hospitaladmittime desc limit 1 ) and lab.labname = 'mch' order by lab.labresulttime asc limit 1 offset 1 ) < ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '022-98345' and patient.hospitaldischargestatus = 'Discharged' order by patient.hospitaladmittime desc limit 1 ) and lab.labname = 'mch' order by lab.labresulttime asc limit 1 ) );
# 2025-07-27 04:57:38.645 | INFO     | __main__:get_prediction:34 - Generated SQL for index 91: select ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '009-5001' and patient.hospitaldischargestatus is null ) and lab.labname = 'bedside glucose' order by lab.labresulttime desc limit 1 ) > ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '009-5001' and patient.hospitaldischargestatus is null ) and lab.labname = 'bedside glucose' order by lab.labresulttime asc limit 1 );
# 2025-07-27 04:57:39.797 | INFO     | __main__:get_prediction:34 - Generated SQL for index 92: select ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '007-15837' and patient.hospitaldischargestatus is null ) and lab.labname = 'wbc x 1000' order by lab.labresulttime desc limit 1 ) < ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '007-15837' and patient.hospitaldischargestatus is null ) and lab.labname = 'wbc x 1000' order by lab.labresulttime desc limit 2 offset 1 );
# 2025-07-27 04:57:42.073 | INFO     | __main__:get_prediction:34 - Generated SQL for index 94: select ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '021-111547' and patient.hospitaldischargestatus is null ) and lab.labname = 'calcium' order by lab.labresulttime desc limit 1 ) < ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '021-111547' and patient.hospitaldischargestatus is null ) and lab.labname = 'calcium' order by lab.labresulttime asc limit 1 );
# 2025-07-27 04:57:43.912 | INFO     | __main__:get_prediction:34 - Generated SQL for index 93: select ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '012-11090' and patient.patienthealthsystemstayid = ( select patient.patienthealthsystemstayid from patient where patient.uniquepid = '012-11090' order by patient.hospitaladmittime asc limit 1 ) ) and lab.labname = 'chloride' order by lab.labresulttime desc limit 1 ) < ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '012-11090' and patient.patienthealthsystemstayid = ( select patient.patienthealthsystemstayid from patient where patient.uniquepid = '012-11090' order by patient.hospitaladmittime asc limit 1 ) ) and lab.labname = 'chloride' order by lab.labresulttime asc limit 1 );
# 2025-07-27 04:57:44.219 | INFO     | __main__:get_prediction:34 - Generated SQL for index 96: select ( select vitalperiodic.systemicmean from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '027-210868' and patient.hospitaldischargestatus = 'Discharged' ) order by vitalperiodic.observationtime desc limit 1 ) > ( select vitalperiodic.systemicmean from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '027-210868' and patient.hospitaldischargestatus = 'Discharged' ) order by vitalperiodic.observationtime asc limit 1 );
# 2025-07-27 04:57:44.732 | INFO     | __main__:get_prediction:34 - Generated SQL for index 95: select ( select vitalperiodic.systemicsystolic from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '006-146580' and patient.unitadmittime = ( select patient.unitadmittime from patient where patient.uniquepid = '006-146580' order by patient.unitadmittime asc limit 1 ) ) order by vitalperiodic.observationtime desc limit 1 ) < ( select vitalperiodic.systemicsystolic from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '006-146580' and patient.unitadmittime = ( select patient.unitadmittime from patient where patient.uniquepid = '006-146580' order by patient.unitadmittime asc limit 1 ) ) ) order by vitalperiodic.observationtime asc limit 1 );
# 2025-07-27 04:57:46.387 | INFO     | __main__:get_prediction:34 - Generated SQL for index 97: select ( select vitalperiodic.sao2 from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '027-165214' and patient.unitdischargetime is null ) order by vitalperiodic.observationtime desc limit 1 )
#        >
#        ( select vitalperiodic.sao2 from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '027-165214' and patient.unitdischargetime is null ) order by vitalperiodic.observationtime asc limit 1 );
# 2025-07-27 04:57:47.892 | INFO     | __main__:get_prediction:34 - Generated SQL for index 101: select patient.age from patient where patient.uniquepid = '028-34632' and patient.hospitaldischargestatus = 'Discharged' order by patient.hospitaladmittime desc limit 1;
# 2025-07-27 04:57:48.098 | INFO     | __main__:get_prediction:34 - Generated SQL for index 98: select ( select vitalperiodic.sao2 from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '031-9128' ) and vitalperiodic.sao2 is not null order by vitalperiodic.observationtime desc limit 1 ) > ( select vitalperiodic.sao2 from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '031-9128' ) and vitalperiodic.sao2 is not null order by vitalperiodic.observationtime desc limit 2 offset 1 );
# 2025-07-27 04:57:48.331 | INFO     | __main__:get_prediction:34 - Generated SQL for index 99: select ( select vitalperiodic.heartrate from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '005-4471' ) and vitalperiodic.heartrate is not null order by vitalperiodic.observationtime desc limit 1 ) < ( select vitalperiodic.heartrate from vitalperiodic where vitalperiodic.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '005-4471' ) and vitalperiodic.heartrate is not null order by vitalperiodic.observationtime asc limit 1 );
# 2025-07-27 04:57:49.402 | INFO     | __main__:get_prediction:34 - Generated SQL for index 102: select patient.age from patient where patient.uniquepid = '016-35481' and patient.hospitaldischargestatus = 'Discharged' order by patient.hospitaladmittime desc limit 1;
# 2025-07-27 04:57:49.606 | INFO     | __main__:get_prediction:34 - Generated SQL for index 104: select patient.age from patient where patient.uniquepid = '006-158338' and patient.hospitaldischargestatus is null;
# 2025-07-27 04:57:50.429 | INFO     | __main__:get_prediction:34 - Generated SQL for index 103: select age from patient where uniquepid = '003-39001' and patienthealthsystemstayid in ( select patient.patienthealthsystemstayid from patient where patient.uniquepid = '003-39001' order by patient.hospitaladmittime desc limit 1 ) order by patient.unitadmittime desc limit 1;
# 2025-07-27 04:57:50.943 | INFO     | __main__:get_prediction:34 - Generated SQL for index 105: select patient.age from patient where patient.uniquepid = '022-130563' and patient.hospitaldischargestatus = 'Discharged' order by patient.hospitaladmittime desc limit 1;
# 2025-07-27 04:57:51.147 | INFO     | __main__:get_prediction:34 - Generated SQL for index 69: select ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '010-37449' and patient.patienthealthsystemstayid = ( select patient.patienthealthsystemstayid from patient where patient.uniquepid = '010-37449' order by patient.hospitaladmittime asc limit 1 ) ) and lab.labname = 'HCT' order by lab.labresulttime desc limit 1 ) - ( select lab.labresult from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '010-37449' and patient.patienthealthsystemstayid = ( select patient.patienthealthsystemstayid from patient where patient.uniquepid = '010-37449' order by patient.hospitaladmittime asc limit 1 ) ) and lab.labname = 'HCT' order by lab.labresulttime asc limit 1 );
# 2025-07-27 04:57:51.532 | INFO     | __main__:get_prediction:34 - Generated SQL for index 106: select age from patient where uniquepid = '002-56583' and patienthealthsystemstayid = ( select patient.patienthealthsystemstayid from patient where patient.uniquepid = '002-56583' order by patient.hospitaladmittime desc limit 1 );
# 2025-07-27 04:57:53.993 | INFO     | __main__:get_prediction:34 - Generated SQL for index 109: select percent_rank() within group (order by lab.labresult) from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.uniquepid = '007-15837' and patient.age = ( select patient.age from patient where patient.uniquepid = '007-15837' ) ) and lab.labname = 'bun' and lab.labresult = 18.0;
# ...
#     join diagnosis d2 on p2.patientunitstayid = d2.patientunitstayid
#     join treatment t2 on p2.patientunitstayid = t2.patientunitstayid
#     join medication t3 on t2.patientunitstayid = t3.patientunitstayid
# where
#     d1.diagnosisname = 'hepatic dysfunction - severe'
#     and d2.diagnosisname = 'hepatic dysfunction - severe'
#     and p1.gender = 'female'
#     and p1.age between '40' and '49'
#     and datetime(t2.treatmenttime) between datetime(d1.diagnosistime, 'start of year') and datetime(d1.diagnosistime, 'start of year') + '1 year'
#     and datetime(t3.drugstarttime) between datetime(t2.treatmenttime) and datetime(t2.treatmenttime) + '2 month'
# group by
#     t3.drugname
# order by
#     prescription_count desc
# limit 4;
# 2025-07-27 05:17:18.132 | INFO     | __main__:get_prediction:34 - Generated SQL for index 1157: select t3.labname from ( select labname, dense_rank() over ( order by count(*) desc ) as c1 from lab where lab.patientunitstayid in ( select patient.patientunitstayid from patient where patient.hospitaldischargestatus = 'Discharged' and strftime('%Y',patient.hospitaldischargetime)) and labname not in ( select medication.drugname from medication where medication.drugstarttime < '2104-01-01' and medication.drugname like '%thyroid hormone%' ) group by lab.labname ) as t3 where t3.c1 <= 3;
# 2025-07-27 05:17:20.171 | INFO     | __main__:get_prediction:34 - Generated SQL for index 1164: select t1.culturesite from ( select culturesite, dense_rank() over ( order by count(*) desc ) as c1 from microlab where datetime(culturetakentime) >= datetime('2100-01-01') group by culturesite ) as t1 where t1.c1 <= 5;
# 2025-07-27 05:17:20.917 | INFO     | __main__:get_prediction:34 - Generated SQL for index 1126: select t4.drugname from ( select t3.drugname, count(*) as c1 from ( select t2.drugname, t1.diagnosistime from ( select patient.uniquepid, diagnosis.diagnosisname, diagnosis.diagnosistime from diagnosis join patient on diagnosis.patientunitstayid = patient.patientunitstayid where diagnosis.diagnosisname = 'pleural effusion - left' ) as t2 where t2.uniquepid in ( select patient.uniquepid from patient where patient.gender = 'male' and patient.age between 50 and 59 ) ) as t3 join medication on t3.drugname = medication.drugname where datetime(t3.diagnosistime) >= datetime('2151-01-01') group by t3.drugname ) as t4 join ( select t2.drugname, count(*) as c2 from ( select t1.drugname, diagnosis.diagnosistime from ( select patient.uniquepid, medication.drugname from medication join patient on medication.patientunitstayid = patient.patientunitstayid where patient.gender = 'male' and patient.age between 50 and 59 ) as t1 where t1.uniquepid in ( select patient.uniquepid from patient where patient.gender = 'male' and patient.age between 50 and 59 ) ) as t2 join medication on t2.drugname = medication.drugname where datetime(t2.diagnosistime) >= datetime('2151-01-01') group by t2.drugname ) as t5 on t4.drugname = t5.drugname where t4.c1 = t5.c2 order by t5.c2 desc limit 4;
# 2025-07-27 05:17:21.967 | INFO     | __main__:get_prediction:34 - Generated SQL for index 1161: select
#     t3.labname,
#     count(*) as test_count
# from
#     treatment t1
#     join patient t2 on t1.patientunitstayid = t2.patientunitstayid
#     join lab t3 on t2.patientunitstayid = t3.patientunitstayid
# where
#     t1.treatmentname = 'vasodilator for pulmonary hypertension'
#     and datetime(t1.treatmenttime,'start of year') = datetime('2100-01-01','start of year')
#     and datetime(t3.labresulttime,'start of month') = datetime(t1.treatmenttime,'start of month')
# group by
#     t3.labname
# order by
#     test_count desc
# limit 5;
# 2025-07-27 05:17:22.427 | INFO     | __main__:get_prediction:34 - Generated SQL for index 1165: select t1.culturesite from ( select culturesite, dense_rank() over ( order by count(*) desc ) as c1 from microlab where datetime(culturetakentime,'start of year') = datetime('2103-01-01','start of year') group by culturesite ) as t1 where t1.c1 <= 5;
# 2025-07-27 05:17:23.170 | INFO     | __main__:get_prediction:34 - Generated SQL for index 1160: select
#     t3.labname as lab_test_name,
#     count(*) as test_frequency
# from
#     patient p
#     join treatment t1 on p.patientunitstayid = t1.patientunitstayid
#     join treatment t2 on p.patientunitstayid = t2.patientunitstayid
#         and t2.treatmenttime > t1.treatmenttime
#         and datetime(t2.treatmenttime,'start of year') = datetime('2104','start of year'))
#     join lab t3 on p.patientunitstayid = t3.patientunitstayid
#         and t3.labresulttime > t2.treatmenttime
#         and datetime(t3.labresulttime,'start of year') = datetime('2104','start of year'))
# where
#     t1.treatmentname = 'parenteral feeds - tpn'
#     and t2.treatmentname = 'parenteral feeds - tpn'
# group by
#     t3.labname
# order by
#     test_frequency desc
# limit 4;
# 2025-07-27 05:17:24.190 | INFO     | __main__:get_prediction:34 - Generated SQL for index 1168: select t1.labname from ( select lab.labname, dense_rank() over ( order by count(*) desc ) as c1 from lab join patient on lab.patientunitstayid = patient.patientunitstayid where lab.labname = 'anemia - iron deficiency anemia secondary to chronic blood loss' and datetime(lab.labresulttime,'start of year') = datetime('2105-01-01','start of year') group by lab.labname ) as t1 where t1.c1 <= 5;
# 2025-07-27 05:17:26.534 | INFO     | __main__:get_prediction:34 - Generated SQL for index 1169: select t3.culturesite from ( select t1.patientunitstayid, count(*) as c1 from diagnosis t1 where t1.diagnosisname = 'hypotension' group by t1.patientunitstayid ) as t2 join ( select patientunitstayid, culturesite from microlab group by patientunitstayid, culturesite ) as t3 on t2.patientunitstayid = t3.patientunitstayid where t2.c1 = 1 and datetime(t3.culturetakentime) between datetime(diagnosis.diagnosistime)) as t4 group by t4.culturesite order by count(*) desc limit 5;
# 2025-07-27 05:17:28.452 | INFO     | __main__:get_prediction:34 - Generated SQL for index 1170: select t3.culturesite from ( select patient.patienthealthsystemstayid, diagnosis.diagnosistime from diagnosis join patient on diagnosis.patientunitstayid = patient.patientunitstayid where diagnosis.diagnosisname = 'change in mental status' and strftime('%Y',diagnosis.diagnosistime)) as t1 join ( select patient.patienthealthsystemstayid, microlab.culturetakentime from microlab join patient on microlab.patientunitstayid = patient.patientunitstayid where strftime('%Y',microlab.culturetakentime) = '2105' ) as t2 on t1.patienthealthsystemstayid = t2.patienthealthsystemstayid where t1.diagnosistime < t2.culturetakentime group by t2.culturesite order by count(*) desc limit 4 );
# 2025-07-27 05:17:30.035 | INFO     | __main__:get_prediction:34 - Generated SQL for index 1171: select t3.culturesite from ( select t2.culturesite, dense_rank() over ( order by count(*) desc ) as c1 from ( select patient.uniquepid, microlab.culturesite, microlab.culturetakentime from microlab join patient on microlab.patientunitstayid = patient.patientunitstayid where microlab.culturesite is not null ) as t2 join ( select patient.uniquepid, diagnosis.diagnosistime from diagnosis join patient on diagnosis.patientunitstayid = patient.patientunitstayid where diagnosis.diagnosisname = 'asthma / bronchospasm' and datetime(diagnosis.diagnosistime) <= datetime('2100-01-01')) as t3 on t2.uniquepid = t3.uniquepid where t2.culturetakentime between t3.diagnosistime and datetime(t3.diagnosistime,'+2 month')) as t4 where t4.c1 <= 4;
# 2025-07-27 05:17:32.850 | INFO     | __main__:get_prediction:34 - Generated SQL for index 1172: select t3.culturesite from ( select t1.culturesite, dense_rank() over ( order by count(*) desc ) as c1 from ( select microlab.culturesite, microlab.patientunitstayid from microlab where datetime(microlab.culturetakentime,'start of year') = datetime('2100-01-01','start of year')) as t1 group by t1.culturesite ) as t2 join ( select treatment.treatmenttime, treatment.patientunitstayid from treatment where treatment.treatmentname = 'endotracheal tube - insertion' and datetime(treatment.treatmenttime,'start of year') = datetime('2100-01-01','start of year') ) as t3 on t2.patientunitstayid = t3.patientunitstayid where t2.c1 <= 3 and datetime(t3.treatmenttime) between datetime(t2.c1) and datetime(t2.c1) + 2 * 'month' order by t2.c1 asc, t3.treatmenttime asc;
# 2025-07-27 05:17:33.208 | INFO     | __main__:get_prediction:34 - Generated SQL for index 1173: select t3.culturesite from ( select microlab.culturesite, count(*) as c1 from microlab join treatment on microlab.patientunitstayid = treatment.patientunitstayid where treatment.treatmentname = 'insulin - sliding scale administration' and datetime(treatment.treatmenttime,'start of month') = datetime('2100-01-01','start of month')) as t1 join ( select microlab.culturesite, count(*) as c2 from microlab where datetime(microlab.culturetakentime,'start of month')) as t2 on t1.culturesite = t2.culturesite where t1.c1 = 1 and datetime(t1.c1) = datetime(t2.c2) order by t2.c2 desc limit 5;
# 2025-07-27 05:17:33.515 | INFO     | __main__:get_prediction:34 - Generated SQL for index 1167: select t3.culturesite from ( select microlab.culturesite, count(*) as c1 from microlab join patient on microlab.patientunitstayid = patient.patientunitstayid where microlab.culturetakentime >= datetime('2100-01-01','-1 year') and microlab.culturetakentime < datetime('2100-01-01','-1 year','+1 month') group by microlab.culturesite ) as t1 ( culturesite, c1 ) join ( select diagnosis.diagnosistime, patient.uniquepid from diagnosis join patient on diagnosis.patientunitstayid = patient.patientunitstayid where diagnosis.diagnosistime >= datetime('2100-01-01','-1 year') and diagnosis.diagnosistime < datetime('2100-01-01','-1 year','+1 month') ) as t2 ( diagnosistime, uniquepid ) on t1.c1 = ( select count(*) from microlab join patient on microlab.patientunitstayid = patient.patientunitstayid where microlab.culturetakentime >= datetime('2100-01-01','-1 year') and microlab.culturetakentime < datetime('2100-01-01','-1 year','+1 month') ) and t1.c1 = ( select count(*) from microlab join patient on microlab.patientunitstayid = patient.patientunitstayid where microlab.culturetakentime >= datetime('2100-01-01','-1 year','-1 month') and microlab.culturetakentime < datetime('2100-01-01','-1 year','+1 month') ) group by t1.culturesite ) as t3 ( culturesite, c1 ) order by t3.c1 desc limit 3;
# 2025-07-27 05:17:36.190 | INFO     | __main__:get_prediction:34 - Generated SQL for index 1178: select t1.celllabel from ( select intakeoutput.celllabel, dense_rank() over ( order by count(*) desc ) as c1 from intakeoutput where intakeoutput.cellpath like '%input%' and datetime(intakeoutput.intakeoutputtime,'start of year') = datetime('2100-01-01','start of year','-1 year') group by intakeoutput.celllabel ) as t1 where t1.c1 <= 4;
# 2025-07-27 05:17:38.208 | INFO     | __main__:get_prediction:34 - Generated SQL for index 1176: select t3.culturesite from ( select t2.culturesite, dense_rank() over ( order by count(*) desc ) as c1 from ( select t1.culturesite, t1.patientunitstayid from ( select patientunitstayid, treatmenttime from treatment where treatmentname = 'ferrous iron compound - iron dextran' and strftime('%Y', treatmenttime) <= '2104' ) as t1 join ( select patientunitstayid, culturesite from microlab ) as t2 on t1.patientunitstayid = t2.patientunitstayid where datetime(t2.culturetakentime) between datetime(t1.treatmenttime) and datetime(t1.treatmenttime) + '2 months' ) as t2 group by t2.culturesite ) as t3 where t3.c1 <= 3;
# 2025-07-27 05:17:38.617 | INFO     | __main__:get_prediction:34 - Generated SQL for index 1174: select t3.culturesite from ( select microlab.culturesite, count(*) as c1 from microlab join treatment on microlab.patientunitstayid = treatment.patientunitstayid where treatment.treatmentname = 'thyroid hormone - injection' and datetime(treatment.treatmenttime,'start of month') = datetime('2105-01-01','start of month') group by microlab.culturesite ) as t1 ( culturesite, c1 )
#
# union all
#
# ( select lab.labname, count(*) as c1 from lab join treatment on lab.patientunitstayid = treatment.patientunitstayid where treatment.treatmentname = 'thyroid hormone - injection' and datetime(treatment.treatmenttime,'start of month') = datetime('2105-01-01','start of month') group by lab.labname ) ) as t2 ( culturesite, c1 )
#
# union all
#
# ( select intakeoutput.cellpath, count(*) as c1 from intakeoutput join treatment on intakeoutput.patientunitstayid = treatment.patientunitstayid where treatment.treatmentname = 'thyroid hormone - injection' and datetime(treatment.treatmenttime,'start of month') = datetime('2105-01-01','start of month') group by intakeoutput.cellpath ) ) as t3 ( culturesite, c1 )
#
# pivot ( count(c1) as c1 )
#
# order by c1 desc
#
# limit 3;
# 2025-07-27 05:17:39.870 | INFO     | __main__:get_prediction:34 - Generated SQL for index 1175: select t3.culturesite from ( select t1.culturesite, count(*) as c1 from ( select patient.uniquepid, treatment.treatmenttime from treatment join patient on treatment.patientunitstayid = patient.patientunitstayid where treatment.treatmentname = 'vasopressors - norepinephrine <= 0.1 micrograms/kg/min' and datetime(treatment.treatmenttime) >= '2105-01-01' ) as t1 join microlab on t1.uniquepid = microlab.patientunitstayid where datetime(microlab.culturetakentime) >= '2105-01-01' and datetime(microlab.culturetakentime) <= datetime('2105-03-01','-2 month')) as t2 join ( select culturesite, count(*) as c2 from microlab where datetime(culturetakentime) >= '2105-01-01' and datetime(culturetakentime) <= datetime('2105-03-01','-2 month')) as t3 on t2.c1 = t3.c2 order by t3.c2 desc limit 4;
# 2025-07-27 05:17:40.407 | INFO     | __main__:get_prediction:34 - Generated SQL for index 1180: select t1.celllabel from ( select intakeoutput.celllabel, count(*) as c1 from intakeoutput where intakeoutput.cellpath like '%input%' and datetime(intakeoutput.intakeoutputtime,'start of year') = datetime('2104','start of year','start of year')) as t1 where t1.c1 in ( select t2.c1 from ( select count(*) as c1 from intakeoutput where intakeoutput.cellpath like '%input%' and datetime(intakeoutput.intakeoutputtime,'start of year') = datetime('2104','start of year','start of year') group by intakeoutput.celllabel ) as t2 order by t2.c1 desc limit 4 ) order by t1.c1 desc;
# 2025-07-27 05:17:40.687 | INFO     | __main__:get_prediction:34 - Generated SQL for index 1179: select t1.celllabel from ( select intakeoutput.celllabel, dense_rank() over ( order by count(*) desc ) as c1 from intakeoutput where intakeoutput.cellpath like '%input%' and datetime(intakeoutput.intakeoutputtime) <= datetime('2100-01-01', '-4 year') group by intakeoutput.celllabel ) as t1 where t1.c1 <= 5;
# 2025-07-27 05:17:40.991 | INFO     | __main__:get_prediction:34 - Generated SQL for index 1182: select t1.celllabel from ( select io.celllabel, dense_rank() over ( order by count(*) desc ) as c1 from intakeoutput io where strftime('%Y',io.intakeoutputtime)) as t1 where t1.c1 <= 4 and t1.celllabel is not null and strftime('%Y',intakeoutput.intakeoutputtime)) <= '2103';
# 2025-07-27 05:17:43.026 | INFO     | __main__:get_prediction:34 - Generated SQL for index 1186: SELECT
#     t1.celllabel AS intake_name,
#     COUNT(*) AS intake_count
# FROM
#     intakeoutput t1
# WHERE
#     t1.intakeoutputtime >= '2102-01-01'
#     AND t1.intakeoutputtime < '2103-01-01'
#     AND t1.cellpath LIKE '%intake%'
# GROUP BY
#     t1.celllabel
# ORDER BY
#     intake_count DESC
# LIMIT 5;
# 2025-07-27 05:17:43.028 | SUCCESS  | __main__:run_predictions_async:13 - All predictions done.
# 2025-07-27 05:17:43.050 | SUCCESS  | __main__:run_predictions_async:30 - Predictions saved to ../model_predictions/eICU/mistral_nemo_minitron_8B_finetuned/trial_1/predictions.json
# 2025-07-27 05:17:43.051 | SUCCESS  | __main__:<module>:27 - Model mistral_nemo_minitron_8B_finetuned. Trial 1 completed. Time taken: 1334.81 seconds

# %% [markdown]
# **Trial 0**:
# - NVIDIA L40S (48GiB), 1 GPUs x 8 CPUs | 147GiB
# - vLLM setting: `--max-num-seqs 4`
# - 1xL40S GPU utlization: 97%
# - Time taken: 1343.81 seconds
#
# **Trial 1**:
# - Settings same as above
# - Time taken
#
#
# **Average**
# - Avg Time Taken: 1334.81 seconds

# %% [markdown]
# # Evaluate SQL query
#
# To evaluate the SQL query, we will execute BOTH the ground truth SQL statement and the predicted SQL statement against the SQL database, and compare their outcomes

# %%
import os
from utils import preprare_directory

# create output directory for evaluation results, relative to the path of model_evaluation directory
# note that the evaluate results need a clean new folder, because it will overwrite any existing files in the folder
pred_directory = f"../model_predictions/eICU/mistral_nemo_minitron_8B_finetuned/trial_{trial_number}"
eval_directory = os.path.join(pred_directory, "evaluation")
preprare_directory(eval_directory, exist_ok=False)

# the predicted file from previous step
pred_file = os.path.join(pred_directory, "predictions.json")

print("Using predictions from: ", pred_file)

# path to the eICU database
db_path = "../model_evaluation/databases/eicu.sqlite"
# Out:
# Using predictions from:  ../model_predictions/eICU/mistral_nemo_minitron_8B_finetuned/trial_1/predictions.json

# %%
# run evaluation
# !python ../model_evaluation/ehrsql_eval.py \
    --pred_file {pred_file} \
    --db_path {db_path} \
    --num_workers -1 \
    --timeout 60 \
    --out_file {eval_directory} \
    --ndigits 2

# %% [markdown]
# # Interpret results

# %%
fp = f"../model_predictions/eICU/mistral_nemo_minitron_8B_finetuned/trial_{trial_number}/evaluation/predictions_metrics.json"

with open(fp, "r") as f:
    metrics = json.load(f)

print(json.dumps(metrics, indent=4))
# Out:
# {
#     "precision_ans": 100.0,
#     "recall_ans": 96.65,
#     "f1_ans": 98.3,
#     "precision_exec": 36.26,
#     "recall_exec": 35.04,
#     "f1_exec": 35.64,
#     "acc": 35.04
# }

# %% [markdown]
# **Results**:
#
# **Trial 0**:
# ```json
# {
#     "precision_ans": 100.0,
#     "recall_ans": 96.71,
#     "f1_ans": 98.33,
#     "precision_exec": 36.81,
#     "recall_exec": 35.6,
#     "f1_exec": 36.2,
#     "acc": 35.6
# }
# ```
#
# **Trial 1**:
#
# ```json
# {
#     "precision_ans": 100.0,
#     "recall_ans": 96.65,
#     "f1_ans": 98.3,
#     "precision_exec": 36.26,
#     "recall_exec": 35.04,
#     "f1_exec": 35.64,
#     "acc": 35.04
# }
# ```

# %%
# average accuracy
import numpy as np
print("Average accuracy: ", np.mean([35.6, 35.04]), "%")
# Out:
# Average accuracy:  35.32 %

# %% [markdown]
# # Notes

# %% [markdown]
# - If DDL does not have comments, then the average accuracy is 35.32%
#     ```python
#     print("Average accuracy: ", np.mean([35.6, 35.04]), "%")
#     ```
